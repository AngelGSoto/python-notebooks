# %% [markdown]
# # Reading spectra of the extragalactic HII

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
from astropy.io import fits
import os
import glob
import json
import matplotlib.pyplot as plt

# %%
datadir = "../ExtHII-spectros/"
file_ = "M1S17brSM.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
plt.xlim(xmin=3700,xmax=8000)
plt.ylim(ymin=1e-17,ymax=0.29e-15)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-10b.0016.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-10r.0016.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3000,xmax=8000)
plt.ylim(ymin=-1e-17,ymax=1e-16)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.60)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-11b.0034.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-11r.0034.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3600,xmax=7000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-13b.0042.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-13r.0042.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=9000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*1.4)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-14b.0026.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-14r.0026.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=9000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*1.4)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-15b.0030.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-15r.0030.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*1.2)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-16b.0020.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-16r.0020.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.90)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-17b.0023.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-17r.0023.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*1.25)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-18b.0030.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-18r.0030.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-19b.0045.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-19r.0045.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-1b.0028.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-1r.0028.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H_20b.0030.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H_20r.0030.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H_21b.0027.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H_21r.0027.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.76)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-22b.0031.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-22r.0031.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.84)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-23b.0034.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-23r.0034.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.54)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-24b.0028.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-24r.0028.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*1.88)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-25b.0035.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-25r.0035.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.74)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-2b.0040.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-2r.0040.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-3b.0035.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-3r.0035.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.90)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-5b.0050.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-5r.0050.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.68)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-6b.0027.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-6r.0027.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.56)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-7b.0020.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-7r.0020.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.64)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-7b.0027.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-7r.0027.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.84)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-8b.0012.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-8r.0012.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.88)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-8b.0050.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-8r.0050.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.74)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "H-9b.0042.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "H-9r.0042.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.74)
gcf().set_size_inches(12,8)

# %% [markdown]
# # SySt

# %%
datadir = "../NGC55-HIIr/"
file_ = "StSy-3b.0032.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "StSy-3r.0032.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "SySt-1b.0014.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "SySt-1r.0014.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.62)
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HIIr/"
file_ = "SySt-2b.0025.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
file_1 = "SySt-2r.0025.dat"
x1 = np.loadtxt(os.path.join(datadir, file_1), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3500,xmax=9000)
plt.ylim(ymin=-1.9e-17,ymax=0.2e-15)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(x['Wl'], x['Flux'])
plt.plot(x1['Wl'], x1['Flux']*0.74)
gcf().set_size_inches(12,8)

# %% [markdown]
# # Comparation

# %%
datadir = "../NGC55-HII-spectros/"
file_ = "H-10b.0016+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
plt.xlim(xmin=3000,xmax=8000)
plt.ylim(ymin=-1e-17,ymax=1e-16)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HII-spectros/"
file_ = "H-13b.0042+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3700,xmax=8000)
plt.ylim(ymin=-0.5e-17,ymax=0.05e-14)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HII-spectros/"
file_ = "H-18b.0030+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-HII-spectros/"
file_ = "H_20b.0030+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-syst-spectros/"
file_ = "StSy-3b.0032+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-syst-spectros/"
file_ = "SySt-1b.0014+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)

# %%
datadir = "../NGC55-syst-spectros/"
file_ = "SySt-2b.0025+r.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
plt.xlim(xmin=3900,xmax=8000)
plt.ylim(ymin=-0.5e-16,ymax=0.05e-14)
plt.plot(x['Wl'], x['Flux'])
gcf().set_size_inches(12,8)
