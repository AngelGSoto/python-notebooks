# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt

# %%
datadir = "../BB_BB1_L3-600-spectros/"
file_ = "BB1_L3_T50_output_SED.dat"

# %%
wll = []
flux = []
f = open(os.path.join(datadir, file_), 'r') 
header1 = f.readline()
for line in f:
    line = line.strip()
    columns = line.split()
    wl = float(columns[0])
    fl = float(columns[6])
    if wl>=2000 and wl<=15000:
        wll.append(wl)
        flux.append(fl)
#wll, flux = zip(*sorted(zip(wll, flux)))

# %%
datadir1 = "../CLOUDY-Luis/Comp-stavros/"
file_1 = "BB1_L3_T50_output_SED.dat"
wll1 = []
flux1 = []
f1 = open(os.path.join(datadir1, file_1), 'r') 
header1 = f1.readline()
for line1 in f1:
    line1 = line1.strip()
    columns1 = line1.split()
    wl1 = float(columns1[0])
    fl1 = float(columns1[6])
    if wl1>=2000 and wl1<=15000:
        wll1.append(wl1)
        flux1.append(fl1)
wll1, flux1 = zip(*sorted(zip(wll1, flux1)))

# %%
datadir2 = "../../../Dropbox/CLOUDY-Luis/"
file_2 = "BB1_L3_T50_output_SED.dat"
wll2 = []
flux2 = []
f2 = open(os.path.join(datadir2, file_2), 'r') 
header2 = f2.readline()
for line2 in f2:
    line2 = line2.strip()
    columns2 = line2.split()
    wl2 = float(columns2[0])
    fl2 = float(columns2[6])
    if wl2>=2000 and wl2<=15000:
        wll2.append(wl2)
        flux2.append(fl2)
wll2, flux2 = zip(*sorted(zip(wll2, flux2)))

# %%
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(wll, flux, label="Coll")
plt.plot(wll1, flux1, label="Sala")
plt.plot(wll2, flux2, label="Luis")
#plt.plot(x3['Wl'], x3['Flux'], label="15kpc")
#plt.plot(x4['Wl'], x4['Flux'], label="20kpc")
plt.yscale("log")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,6)

# %%
datadir = "../BB_BB1_L3-300-spectros/"
file_ = "BB1_L3_T70_output_SED.dat"
wll = []
flux = []
f = open(os.path.join(datadir, file_), 'r') 
header1 = f.readline()
for line in f:
    line = line.strip()
    columns = line.split()
    wl = float(columns[0])
    fl = float(columns[6])
    if wl>=2000 and wl<=15000:
        wll.append(wl)
        flux.append(fl)
wll, flux = zip(*sorted(zip(wll, flux)))

# %%
datadir2 = "../../../Dropbox/CLOUDY-Luis/"
file_2 = "BB1_L3_T70_output_SED.dat"
wll2 = []
flux2 = []
f2 = open(os.path.join(datadir2, file_2), 'r') 
header2 = f2.readline()
for line2 in f2:
    line2 = line2.strip()
    columns2 = line2.split()
    wl2 = float(columns2[0])
    fl2 = float(columns2[6])
    if wl2>=2000 and wl2<=15000:
        wll2.append(wl2)
        flux2.append(fl2)
wll2, flux2 = zip(*sorted(zip(wll2, flux2)))

# %%
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(wll, flux, label="Coll")
plt.plot(wll2, flux2, label="Luis")
#plt.plot(x2['Wl'], x2['Flux'], label="5kpc")
#plt.plot(x3['Wl'], x3['Flux'], label="15kpc")
#plt.plot(x4['Wl'], x4['Flux'], label="20kpc")
plt.yscale("log")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,8)

# %%
datadir = "../BB_BB1_L3-300-spectros/"
file_ = "BB1_L3_T70_output_SED.dat"
wll = []
flux = []
f = open(os.path.join(datadir, file_), 'r') 
header1 = f.readline()
for line in f:
    line = line.strip()
    columns = line.split()
    wl = float(columns[0])
    fl = float(columns[6])
    if wl>=2000 and wl<=15000:
        wll.append(wl)
        flux.append(fl)
wll, flux = zip(*sorted(zip(wll, flux)))

# %%
datadir2 = "../luis-modelpne/"
file_2 = "BB1_L3_T70_output_SED.dat"
wll2 = []
flux2 = []
f2 = open(os.path.join(datadir2, file_2), 'r') 
header2 = f2.readline()
for line2 in f2:
    line2 = line2.strip()
    columns2 = line2.split()
    wl2 = float(columns2[0])
    fl2 = float(columns2[6])
    if wl2>=2000 and wl2<=15000:
        wll2.append(wl2)
        flux2.append(fl2)
wll2, flux2 = zip(*sorted(zip(wll2, flux2)))

# %%
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(wll, flux, label="Denise")
plt.plot(wll2, flux2, label="Luis")
#plt.plot(x2['Wl'], x2['Flux'], label="5kpc")
#plt.plot(x3['Wl'], x3['Flux'], label="15kpc")
#plt.plot(x4['Wl'], x4['Flux'], label="20kpc")
plt.yscale("log")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,8)

# %%
datadir = "../BB_BB1_L3-600-spectros/"
file_ = "BB1_L3_T50_output_SED.dat"
wll = []
flux = []
f = open(os.path.join(datadir, file_), 'r') 
header1 = f.readline()
for line in f:
    line = line.strip()
    columns = line.split()
    wl = float(columns[0])
    fl = float(columns[6])
    if wl>=2000 and wl<=15000:
        wll.append(wl)
        flux.append(fl)
wll, flux = zip(*sorted(zip(wll, flux)))

datadir2 = "../luis-modelpne/"
file_2 = "BB1_L3_T50_output_SED.dat"
wll2 = []
flux2 = []
f2 = open(os.path.join(datadir2, file_2), 'r') 
header2 = f2.readline()
for line2 in f2:
    line2 = line2.strip()
    columns2 = line2.split()
    wl2 = float(columns2[0])
    fl2 = float(columns2[6])
    if wl2>=2000 and wl2<=15000:
        wll2.append(wl2)
        flux2.append(fl2)
wll2, flux2 = zip(*sorted(zip(wll2, flux2)))

# %%
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(wll, flux, label="Denise")
plt.plot(wll2, flux2, label="Luis")
#plt.plot(x2['Wl'], x2['Flux'], label="5kpc")
#plt.plot(x3['Wl'], x3['Flux'], label="15kpc")
#plt.plot(x4['Wl'], x4['Flux'], label="20kpc")
plt.yscale("log")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,8)

# %% [markdown]
# # Testiando nuevamente CLOUDY 2017

# %%
datadir = "../BB_BB1_L3-600-spectros/"
file_ = "BB1_L3_T50_output_SED.dat"
wll = []
flux = []
f = open(os.path.join(datadir, file_), 'r') 
header1 = f.readline()
for line in f:
    line = line.strip()
    columns = line.split()
    wl = float(columns[0])
    fl = float(columns[6])
    if wl>=2000 and wl<=15000:
        wll.append(wl)
        flux.append(fl)
wll, flux = zip(*sorted(zip(wll, flux)))

datadir2 = "../../../Dropbox/CLOUDY-Luis/luis-create/"
file_2 = "BB1_L3_T50_output_SED.dat"
wll2 = []
flux2 = []
f2 = open(os.path.join(datadir2, file_2), 'r') 
header2 = f2.readline()
for line2 in f2:
    line2 = line2.strip()
    columns2 = line2.split()
    wl2 = float(columns2[0])
    fl2 = float(columns2[6])
    if wl2>=2000 and wl2<=15000:
        wll2.append(wl2)
        flux2.append(fl2)
wll2, flux2 = zip(*sorted(zip(wll2, flux2)))

# %%
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(wll, flux, label="Denise")
plt.plot(wll2, flux2, label="Luis")
#plt.plot(x2['Wl'], x2['Flux'], label="5kpc")
#plt.plot(x3['Wl'], x3['Flux'], label="15kpc")
#plt.plot(x4['Wl'], x4['Flux'], label="20kpc")
plt.yscale("log")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,8)

# %%
"""
Routine to read a cloudy continuum output, produced by save last continuum
"""
from collections import namedtuple
import scipy.constants as physcons
try:
    c = physcons.c * 1e2   # c in CGS units
except:
    # This exception is here to deal with readthedocs not having scipy
    c = 3.0e10

def read_cloudy_continuum(filename, r0=None):
    """
    Reads a cloudy continuum output, produced by save last continuum

    Parameters
       filename : string
          name of the file to be read
       r0 : float
          inner radius, in cm; if included, the quantities returned will
          be total energies instead of energy emission rates instead of
          rates per unit area

    Returns
       A namedtuple containing the following fields:

       wl : array
          wavelengths in Angstrom
       incident : array
          incident radiation field intensity
    """

    # Open file
    fp = open(filename, 'r')

    # Burn the header line
    fp.readline()

    # Prepare storage
    en = []
    emission = []
    line_label = []
    cont_label = []
    line_density = []

    # Read the data
    for line in fp:
        # Skip comment lines that start with #
        if line.strip()[0] == '#':
            continue
        linesplit = line.split()
        en.append(float(linesplit[0]))
        incident = float(linesplit[1])
        transmitted = float(linesplit[2])
        emitted = float(linesplit[3])
        transmitted_plus_emitted = float(linesplit[4])
        emission.append([incident, transmitted, emitted,
                         transmitted_plus_emitted])
    fp.close()

    # Convert to arrays
    en = np.array(en)
    emission = np.transpose(np.array(emission))

    # Convert units to match convension in SLUG -- emission is
    # L_lambda, units of erg / s / Ang, flux is F_lambda, units of erg
    # / cm^2 / s / Ang; cloudy gives us nu L_nu / 4 pi r_0^2, units of
    # erg / s / cm^2
    nu = en * physcons.Rydberg*physcons.c  # Rydbergs to Hz
    F_nu = emission / nu                   # Convert nu L_nu to L_nu
    F_lambda = F_nu * nu**2/c / 1e8        # Convert L_nu to L_lambda,
                                           # and units to erg / s / Ang
    wl = 1e8 * c/nu[::-1]                  # Wavelength in Angstrom
    F_lambda = np.copy(F_lambda[:,::-1])   # Reverse order
    if r0 is not None:
        L_lambda = F_lambda * 4.0*np.pi*r0**2
        out_type = namedtuple('cloudy_continuum',
                              ['wl', 'L_lambda'])
        out = out_type(wl, L_lambda)
    else:
        out_type = namedtuple('cloudy_continuum',
                              ['wl', 'F_lambda'])
        out = out_type(wl, F_lambda)

    # Return output
    return out

# %%
datadir = "../../../Dropbox/CLOUDY-Luis/"
file_ = "BB1_L3_T50_output_SED.dat"
file__ = os.path.join(datadir, file_)

# %%
x, y = read_cloudy_continuum(file__)

# %%
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           3.05112207e+20,   3.03054261e+20,   3.01044533e+20],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           3.08570493e+33,   3.06393161e+33,   3.04263207e+33],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           3.08570493e+33,   3.06393161e+33,   3.04263207e+33]])

# %% [markdown]
# # New comments
