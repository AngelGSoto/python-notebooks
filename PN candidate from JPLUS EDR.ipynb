# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt

# %% [markdown]
# PN candidate classify as star in JPLUS EDR: 4589 (07 18 37.37177  +38 16  21.5144). No appears in the literature

# %%
mag = [22.0, 22.0, 22.0102539, 21.7526703, 22.1947689,  21.7716465, 21.549675, 20.6785908,  19.4841557, 21.4224014, 20.7914772, 21.0010147]

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters.append(a)

# %%
plt.plot(filters, mag, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlim(xmin=0,xmax=13)
# Out:
# (0, 13)

# %% [markdown]
# PN candidate classify as galaxy in JPLUS EDR: 23570 (123.412822537,	30.9374283136: 08 13 39.07741 +30 56 14.7419). Literature is a QSO: 08:13:39.08, +30:56:14.55 from SDSS dr14. Could be a H II region?

# %%
mag1 = [21.9655132, 21.6100349, 22.0207939, 20.9312897, 21.6066322, 21.233202, 22.3435555, 21.2108803,20.1311932,21.3538456 , 22.7403641, 22.5796413]

# %%
plt.plot(filters, mag1, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlim(xmin=0,xmax=13)
# Out:
# (0, 13)

# %% [markdown]
# Object classyfy as galaxy in JPLUS EDR:  15268.0 (125.093778615, 30.8083522017; 08 20 22.50687 +30 48 30.0679). Classify as Galaxy in SDSS DR14

# %%
mag2 = [20.9506092, 21.5800762, 22.1397457, 20.5938778, 20.7896156, 21.6442261, 22.3766041, 21.997509, 20.5363503, 22.6816711,22.6917553, 22.7961063]

# %%
plt.plot(filters, mag2, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlim(xmin=0,xmax=13)
# Out:
# (0, 13)

# %% [markdown]
# Classfy as galaxy in JPLUS EDR: 6756.0 (131.868220855, 40.0129381175; 08 47 28.37301 +40 00 46.5772). Classify as galaxy in SDSS DR14

# %%
mag3 = [19.997858, 22 , 22, 22, 21.1861305, 21.3749428, 22.0581818, 20.7113991, 19.2718239, 23.7036018, 22.1432762, 21.0784988]

# %%
plt.plot(filters, mag3, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlim(xmin=0,xmax=13)
# Out:
# (0, 13)

# %% [markdown]
# Classify as galaxi in JPLUS EDR: 16206.0 (133.466360163, 30.6019691357; 08:53:52.44, +30:36:00.37. Classy fy as galaxy in SDSS DR14

# %%
mag4 = [20.7325516, 21.5735493, 22.4782333, 22.4897614, 22.8986588, 20.6022797, 20.7057686, 20.7625465, 19.6417923, 22,21.5353165, 21.4987144]

# %%
plt.plot(filters, mag4, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlim(xmin=0,xmax=13)
# Out:
# (0, 13)

# %% [markdown]
# # INTERNAL DATA RELEASE (IDR)

# %% [markdown]
# Known PN found in JPLUS IDR. PN Sp 4-1 -- Planetary Nebula (19 00 26.550, +38 21 07.27). 17643.0 (285.110597952	38.3520080884) (19 00 26.544  +38 21 07.229') Class Stars= 0.974609. FWHM (arcsec)= 1.28

# %%
mag5 = [14.6058369, 14.5288668, 14.6673603, 15.0193253, 14.7185335, 13.8502798, 15.42239, 14.1130219,
        12.0540113, 14.9632168, 15.2237234, 15.0010681]

# %%
plt.plot(filters, mag5, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.xlim(xmin=0,xmax=13)
plt.tight_layout()
plt.savefig("Obje1-knownPN-sp41-photo17643.png")

# %% [markdown]
# Candidate JPLUS IDR. 7859.0	(15.7616286539, 1.63029671511) (01 03 02.79088 +01 37 49.0682). Class star = 0.774414. FWHM (arcsec) =1.10. Cataloged as star in SDSS

# %%
mag6 = [21.4215622, 20.726963, 20.7051067, 20.7301559, 20.7722778, 20.9727077, 
        21.3519726, 21.3417625, 20.5979671, 22.2363529, 22.3431816, 23.1128502]

# %%
plt.plot(filters, mag6, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlim(xmin=0,xmax=13)
plt.savefig("Cand1-jplus-photo7859.png")

# %% [markdown]
# PN candidate: 5283.0 (38.4293302806, 30.7057926813). DESCARTADA

# %%
mag66 = [23.2055397, 21.9905357, 21.7547379, 22.0943661, 22.2853642, 21.3431892, 21.6398106, 
         21.6556988, 20.9356613, 21.9581146, 24.812994, 22.6575108]
filters11 = []
filter_name11 = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters11.append(a)

plt.plot(filters11, mag66, 'ko-')
plt.xticks(filters11, filter_name11, rotation=45)
plt.xlim(xmin=0,xmax=13)
# Out:
# (0, 13)

# %% [markdown]
# Candidate PN: 34367.0 (281.09055876, 30.2201731503). Class star=0.056427. FWHM (arcsec) = 1.90

# %%
mag7 = [21.4142246, 21.7391129, 22.423687, 21.6940117, 20.2288094, 22.2980976, 22.493103, 22.3390484]

# %%
filters1 = []
filter_name1 = ['J0410',  'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 9):
    filters1.append(a)

plt.plot(filters1, mag7, 'ko-')
plt.xticks(filters1, filter_name1, rotation=45)
plt.xlim(xmin=0,xmax=9)
plt.savefig("Cand3-jplus-photo34367.png")

# %% [markdown]
# Known H II region: [HLG90] 73 -- HII (ionized) region (01 05 09.0 +02 09 12). IN JPLUS IDR: 17977.0 (16.2867819208, 2.1530595513). Class star=0.016632. FWHM (arcsec)= 1.72

# %%
mag8 = [19.3095665, 19.3799591, 20.0081215, 19.9795589, 19.8121529, 19.4880466, 19.7560844, 19.2536697, 17.6604843, 19.9728661, 20.5833836, 19.6220112]

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters.append(a)
plt.plot(filters, mag8, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.tight_layout()
plt.xlim(xmin=0,xmax=13)
plt.savefig("Obje2-known-HIIregion-[HLG90]73-jplusidr-photo17977.png")

# %% [markdown]
# PN candidate: 2469.0 (223.845641755	56.289220761), (14 55 22.95402 +56 17 21.1947). Class stars=0.008125. FWHM (arcsec) = 2.96

# %%
mag9 = [20.5307159, 20.652298, 20.9595146, 23.0192871, 21.1818352,
        22.0221596, 21.1660538, 19.7879505, 22.0194511, 23.0887146, 21.4332161]

# %%
filters2 = []
filter_name2 = ['uJAVA', 'J0378',  'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 12):
    filters2.append(a)
plt.plot(filters2, mag9, 'ko-')
plt.xticks(filters2, filter_name2, rotation=45)
plt.xlim(xmin=0,xmax=12)
plt.savefig("Cand4-jplus-photo2469.png")

# %% [markdown]
# PN candidate: 15002.0 (243.688196616 50.008513813); (16 14 45.16719 +50 00 30.6497). Class Star=0.066895. FWHM (arcsec) = 2.03. Segun sloan es Galaxia.

# %%
mag10 = [ 23.5387402, 23.8128204, 21.9594841, 22.0358047, 
         22.2028503, 22.2630882, 21.1854229, 22.8374329, 22.7703514, 24.2378292]

# %%
filters3 = []
filter_name3 = ['uJAVA', 'J0395', 'J0410',  'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 11):
    filters3.append(a)
plt.plot(filters3, mag10, 'ko-')
plt.xticks(filters3, filter_name3, rotation=45)
plt.xlim(xmin=0,xmax=11)
plt.savefig("Cand5-jplus-photo15002.png")

# %% [markdown]
# PN candidate: 29053.0 (285.144793867	39.9382548121), (19 00 34.75053 +39 56 17.7173). Class star=0.000165

# %%
mag11 = [20.3405132,  20.3104591, 19.9595222, 20.9230347, 21.2799015, 21.1393986, 
         19.5153046, 21.7178383, 22.0209236, 21.2477341]

# %%
filters4 = []
filter_name4 = ['uJAVA', 'J0395', 'J0410', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 11):
    filters4.append(a)
plt.plot(filters4, mag11, 'ko-')
plt.xticks(filters4, filter_name4, rotation=45)
plt.xlim(xmin=0,xmax=11)
plt.savefig("Cand6-jplus-photo29053.png")

# %% [markdown]
# PN candidate: 34799.0 (257.621211156 26.486357681), (17 10 29.09068 +26 29 10.8877). Class star=	0.040222. FWHM (arcsec)=2.33. Catalogada como estrella en el SLOAN

# %%
mag12 = [21.743515, 21.8722248, 22.659481,
         22.3062725,21.2263126, 23.1734257, 23.4847336, 23.8582687]

# %%
filters4 = []
filter_name4 = ['J0410', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 9):
    filters4.append(a)
plt.plot(filters4, mag12, 'ko-')
plt.xticks(filters4, filter_name4, rotation=45)
plt.xlim(xmin=0,xmax=9)
plt.savefig("Cand7-jplus-photo34799.png")

# %% [markdown]
# known Region HII??: 6143.0 (147.587169496	31.4864085285)(09 50 20.92068, +31 29 11.0707)--> CasHII Z 152-072 a -- HII (ionized) region (09 50 21.0, +31 29 30 ).  Class star = 0.026703. FWHM (arcsec) = 2.47. Sloan dice que es Galaxi.

# %%
mag13 = [17.8413029, 17.5914726, 17.7431622, 18.1091766, 17.8955116, 
         17.4969044, 18.0379257, 17.6115398, 16.0359306, 18.1020355, 18.3448849, 18.3293324]

# %%
filters5 = []
filter_name5 = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters5.append(a)
plt.plot(filters5, mag13, 'ko-')
plt.xticks(filters5, filter_name5, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.tight_layout()
plt.xlim(xmin=0,xmax=13)
plt.savefig("Cand2-jplus-photo6143.png")

# %% [markdown]
# # SySt candidates

# %% [markdown]
# Syst candidate: 2098.0 (130.299278814, 38.2094061099). Prob class = 0.911133. FWHM (arcsec)=1.71

# %%
mag14 = [21.1284561, 21.5151329, 21.0258789, 20.3726768, 20.109005, 19.2853069, 
         19.1498528, 18.2373581, 17.1633301, 17.7281342, 17.5632858, 17.426857]
filters6 = []
filter_name6 = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters6.append(a)
plt.plot(filters6, mag14, 'ko-')
plt.xticks(filters6, filter_name6, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.tight_layout()
plt.xlim(xmin=0,xmax=13)
plt.savefig("Cand1-syst-jplus-idr-photo2098.png")
plt.show()
plt.clf()

# %% [markdown]
# SySt candidate: 7371.0 (6.60090732575, 7.17631773078). Prob class = 0.994141. FWHM (arcsec) = 0.86

# %%
mag14 = [21.61903, 21.6313744, 20.451746, 20.9835987, 19.6135941, 
         19.2779655, 18.3477707, 16.7823753, 17.3516045, 16.9901676, 16.9283581]
filters6 = []
filter_name6 = ['J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 12):
    filters6.append(a)
plt.plot(filters6, mag14, 'ko-')
plt.xticks(filters6, filter_name6, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.tight_layout()
plt.xlim(xmin=0,xmax=13)
plt.savefig("Cand2-syst-jplus-idr-photo7371.png")
plt.show()
plt.clf()

# %% [markdown]
# SySt candidate: 9347.0 (225.810247684, 56.6229292985). Prob = 0.974609. FWHM (arcsec) = 0.95

# %%
mag14 = [21.2921562, 20.3384132, 20.2643261, 19.7200851, 18.4421539, 18.239769, 17.0612278, 15.5972338, 16.0306435, 15.6527824, 15.5058784]
filters6 = []
filter_name6 = ['J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 12):
    filters6.append(a)
plt.plot(filters6, mag14, 'ko-')
plt.xticks(filters6, filter_name6, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.tight_layout()
plt.xlim(xmin=0,xmax=13)
plt.savefig("Cand3-syst-jplus-idr-photo9347.png")
plt.show()
plt.clf()
