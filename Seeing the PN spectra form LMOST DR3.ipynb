# %% [markdown]
# # Plotting the Lamost spectra of PNe

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astroquery.simbad import Simbad
import astropy.coordinates as coord
import astropy.units as u
from astropy.io import ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord 
from astroquery.sdss import SDSS
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import seaborn as sn
sn.set_context("poster")
import glob

# %%
#Defining scrit to make the plots
def spectra(hduspectra):
            namefile = hduspectra.split("ec/")[-1].split(".f")[0]
            hdu = fits.open(hduspectra)
            hdudata = hdu[0].data
            wl = hdudata[2]
            Flux = hdudata[0]
            n = np.linspace(1, len(wl), num=len(wl), dtype = int)
            fig, ax = plt.subplots(figsize=(11, 5))
            ax.set_title(namefile)
            ax.set(xlim=[3600,9000])
            #plt.ylim(ymin=0.0,ymax=500)
            ax.set(xlabel='Wavelength $(\AA)$')
            ax.set(ylabel='Flux')
            ax.plot(wl, Flux, linewidth=0.9, zorder=5)
            ax.axvline(6560.28, color='k', linewidth=0.5, linestyle='--', label=r"H$\alpha$")
            ax.axvline(5000.7, color='k', linewidth=0.5, linestyle='-', label="[O III]")
            ax.axvline(4686, color='r', linewidth=0.5, linestyle='-', label="He II")
            ax.legend()
            ra = hdu[0].header["RA"]
            dec = hdu[0].header["DEC"]
            print("Nome file:", namefile, "=>", "RA and DEC:", ra, dec)

# %%
fitsfile_="../PNe-lamost-spec/*fits"
file_list = glob.glob(fitsfile_)

# %%
for file_ in file_list:
    spectra(file_)
# Out:
# Nome file: spec-56996-HD043544N451252V01_sp12-022 => RA and DEC: 70.838616 46.701622
# Nome file: spec-57732-HD083725N555909M01_sp11-040 => RA and DEC: 130.3982 58.230102
# Nome file: spec-56568-KP195920N454621M01_sp03-021 => RA and DEC: 299.003583 45.387889
# Nome file: spec-56767-HD175745N291452V01_sp05-212 => RA and DEC: 268.595849 27.999513
# Nome file: spec-57697-HD214208N454556B01_sp03-140 => RA and DEC: 324.704138 46.007792
# Nome file: spec-57491-HD093959N532949B02_sp06-028 => RA and DEC: 147.858229 53.158543
# Nome file: spec-57377-HD232455N560623V01_sp11-177 => RA and DEC: 351.561771 58.181834
# Nome file: spec-56952-HD070013N000500V_sp06-114 => RA and DEC: 107.343841 -0.806558
# Nome file: spec-55907-M31_021N30_B1_sp13-190 => RA and DEC: 27.72618 31.129651
# Nome file: spec-57778-HD084529N184902B02_sp08-197 => RA and DEC: 131.722663 17.879169
# Nome file: spec-56287-VB053N42V2_sp15-004 => RA and DEC: 52.800008 43.904232
# Nome file: spec-57169-HD163917N221316V01_sp12-025 => RA and DEC: 251.122977 23.799939
# Nome file: spec-56701-GAC071N47V1_sp05-062 => RA and DEC: 70.838698 46.701582
# Nome file: spec-57042-GAC084N40B1_sp08-116 => RA and DEC: 85.342194 39.252234
# Nome file: spec-57779-HD031226N474333B01_sp04-211 => RA and DEC: 48.691328 48.201636
# Nome file: spec-57019-HD083217N291909M01_sp16-242 => RA and DEC: 126.77306 31.502316
# Nome file: spec-56649-GAC078N31M1_sp05-241 => RA and DEC: 77.969074 30.465338
# Nome file: spec-57652-HD230346N280458B01_sp12-174 => RA and DEC: 347.867135 29.492757
# Nome file: spec-55903-M31_021N30_B1_sp13-190 => RA and DEC: 27.72618 31.129651
# Nome file: spec-57888-HD154717N140655B01_sp09-044 => RA and DEC: 237.728037 14.992719
# Nome file: spec-57752-HD085216N080346B01_sp09-151 => RA and DEC: 133.554475 8.89845
# Nome file: spec-55960-GAC_071N47_V1_sp05-062 => RA and DEC: 70.838698 46.701582
# Nome file: spec-56206-GAC089N24B1_sp09-123 => RA and DEC: 89.688914 25.312216
# /home/lgutierrez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':
# Nome file: spec-57300-EG024123N083137V01_sp11-198 => RA and DEC: 40.197299 10.350689
# Nome file: spec-56249-HD084529N184902M01_sp08-197 => RA and DEC: 131.72272 17.87953
# Nome file: spec-56966-HD213605N150455V01_sp01-008 => RA and DEC: 324.2207 12.788638
# Nome file: spec-56646-VB061N34V3_sp10-010 => RA and DEC: 59.091724 33.874889
# Nome file: spec-55909-B90903_1_sp16-130 => RA and DEC: 55.43086 52.283422
# Nome file: spec-56943-GAC079N41B1_sp07-037 => RA and DEC: 80.487607 39.517347
# Nome file: spec-57860-HD181338N104933V01_sp08-147 => RA and DEC: 274.392099 10.150929
# Nome file: spec-56600-GAC078N31M1_sp05-241 => RA and DEC: 77.969074 30.465338
# Nome file: spec-56265-GAC111S00V2_sp15-100 => RA and DEC: 110.952 0.60888
# Nome file: spec-56018-B5601808_sp04-177 => RA and DEC: 250.075904 38.705622
# Nome file: spec-56435-KP194045N483045V01_sp11-109 => RA and DEC: 296.200708 50.525083
# Nome file: spec-56396-HD125932N280356F01_sp04-145 => RA and DEC: 194.86575 27.63629
# Nome file: spec-56769-VB194N28V1_sp04-145 => RA and DEC: 194.86571 27.636259
# Nome file: spec-56249-HD084529N184902B01_sp08-197 => RA and DEC: 131.72272 17.87953
# Nome file: spec-57455-HD072742S030417V01_sp09-120 => RA and DEC: 112.493651 -2.110447
# Nome file: spec-56326-GAC069N36V2_sp08-030 => RA and DEC: 69.949695 36.76182
# Nome file: spec-55931-F5593101_sp11-120 => RA and DEC: 178.352908 59.6659
# Nome file: spec-57725-HD083217N291909M02_sp16-242 => RA and DEC: 126.77306 31.502316
# Nome file: spec-56404-HD114750N494922B01_sp06-020 => RA and DEC: 179.4368 48.938386
# Nome file: spec-56258-GAC105N15V1_sp05-035 => RA and DEC: 104.9874 14.609561
# Nome file: spec-57325-EG214033N103644V01_sp16-228 => RA and DEC: 324.2207 12.788638
# Nome file: spec-57059-HD072031N175152V01_sp04-045 => RA and DEC: 110.006438 18.290544
# Nome file: spec-56396-HD125932N280356M01_sp04-145 => RA and DEC: 194.86575 27.63629
# Nome file: spec-56570-GAC069N36V2_sp08-030 => RA and DEC: 69.949695 36.76182
# Nome file: spec-57882-HD180655S031400V01_sp16-181 => RA and DEC: 270.46746 -1.43817
# Nome file: spec-55931-M31_025N30_B2_sp13-176 => RA and DEC: 27.72618 31.129651

# %% [markdown]
# # Plotting the Lamost spectra of SySt

# %%
fitsfile_1="../SySt-lamost-spec/*fits"
file_list1 = glob.glob(fitsfile_1)

# %%
for file_1 in file_list1:
    spectra(file_1)
# Out:
# Nome file: spec-57909-HD204132N355439V01_sp05-145 => RA and DEC: 310.329129 34.747869
# Nome file: spec-55939-GAC_104N11_V3_sp13-088 => RA and DEC: 106.05323 12.059527
# Nome file: spec-56583-KP195920N454621V03_sp14-175 => RA and DEC: 297.489958 46.255722
# Nome file: spec-57377-HD232455N560623V01_sp11-177 => RA and DEC: 351.561771 58.181834
# Nome file: spec-57299-KP195920N454621V05_sp14-175 => RA and DEC: 297.48996 46.255718
# Nome file: spec-56203-EG213945N020821V01_sp09-161 => RA and DEC: 325.437011 2.73178
# Nome file: spec-57909-HD204132N355439V01_sp06-148 => RA and DEC: 312.75513 35.58167
# Nome file: spec-56965-HD081044N520834V01_sp03-146 => RA and DEC: 121.449794 52.774534
# Nome file: spec-57893-HD184507N063922B01_sp04-143 => RA and DEC: 281.192 6.11767
# Nome file: spec-56675-HD123204S014620V01_sp03-171 => RA and DEC: 187.020446 -1.807158
# Nome file: spec-56591-KP195920N454621V3_sp14-175 => RA and DEC: 297.489958 46.255722
# Nome file: spec-57414-HD123204S014620V02_sp03-171 => RA and DEC: 187.020446 -1.807158
# Nome file: spec-57866-HD180852N200242V01_sp13-152 => RA and DEC: 273.64246 20.98925
# Nome file: spec-57887-HD181910N242645V01_sp08-102 => RA and DEC: 275.532704 23.455544
