# %% [markdown]
# # Plotting Lamost spectra

# %%
from astroquery.simbad import Simbad
import astropy.coordinates as coord
import astropy.units as u
from astropy.io import ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord 
from astroquery.sdss import SDSS
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import seaborn as sn
sn.set_context("poster")
import glob
from spectra_lamost import spectra

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-56739-HD144825N222355V_sp15-005.fits")
# Out:
# Nome file: spec-56739-HD144825N222355V_sp15-005 => RA and DEC: 221.784571 23.360364

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-56609-GAC093N22B1_sp06-066.fits")
# Out:
# Nome file: spec-56609-GAC093N22B1_sp06-066 => RA and DEC: 95.713029 22.751647

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-56296-GAC096N02V1_sp12-078.fits")
# Out:
# Nome file: spec-56296-GAC096N02V1_sp12-078 => RA and DEC: 97.899001 4.413244

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-56609-GAC093N22M1_sp01-241.fits")
# Out:
# Nome file: spec-56609-GAC093N22M1_sp01-241 => RA and DEC: 92.31512 20.665459

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-55960-GAC_101N09_V1_sp05-160.fits")
# Out:
# Nome file: spec-55960-GAC_101N09_V1_sp05-160 => RA and DEC: 101.0623 8.879237

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-56306-GAC080N33M1_sp15-233.fits")
# Out:
# Nome file: spec-56306-GAC080N33M1_sp15-233 => RA and DEC: 79.037248 34.633443

# %%
spectra("../Lamost/HouEmission2016/spectra/spec-56646-VB061N34V3_sp14-080.fits")
# Out:
# Nome file: spec-56646-VB061N34V3_sp14-080 => RA and DEC: 59.884812 35.04121

# %%
fitsfile = Table.read("../Lamost/PN_SySt_Hou_EMO_Lamots.txt", format="ascii")

# %%
fitsfile_="../Lamost/HouEmission2016/spectra/*fits"
file_list = glob.glob(fitsfile_)

# %%
for file1, file2 in zip(fitsfile, file_list):
    print(file1, file2)
# Out:
# 'spec-56739-HD144825N222355V_sp15-005.fits'
# -------------------------------------------
#      'spec-56609-GAC093N22B1_sp06-066.fits' ../Lamost/HouEmission2016/spectra/spec-55863-GAC_105N29_B1_sp05-083.fits
# 'spec-56739-HD144825N222355V_sp15-005.fits'
# -------------------------------------------
#      'spec-56296-GAC096N02V1_sp12-078.fits' ../Lamost/HouEmission2016/spectra/spec-55922-GAC_091N29_M1_sp05-221.fits
# 'spec-56739-HD144825N222355V_sp15-005.fits'
# -------------------------------------------
#      'spec-56609-GAC093N22M1_sp01-241.fits' ../Lamost/HouEmission2016/spectra/spec-56974-HD040911N362538V01_sp10-123.fits
# 'spec-56739-HD144825N222355V_sp15-005.fits'
# -------------------------------------------
#    'spec-55960-GAC_101N09_V1_sp05-160.fits' ../Lamost/HouEmission2016/spectra/spec-55910-B91003_sp10-173.fits
# 'spec-56739-HD144825N222355V_sp15-005.fits'
# -------------------------------------------
# ...
