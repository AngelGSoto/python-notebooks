# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt
import pandas as pd
from astropy.table import Table

# %%
#datadir = "../JPLUS-DR2/aper6_mag_idr"
datadir = "../JPLUS-DR2/aper6_mag_idr/"
file_ = "PN-pc-Halpha_emitters_threeerror-cleaning-limfilter-limcolor-flags.tab"
file_1 = "SySt-pc-Halpha_emitters_threeerror-cleaning-limfilter-limcolor-flags.tab"

# %%
data = Table.read(os.path.join(datadir, file_), format="ascii.tab")
data1 = Table.read(os.path.join(datadir, file_1), format="ascii.tab")

# %%
print("# PNe =", len(data))
print("# SySt =", len(data1))
# Out:
# # PNe = 194
# # SySt = 1822

# %%
plt.xlim(-3., 3.)
plt.ylim(-2.2, 3.5)
#plt.plot((data1["r_auto"] - data1["i_auto"]), (data1["r_auto"] - data1["F660_auto"]), "o")
plt.plot((data["rSDSS_MAG_APER_6_0"] - data["iSDSS_MAG_APER_6_0"]), 
         (data["rSDSS_MAG_APER_6_0"] - data["J0660_MAG_APER_6_0"]), "ko", alpha=0.7, label="PNe")
plt.plot((data1["rSDSS_MAG_APER_6_0"] - data1["iSDSS_MAG_APER_6_0"]), 
         (data1["rSDSS_MAG_APER_6_0"] - data1["J0660_MAG_APER_6_0"]), "ro", alpha=0.2, label="SySt")
#plt.plot((data["rSDSS_auto"] - data["iSDSS_auto"]), 
         #(data["rSDSS_auto"] - data["J0660_auto"]), "ko", alpha=0.7, label="PNe")
#plt.plot((data1["rSDSS_auto"] - data1["iSDSS_auto"]), 
         #(data1["rSDSS_auto"] - data1["J0660_auto"]), "ro", alpha=0.2, label="SySt")
x = np.linspace(-5, 5)
y =  0.25*x + 0.5
plt.plot(x, y, "-")
plt.legend(fontsize=13)
gcf().set_size_inches(10,8)
