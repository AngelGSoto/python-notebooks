# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt

# %%
datadir = "../syst-spectros/"
file_ = "LHa_115_N_60.txt"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
plt.xlim(xmin=4000,xmax=8000)
plt.ylim(ymin=0.0,ymax=5e-15)
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(x['Wl'], x['Flux'])
plt.axvline(6825, color='k', linewidth=0.5, linestyle='--', label="6825")
plt.axvline(7082, color='k', linewidth=0.5, linestyle='-', label="7088")
plt.axvline(4686, color='r', linewidth=0.5, linestyle='-', label="He II")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,8)

# %%
def sys(spectra):
    datadir = "../syst-spectros/"
    file_ = spectra
    x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
    return x['Wl'], x['Flux']

# %%
def plot(spectra, yc):
    x, y = sys(spectra) 
    plt.xlim(xmin=4000,xmax=8000)
    plt.ylim(ymin=0.0,ymax=yc)
    plt.xlabel('Wavelength $(\AA)$', fontsize=15)
    plt.ylabel('Flux', fontsize=15)
    plt.plot(x, y)
    plt.axvline(6825, color='k', linestyle='--', label="6825")
    plt.axvline(7082, color='k', linestyle='-', label="7082")
    plt.axvline(4686, color='r', linestyle='-', label="He II")
    plt.legend()
    plt.savefig("spectrum-DdDm1.jpg")
    gcf().set_size_inches(12,8)

# %%
plot("LMC1.txt", 5e-14)

# %%
plot("SMC1.txt", 1e-14)

# %%
plot("SMC2.txt", 1e-14)

# %%
plot("SMC3.txt", 1e-14)

# %%
plot("Lin358.txt", 1e-14)

# %%
plot("Sanduleak.txt", 1e-14)

# %%
plot("LHa_115_N_73.txt", 1e-14)

# %%
plot("LHa_120_S_63.txt", 1e-14)

# %%
plot("LHa_115_N_67_1996.txt", 1e-14)

# %%
plt.clf()

# %% [markdown]
# # Symbiotics from IPHAS

# %%
def sys(spectra):
    datadir = "../symbiotic-IPHAS-spectros/"
    file_ = spectra
    x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
    return x['Wl'], x['Flux']

def plot(spectra, yc):
    x, y = sys(spectra) 
    plt.xlim(xmin=4000,xmax=8000)
    plt.ylim(ymin=0.0,ymax=yc)
    plt.xlabel('Wavelength $(\AA)$', fontsize=15)
    plt.ylabel('Flux', fontsize=15)
    plt.plot(x, y)
    plt.axvline(6825, color='k', linestyle='--', label="6825")
    plt.axvline(7082, color='k', linestyle='-', label="7082")
    plt.axvline(4686, color='r', linestyle='-', label="He II")
    plt.legend()
    plt.savefig("spectrum-DdDm1.jpg")
    gcf().set_size_inches(12,8)

# %%
plot("S18290608_0034572.dat",9e-16)

# %%
plot("S18350183_0146560.dat",9e-15)

# %%
plot("S18444608_0607035.dat",5e-15)

# %%
plot("S18473303_0325543.dat",1e-15)

# %%
plot("S18532358_0849551.dat",1e-15)

# %%
plot("S19092464_0109102.dat",5e-15)

# %%
plot("S19092660_1200446.dat",5e-15)

# %%
plot("S19343606_1631289.dat",5e-15)

# %%
plot("S19460752_2231123.dat",5e-15)

# %%
plot("S20251058_4352330.dat",5e-15)

# %%
plt.clf()

# %% [markdown]
# # Extragalactic SySt

# %%
def sys(spectra):
    datadir = "../syst-NGC205-spectros/"
    file_ = spectra
    x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
    return x['Wl'], x['Flux']

def plot(spectra, yc):
    x, y = sys(spectra) 
    plt.xlim(xmin=4000,xmax=8000)
    plt.ylim(ymin=0.0,ymax=yc)
    plt.xlabel('Wavelength $(\AA)$', fontsize=15)
    plt.ylabel('Flux', fontsize=15)
    plt.plot(x, y)
    plt.axvline(6825, color='k', linestyle='--', label="6825")
    plt.axvline(7082, color='k', linestyle='-', label="7082")
    plt.axvline(4686, color='r', linestyle='-', label="He II")
    plt.legend()
    #plt.savefig("spectrum-DdDm1.jpg")
    gcf().set_size_inches(12,8)

# %%
plot("SySt1_blue_gap+r.dat", 1e-16)

# %%
plot("SySt2_blue_gap+r.dat", 5e-17)

# %%
plot("SySt3_blue_gap+r.dat", 5e-17)

# %%
plot("SySt1.dat", 5e-17)

# %%
plot("IC10_SySt_dist_scaled.dat", 3e-17)
