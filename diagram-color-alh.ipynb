# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/angel/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from __future__ import print_function
import numpy as np
import glob
import json
import matplotlib.pyplot as plt

# %%
pattern = "../*-spectros/*-alh-magnitude.json"
file_list = glob.glob(pattern)

# %%
def filter_mag(p, f1, f2, f3):
    col, col0 = [], []
    if data['id'].endswith(p) or data['id'].startswith(p):
        filter1 = data[f1]
        filter2 = data[f2]
        filter3 = data[f3]
        diff = filter1 - filter2
        diff0 = filter1 - filter3
        col.append(diff)
        col0.append(diff0)
    
    return col, col0

# %%
dx, dy = [], []
dx_c, dy_c = [], []
dx_L2d, dy_L2d = [], []
dx_L3d, dy_L3d = [], []
dx_L4d, dy_L4d = [], []
dx_L5d, dy_L5d = [], []
dx_L2N, dy_L2N = [], []
dx_L3N, dy_L3N = [], []
dx_L4N, dy_L4N = [], []
dx_L5N, dy_L5N = [], []
dx_L2k, dy_L2k = [], []
dx_L3k, dy_L3k = [], []
dx_L4k, dy_L4k = [], []
dx_L5k, dy_L5k = [], []
dx_L2B, dy_L2B = [], []
dx_L3B, dy_L3B = [], []
dx_L4B, dy_L4B = [], []
dx_L5B, dy_L5B = [], []
dx_L2T, dy_L2T = [], []
dx_L3T, dy_L3T = [], []
dx_L4T, dy_L4T = [], []
dx_L5T, dy_L5T = [], []

for file_name in file_list:
    with open(file_name) as f:
        data = json.load(f)
        x, y = filter_mag("HPNe", "F_613_3", "F_644_3", "F_768_3")
        x1, y1 = filter_mag("catB", "F_613_3", "F_644_3", "F_768_3")
        x2, y2 = filter_mag("DdDm1_L2", "F_613_3", "F_644_3", "F_768_3")
        x3, y3 = filter_mag("DdDm1_L3", "F_613_3", "F_644_3", "F_768_3")
        x4, y4 = filter_mag("DdDm1_L4", "F_613_3", "F_644_3", "F_768_3")
        x5, y5 = filter_mag("DdDm1_L5", "F_613_3", "F_644_3", "F_768_3")
        x6, y6 = filter_mag("N2242_L2", "F_613_3", "F_644_3", "F_768_3")
        x7, y7 = filter_mag("N2242_L3", "F_613_3", "F_644_3", "F_768_3")
        x8, y8 = filter_mag("N2242_L4", "F_613_3", "F_644_3", "F_768_3")
        x9, y9 = filter_mag("N2242_L5", "F_613_3", "F_644_3", "F_768_3")
        x10, y10 = filter_mag("K648_L2", "F_613_3", "F_644_3", "F_768_3")
        x11, y11 = filter_mag("K648_L3", "F_613_3", "F_644_3", "F_768_3")
        x12, y12 = filter_mag("K648_L4", "F_613_3", "F_644_3", "F_768_3")
        x13, y13 = filter_mag("K648_L5", "F_613_3", "F_644_3", "F_768_3")
        x14, y14 = filter_mag("BB1_L2", "F_613_3", "F_644_3", "F_768_3")
        x15, y15 = filter_mag("BB1_L3", "F_613_3", "F_644_3", "F_768_3")
        x16, y16 = filter_mag("BB1_L4", "F_613_3", "F_644_3", "F_768_3")
        x17, y17 = filter_mag("BB1_L5", "F_613_3", "F_644_3", "F_768_3")
        x18, y18 = filter_mag("Typ_L2", "F_613_3", "F_644_3", "F_768_3")
        x19, y19 = filter_mag("Typ_L3", "F_613_3", "F_644_3", "F_768_3")
        x20, y20 = filter_mag("Typ_L4", "F_613_3", "F_644_3", "F_768_3")
        x21, y21 = filter_mag("Typ_L5", "F_613_3", "F_644_3", "F_768_3")
      
        for a, b in zip(x, y):
            dx.append(a)
            dy.append(b)
        for a, b in zip(x1, y1):
            dx_c.append(a)
            dy_c.append(b)
        for a, b in zip(x2, y2):
            dx_L2d.append(a)
            dy_L2d.append(b)
        for a, b in zip(x3, y3):
            dx_L3d.append(a)
            dy_L3d.append(b)
        for a, b in zip(x4, y4):
            dx_L4d.append(a)
            dy_L4d.append(b)
        for a, b in zip(x5, y5):
            dx_L5d.append(a)
            dy_L5d.append(b)
        for a, b in zip(x6, y6):
            dx_L2N.append(a)
            dy_L2N.append(b)
        for a, b in zip(x7, y7):
            dx_L3N.append(a)
            dy_L3N.append(b)
        for a, b in zip(x8, y8):
            dx_L4N.append(a)
            dy_L4N.append(b)
        for a, b in zip(x9, y9):
            dx_L5N.append(a)
            dy_L5N.append(b)
        for a, b in zip(x10, y10):
            dx_L2k.append(a)
            dy_L2k.append(b)
        for a, b in zip(x11, y11):
            dx_L3k.append(a)
            dy_L3k.append(b)
        for a, b in zip(x12, y12):
            dx_L4k.append(a)
            dy_L4k.append(b)
        for a, b in zip(x13, y13):
            dx_L5k.append(a)
            dy_L5k.append(b)
        for a, b in zip(x14, y14):
            dx_L2B.append(a)
            dy_L2B.append(b)
        for a, b in zip(x15, y15):
            dx_L3B.append(a)
            dy_L3B.append(b)
        for a, b in zip(x16, y16):
            dx_L4B.append(a)
            dy_L4B.append(b)
        for a, b in zip(x17, y17):
            dx_L5B.append(a)
            dy_L5B.append(b)
        for a, b in zip(x18, y18):
            dx_L2T.append(a)
            dy_L2T.append(b)
        for a, b in zip(x19, y19):
            dx_L3T.append(a)
            dy_L3T.append(b)
        for a, b in zip(x20, y20):
            dx_L4T.append(a)
            dy_L4T.append(b)
        for a, b in zip(x21, y21):
            dx_L5T.append(a)
            dy_L5T.append(b)

# %%
-

# %%
dx, dy = [], []
dx_c, dy_c = [], []
dx_L2d, dy_L2d = [], []
dx_L3d, dy_L3d = [], []
dx_L4d, dy_L4d = [], []
dx_L5d, dy_L5d = [], []
dx_L2N, dy_L2N = [], []
dx_L3N, dy_L3N = [], []
dx_L4N, dy_L4N = [], []
dx_L5N, dy_L5N = [], []
dx_L2k, dy_L2k = [], []
dx_L3k, dy_L3k = [], []
dx_L4k, dy_L4k = [], []
dx_L5k, dy_L5k = [], []
dx_L2B, dy_L2B = [], []
dx_L3B, dy_L3B = [], []
dx_L4B, dy_L4B = [], []
dx_L5B, dy_L5B = [], []
dx_L2T, dy_L2T = [], []
dx_L3T, dy_L3T = [], []
dx_L4T, dy_L4T = [], []
dx_L5T, dy_L5T = [], []

for file_name in file_list:
    with open(file_name) as f:
        data = json.load(f)
        x, y = filter_mag("HPNe", "F_613_3", "F_892_3", "F_427_3")
        x1, y1 = filter_mag("catB", "F_613_3", "F_892_3", "F_427_3")
        x2, y2 = filter_mag("DdDm1_L2", "F_613_3", "F_892_3", "F_427_3")
        x3, y3 = filter_mag("DdDm1_L3", "F_613_3", "F_892_3", "F_427_3")
        x4, y4 = filter_mag("DdDm1_L4", "F_613_3", "F_892_3", "F_427_3")
        x5, y5 = filter_mag("DdDm1_L5", "F_613_3", "F_892_3", "F_427_3")
        x6, y6 = filter_mag("N2242_L2", "F_613_3", "F_892_3", "F_427_3")
        x7, y7 = filter_mag("N2242_L3", "F_613_3", "F_892_3", "F_427_3")
        x8, y8 = filter_mag("N2242_L4", "F_613_3", "F_892_3", "F_427_3")
        x9, y9 = filter_mag("N2242_L5", "F_613_3", "F_892_3", "F_427_3")
        x10, y10 = filter_mag("K648_L2", "F_613_3", "F_892_3", "F_427_3")
        x11, y11 = filter_mag("K648_L3", "F_613_3", "F_892_3", "F_427_3")
        x12, y12 = filter_mag("K648_L4", "F_613_3", "F_892_3", "F_427_3")
        x13, y13 = filter_mag("K648_L5", "F_613_3", "F_892_3", "F_427_3")
        x14, y14 = filter_mag("BB1_L2", "F_613_3", "F_892_3", "F_427_3")
        x15, y15 = filter_mag("BB1_L3", "F_613_3", "F_892_3", "F_427_3")
        x16, y16 = filter_mag("BB1_L4", "F_613_3", "F_892_3", "F_427_3")
        x17, y17 = filter_mag("BB1_L5", "F_613_3", "F_892_3", "F_427_3")
        x18, y18 = filter_mag("Typ_L2", "F_613_3", "F_892_3", "F_427_3")
        x19, y19 = filter_mag("Typ_L3", "F_613_3", "F_892_3", "F_427_3")
        x20, y20 = filter_mag("Typ_L4", "F_613_3", "F_892_3", "F_427_3")
        x21, y21 = filter_mag("Typ_L5", "F_613_3", "F_892_3", "F_427_3")
      
        for a, b in zip(x, y):
            dx.append(a)
            dy.append(b)
        for a, b in zip(x1, y1):
            dx_c.append(a)
            dy_c.append(b)
        for a, b in zip(x2, y2):
            dx_L2d.append(a)
            dy_L2d.append(b)
        for a, b in zip(x3, y3):
            dx_L3d.append(a)
            dy_L3d.append(b)
        for a, b in zip(x4, y4):
            dx_L4d.append(a)
            dy_L4d.append(b)
        for a, b in zip(x5, y5):
            dx_L5d.append(a)
            dy_L5d.append(b)
        for a, b in zip(x6, y6):
            dx_L2N.append(a)
            dy_L2N.append(b)
        for a, b in zip(x7, y7):
            dx_L3N.append(a)
            dy_L3N.append(b)
        for a, b in zip(x8, y8):
            dx_L4N.append(a)
            dy_L4N.append(b)
        for a, b in zip(x9, y9):
            dx_L5N.append(a)
            dy_L5N.append(b)
        for a, b in zip(x10, y10):
            dx_L2k.append(a)
            dy_L2k.append(b)
        for a, b in zip(x11, y11):
            dx_L3k.append(a)
            dy_L3k.append(b)
        for a, b in zip(x12, y12):
            dx_L4k.append(a)
            dy_L4k.append(b)
        for a, b in zip(x13, y13):
            dx_L5k.append(a)
            dy_L5k.append(b)
        for a, b in zip(x14, y14):
            dx_L2B.append(a)
            dy_L2B.append(b)
        for a, b in zip(x15, y15):
            dx_L3B.append(a)
            dy_L3B.append(b)
        for a, b in zip(x16, y16):
            dx_L4B.append(a)
            dy_L4B.append(b)
        for a, b in zip(x17, y17):
            dx_L5B.append(a)
            dy_L5B.append(b)
        for a, b in zip(x18, y18):
            dx_L2T.append(a)
            dy_L2T.append(b)
        for a, b in zip(x19, y19):
            dx_L3T.append(a)
            dy_L3T.append(b)
        for a, b in zip(x20, y20):
            dx_L4T.append(a)
            dy_L4T.append(b)
        for a, b in zip(x21, y21):
            dx_L5T.append(a)
            dy_L5T.append(b) 
            
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.xlabel('F613W - F427W', size = 12)
plt.ylabel('F613W - F892W', size = 12)
ax1.scatter(dy, dx, c='black', alpha=0.8, s=35, label='Halo PNe')
ax1.scatter(dy_c, dx_c, c='purple', alpha=0.8, label='CVV')
ax1.scatter(dy_L2d, dx_L2d,  c= "orange", alpha=0.8, marker='s', label='BB dddm1 L2')
ax1.scatter(dy_L3d, dx_L3d,  c= "orange", alpha=0.8, marker='D', label='BB dddm1 L3')
ax1.scatter(dy_L4d, dx_L4d,  c= "orange", alpha=0.8, marker='^', label='BB dddm1 L4')
ax1.scatter(dy_L5d, dx_L5d,  c= "orange", alpha=0.8, marker='*', label='BB dddm1 L5')
ax1.scatter(dy_L2N, dx_L2N,  c= "green", alpha=0.8, marker='s', label='BB N2242 L2')
ax1.scatter(dy_L3N, dx_L3N,  c= "green", alpha=0.8, marker='D', label='BB N2242 L3')
ax1.scatter(dy_L4N, dx_L4N,  c= "green", alpha=0.8, marker='^', label='BB N2242 L4')
ax1.scatter(dy_L5N, dx_L5N,  c= "green", alpha=0.8, marker='*', label='BB N2242 L5')
ax1.scatter(dy_L2k, dx_L2k,  c= "brown", alpha=0.8, marker='s', label='BB K648 L2')
ax1.scatter(dy_L3k, dx_L3k,  c= "brown", alpha=0.8, marker='D', label='BB K648 L3')
ax1.scatter(dy_L4k, dx_L4k,  c= "brown", alpha=0.8, marker='^', label='BB K648 L4')
ax1.scatter(dy_L5k, dx_L5k,  c= "brown", alpha=0.8, marker='*', label='BB K648 L5')
ax1.scatter(dy_L2B, dx_L2B,  c= "cyan", alpha=0.8, marker='s', label='BB BB1 L2')
ax1.scatter(dy_L3B, dx_L3B,  c= "cyan", alpha=0.8, marker='D', label='BB BB1 L3')
ax1.scatter(dy_L4B, dx_L4B,  c= "cyan", alpha=0.8, marker='^', label='BB BB1 L4')
ax1.scatter(dy_L5B, dx_L5B,  c= "cyan", alpha=0.8, marker='*', label='BB BB1 L5')
ax1.scatter(dy_L2T, dx_L2T,  c= "magenta", alpha=0.8, marker='s', label='BB Typ L2')
ax1.scatter(dy_L3T, dx_L3T,  c= "magenta", alpha=0.8, marker='D', label='BB Typ L3')
ax1.scatter(dy_L4T, dx_L4T,  c= "magenta", alpha=0.8, marker='^', label='BB Typ L4')
ax1.scatter(dy_L5T, dx_L5T,  c= "magenta", alpha=0.8, marker='*', label='BB Typ L5')
ax1.legend(scatterpoints=1, ncol=2, fontsize='x-small')
ax1.grid()
gcf().set_size_inches(12,8)

# %%
dx, dy = [], []
dx_c, dy_c = [], []
dx_L2d, dy_L2d = [], []
dx_L3d, dy_L3d = [], []
dx_L4d, dy_L4d = [], []
dx_L5d, dy_L5d = [], []
dx_L2N, dy_L2N = [], []
dx_L3N, dy_L3N = [], []
dx_L4N, dy_L4N = [], []
dx_L5N, dy_L5N = [], []
dx_L2k, dy_L2k = [], []
dx_L3k, dy_L3k = [], []
dx_L4k, dy_L4k = [], []
dx_L5k, dy_L5k = [], []
dx_L2B, dy_L2B = [], []
dx_L3B, dy_L3B = [], []
dx_L4B, dy_L4B = [], []
dx_L5B, dy_L5B = [], []
dx_L2T, dy_L2T = [], []
dx_L3T, dy_L3T = [], []
dx_L4T, dy_L4T = [], []
dx_L5T, dy_L5T = [], []

for file_name in file_list:
    with open(file_name) as f:
        data = json.load(f)
        x, y = filter_mag("HPNe", "F_613_3", "F_489_3", "F_892_3")
        x1, y1 = filter_mag("catB", "F_613_3", "F_489_3", "F_892_3")
        x2, y2 = filter_mag("DdDm1_L2", "F_613_3", "F_489_3", "F_892_3")
        x3, y3 = filter_mag("DdDm1_L3", "F_613_3", "F_489_3", "F_892_3")
        x4, y4 = filter_mag("DdDm1_L4", "F_613_3", "F_489_3", "F_892_3")
        x5, y5 = filter_mag("DdDm1_L5", "F_613_3", "F_489_3", "F_892_3")
        x6, y6 = filter_mag("N2242_L2", "F_613_3", "F_489_3", "F_892_3")
        x7, y7 = filter_mag("N2242_L3", "F_613_3", "F_489_3", "F_892_3")
        x8, y8 = filter_mag("N2242_L4", "F_613_3", "F_489_3", "F_892_3")
        x9, y9 = filter_mag("N2242_L5", "F_613_3", "F_489_3", "F_892_3")
        x10, y10 = filter_mag("K648_L2", "F_613_3", "F_489_3", "F_892_3")
        x11, y11 = filter_mag("K648_L3", "F_613_3", "F_489_3", "F_892_3")
        x12, y12 = filter_mag("K648_L4", "F_613_3", "F_489_3", "F_892_3")
        x13, y13 = filter_mag("K648_L5", "F_613_3", "F_489_3", "F_892_3")
        x14, y14 = filter_mag("BB1_L2", "F_613_3", "F_489_3", "F_892_3")
        x15, y15 = filter_mag("BB1_L3", "F_613_3", "F_489_3", "F_892_3")
        x16, y16 = filter_mag("BB1_L4", "F_613_3", "F_489_3", "F_892_3")
        x17, y17 = filter_mag("BB1_L5", "F_613_3", "F_489_3", "F_892_3")
        x18, y18 = filter_mag("Typ_L2", "F_613_3", "F_489_3", "F_892_3")
        x19, y19 = filter_mag("Typ_L3", "F_613_3", "F_489_3", "F_892_3")
        x20, y20 = filter_mag("Typ_L4", "F_613_3", "F_489_3", "F_892_3")
        x21, y21 = filter_mag("Typ_L5", "F_613_3", "F_489_3", "F_892_3")
      
        for a, b in zip(x, y):
            dx.append(a)
            dy.append(b)
        for a, b in zip(x1, y1):
            dx_c.append(a)
            dy_c.append(b)
        for a, b in zip(x2, y2):
            dx_L2d.append(a)
            dy_L2d.append(b)
        for a, b in zip(x3, y3):
            dx_L3d.append(a)
            dy_L3d.append(b)
        for a, b in zip(x4, y4):
            dx_L4d.append(a)
            dy_L4d.append(b)
        for a, b in zip(x5, y5):
            dx_L5d.append(a)
            dy_L5d.append(b)
        for a, b in zip(x6, y6):
            dx_L2N.append(a)
            dy_L2N.append(b)
        for a, b in zip(x7, y7):
            dx_L3N.append(a)
            dy_L3N.append(b)
        for a, b in zip(x8, y8):
            dx_L4N.append(a)
            dy_L4N.append(b)
        for a, b in zip(x9, y9):
            dx_L5N.append(a)
            dy_L5N.append(b)
        for a, b in zip(x10, y10):
            dx_L2k.append(a)
            dy_L2k.append(b)
        for a, b in zip(x11, y11):
            dx_L3k.append(a)
            dy_L3k.append(b)
        for a, b in zip(x12, y12):
            dx_L4k.append(a)
            dy_L4k.append(b)
        for a, b in zip(x13, y13):
            dx_L5k.append(a)
            dy_L5k.append(b)
        for a, b in zip(x14, y14):
            dx_L2B.append(a)
            dy_L2B.append(b)
        for a, b in zip(x15, y15):
            dx_L3B.append(a)
            dy_L3B.append(b)
        for a, b in zip(x16, y16):
            dx_L4B.append(a)
            dy_L4B.append(b)
        for a, b in zip(x17, y17):
            dx_L5B.append(a)
            dy_L5B.append(b)
        for a, b in zip(x18, y18):
            dx_L2T.append(a)
            dy_L2T.append(b)
        for a, b in zip(x19, y19):
            dx_L3T.append(a)
            dy_L3T.append(b)
        for a, b in zip(x20, y20):
            dx_L4T.append(a)
            dy_L4T.append(b)
        for a, b in zip(x21, y21):
            dx_L5T.append(a)
            dy_L5T.append(b) 
            
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.xlabel('F613W - F892W', size = 12)
plt.ylabel('F613W - F489W', size = 12)
ax1.scatter(dy, dx, c='black', alpha=0.8, s=35, label='Halo PNe')
ax1.scatter(dy_c, dx_c, c='purple', alpha=0.8, label='CVV')
ax1.scatter(dy_L2d, dx_L2d,  c= "orange", alpha=0.8, marker='s', label='BB dddm1 L2')
ax1.scatter(dy_L3d, dx_L3d,  c= "orange", alpha=0.8, marker='D', label='BB dddm1 L3')
ax1.scatter(dy_L4d, dx_L4d,  c= "orange", alpha=0.8, marker='^', label='BB dddm1 L4')
ax1.scatter(dy_L5d, dx_L5d,  c= "orange", alpha=0.8, marker='*', label='BB dddm1 L5')
ax1.scatter(dy_L2N, dx_L2N,  c= "green", alpha=0.8, marker='s', label='BB N2242 L2')
ax1.scatter(dy_L3N, dx_L3N,  c= "green", alpha=0.8, marker='D', label='BB N2242 L3')
ax1.scatter(dy_L4N, dx_L4N,  c= "green", alpha=0.8, marker='^', label='BB N2242 L4')
ax1.scatter(dy_L5N, dx_L5N,  c= "green", alpha=0.8, marker='*', label='BB N2242 L5')
ax1.scatter(dy_L2k, dx_L2k,  c= "brown", alpha=0.8, marker='s', label='BB K648 L2')
ax1.scatter(dy_L3k, dx_L3k,  c= "brown", alpha=0.8, marker='D', label='BB K648 L3')
ax1.scatter(dy_L4k, dx_L4k,  c= "brown", alpha=0.8, marker='^', label='BB K648 L4')
ax1.scatter(dy_L5k, dx_L5k,  c= "brown", alpha=0.8, marker='*', label='BB K648 L5')
ax1.scatter(dy_L2B, dx_L2B,  c= "cyan", alpha=0.8, marker='s', label='BB BB1 L2')
ax1.scatter(dy_L3B, dx_L3B,  c= "cyan", alpha=0.8, marker='D', label='BB BB1 L3')
ax1.scatter(dy_L4B, dx_L4B,  c= "cyan", alpha=0.8, marker='^', label='BB BB1 L4')
ax1.scatter(dy_L5B, dx_L5B,  c= "cyan", alpha=0.8, marker='*', label='BB BB1 L5')
ax1.scatter(dy_L2T, dx_L2T,  c= "magenta", alpha=0.8, marker='s', label='BB Typ L2')
ax1.scatter(dy_L3T, dx_L3T,  c= "magenta", alpha=0.8, marker='D', label='BB Typ L3')
ax1.scatter(dy_L4T, dx_L4T,  c= "magenta", alpha=0.8, marker='^', label='BB Typ L4')
ax1.scatter(dy_L5T, dx_L5T,  c= "magenta", alpha=0.8, marker='*', label='BB Typ L5')
ax1.legend(scatterpoints=1, ncol=2, fontsize='x-small')
ax1.grid()
gcf().set_size_inches(12,8)

# %%
dx, dy = [], []
dx_c, dy_c = [], []
dx_L2d, dy_L2d = [], []
dx_L3d, dy_L3d = [], []
dx_L4d, dy_L4d = [], []
dx_L5d, dy_L5d = [], []
dx_L2N, dy_L2N = [], []
dx_L3N, dy_L3N = [], []
dx_L4N, dy_L4N = [], []
dx_L5N, dy_L5N = [], []
dx_L2k, dy_L2k = [], []
dx_L3k, dy_L3k = [], []
dx_L4k, dy_L4k = [], []
dx_L5k, dy_L5k = [], []
dx_L2B, dy_L2B = [], []
dx_L3B, dy_L3B = [], []
dx_L4B, dy_L4B = [], []
dx_L5B, dy_L5B = [], []
dx_L2T, dy_L2T = [], []
dx_L3T, dy_L3T = [], []
dx_L4T, dy_L4T = [], []
dx_L5T, dy_L5T = [], []

for file_name in file_list:
    with open(file_name) as f:
        data = json.load(f)
        x, y = filter_mag("HPNe", "F_613_3", "F_396_3", "F_892_3")
        x1, y1 = filter_mag("catB", "F_613_3", "F_396_3", "F_892_3")
        x2, y2 = filter_mag("DdDm1_L2", "F_613_3", "F_396_3", "F_892_3")
        x3, y3 = filter_mag("DdDm1_L3", "F_613_3", "F_396_3", "F_892_3")
        x4, y4 = filter_mag("DdDm1_L4", "F_613_3", "F_396_3", "F_892_3")
        x5, y5 = filter_mag("DdDm1_L5", "F_613_3", "F_396_3", "F_892_3")
        x6, y6 = filter_mag("N2242_L2", "F_613_3", "F_396_3", "F_892_3")
        x7, y7 = filter_mag("N2242_L3", "F_613_3", "F_396_3", "F_892_3")
        x8, y8 = filter_mag("N2242_L4", "F_613_3", "F_396_3", "F_892_3")
        x9, y9 = filter_mag("N2242_L5", "F_613_3", "F_396_3", "F_892_3")
        x10, y10 = filter_mag("K648_L2", "F_613_3", "F_396_3", "F_892_3")
        x11, y11 = filter_mag("K648_L3", "F_613_3", "F_396_3", "F_892_3")
        x12, y12 = filter_mag("K648_L4", "F_613_3", "F_396_3", "F_892_3")
        x13, y13 = filter_mag("K648_L5", "F_613_3", "F_396_3", "F_892_3")
        x14, y14 = filter_mag("BB1_L2", "F_613_3", "F_396_3", "F_892_3")
        x15, y15 = filter_mag("BB1_L3", "F_613_3", "F_396_3", "F_892_3")
        x16, y16 = filter_mag("BB1_L4", "F_613_3", "F_396_3", "F_892_3")
        x17, y17 = filter_mag("BB1_L5", "F_613_3", "F_396_3", "F_892_3")
        x18, y18 = filter_mag("Typ_L2", "F_613_3", "F_396_3", "F_892_3")
        x19, y19 = filter_mag("Typ_L3", "F_613_3", "F_396_3", "F_892_3")
        x20, y20 = filter_mag("Typ_L4", "F_613_3", "F_396_3", "F_892_3")
        x21, y21 = filter_mag("Typ_L5", "F_613_3", "F_396_3", "F_892_3")
      
        for a, b in zip(x, y):
            dx.append(a)
            dy.append(b)
        for a, b in zip(x1, y1):
            dx_c.append(a)
            dy_c.append(b)
        for a, b in zip(x2, y2):
            dx_L2d.append(a)
            dy_L2d.append(b)
        for a, b in zip(x3, y3):
            dx_L3d.append(a)
            dy_L3d.append(b)
        for a, b in zip(x4, y4):
            dx_L4d.append(a)
            dy_L4d.append(b)
        for a, b in zip(x5, y5):
            dx_L5d.append(a)
            dy_L5d.append(b)
        for a, b in zip(x6, y6):
            dx_L2N.append(a)
            dy_L2N.append(b)
        for a, b in zip(x7, y7):
            dx_L3N.append(a)
            dy_L3N.append(b)
        for a, b in zip(x8, y8):
            dx_L4N.append(a)
            dy_L4N.append(b)
        for a, b in zip(x9, y9):
            dx_L5N.append(a)
            dy_L5N.append(b)
        for a, b in zip(x10, y10):
            dx_L2k.append(a)
            dy_L2k.append(b)
        for a, b in zip(x11, y11):
            dx_L3k.append(a)
            dy_L3k.append(b)
        for a, b in zip(x12, y12):
            dx_L4k.append(a)
            dy_L4k.append(b)
        for a, b in zip(x13, y13):
            dx_L5k.append(a)
            dy_L5k.append(b)
        for a, b in zip(x14, y14):
            dx_L2B.append(a)
            dy_L2B.append(b)
        for a, b in zip(x15, y15):
            dx_L3B.append(a)
            dy_L3B.append(b)
        for a, b in zip(x16, y16):
            dx_L4B.append(a)
            dy_L4B.append(b)
        for a, b in zip(x17, y17):
            dx_L5B.append(a)
            dy_L5B.append(b)
        for a, b in zip(x18, y18):
            dx_L2T.append(a)
            dy_L2T.append(b)
        for a, b in zip(x19, y19):
            dx_L3T.append(a)
            dy_L3T.append(b)
        for a, b in zip(x20, y20):
            dx_L4T.append(a)
            dy_L4T.append(b)
        for a, b in zip(x21, y21):
            dx_L5T.append(a)
            dy_L5T.append(b) 
            
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.xlabel('F613W - F892W', size = 12)
plt.ylabel('F613W - F3963W', size = 12)
ax1.scatter(dy, dx, c='black', alpha=0.8, s=35, label='Halo PNe')
ax1.scatter(dy_c, dx_c, c='purple', alpha=0.8, label='CVV')
ax1.scatter(dy_L2d, dx_L2d,  c= "orange", alpha=0.8, marker='s', label='BB dddm1 L2')
ax1.scatter(dy_L3d, dx_L3d,  c= "orange", alpha=0.8, marker='D', label='BB dddm1 L3')
ax1.scatter(dy_L4d, dx_L4d,  c= "orange", alpha=0.8, marker='^', label='BB dddm1 L4')
ax1.scatter(dy_L5d, dx_L5d,  c= "orange", alpha=0.8, marker='*', label='BB dddm1 L5')
ax1.scatter(dy_L2N, dx_L2N,  c= "green", alpha=0.8, marker='s', label='BB N2242 L2')
ax1.scatter(dy_L3N, dx_L3N,  c= "green", alpha=0.8, marker='D', label='BB N2242 L3')
ax1.scatter(dy_L4N, dx_L4N,  c= "green", alpha=0.8, marker='^', label='BB N2242 L4')
ax1.scatter(dy_L5N, dx_L5N,  c= "green", alpha=0.8, marker='*', label='BB N2242 L5')
ax1.scatter(dy_L2k, dx_L2k,  c= "brown", alpha=0.8, marker='s', label='BB K648 L2')
ax1.scatter(dy_L3k, dx_L3k,  c= "brown", alpha=0.8, marker='D', label='BB K648 L3')
ax1.scatter(dy_L4k, dx_L4k,  c= "brown", alpha=0.8, marker='^', label='BB K648 L4')
ax1.scatter(dy_L5k, dx_L5k,  c= "brown", alpha=0.8, marker='*', label='BB K648 L5')
ax1.scatter(dy_L2B, dx_L2B,  c= "cyan", alpha=0.8, marker='s', label='BB BB1 L2')
ax1.scatter(dy_L3B, dx_L3B,  c= "cyan", alpha=0.8, marker='D', label='BB BB1 L3')
ax1.scatter(dy_L4B, dx_L4B,  c= "cyan", alpha=0.8, marker='^', label='BB BB1 L4')
ax1.scatter(dy_L5B, dx_L5B,  c= "cyan", alpha=0.8, marker='*', label='BB BB1 L5')
ax1.scatter(dy_L2T, dx_L2T,  c= "magenta", alpha=0.8, marker='s', label='BB Typ L2')
ax1.scatter(dy_L3T, dx_L3T,  c= "magenta", alpha=0.8, marker='D', label='BB Typ L3')
ax1.scatter(dy_L4T, dx_L4T,  c= "magenta", alpha=0.8, marker='^', label='BB Typ L4')
ax1.scatter(dy_L5T, dx_L5T,  c= "magenta", alpha=0.8, marker='*', label='BB Typ L5')
ax1.legend(scatterpoints=1, ncol=2, fontsize='x-small')
ax1.grid()
gcf().set_size_inches(12,8)
