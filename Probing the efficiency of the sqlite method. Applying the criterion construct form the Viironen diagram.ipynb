# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/lgutierrez/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['table']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt
import pandas as pd
from astropy.table import Table

# %%
#datadir = "../SPLUS-DR2/auto_dr2"
#file_ = "SPLUS_SPLUS_iDR2_HalphaVii-Error-Lim.tab"
#file_1 = "SPLUS_HYDRA_iDR2_HalphaVii.tab"

# %%
#data = Table.read(os.path.join(datadir, file_), format="ascii.tab")
#data1 = Table.read(os.path.join(datadir, file_1), format="ascii.tab")

# %%
#len(data)

# %%
#data1.shape

# %%
#plt.xlim(-3.7, 3.5)
#plt.ylim(-1.1, 2.8)
#plt.plot((data1["r_auto"] - data1["i_auto"]), (data1["r_auto"] - data1["F660_auto"]), "o")
#plt.plot((data["r_auto"] - data["i_auto"]), (data["r_auto"] - data["F660_auto"]), "o")
#x = np.linspace(-5, 5)
#y =  0.108*x + 0.5
#plt.plot(x, y, "-")
#gcf().set_size_inches(10,8)

# %%
from astropy.io import fits
import seaborn as sn
import pandas as pd
sn.set_context("poster")

# %%
datadir1 = "../DR3-SPLUS/HYDRA/"
fitsfile = "HalphaEmit_hydra_3error_pstotal.fits"

# %%
hdu = fits.open(os.path.join(datadir1, fitsfile))

# %%
table = hdu[1].data
len(table)
# Out:
# 3232

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.legend(ncol=2).set_title(r"H$\alpha$ emitters")
ax.set(xlim=[-3.7, 3.7], ylim=[-2.4, 2.8])
ax.set_aspect("equal")
ax.set(xlabel=r"$r - i$", ylabel=r"$r - F660$")
#plt.plot((data1["r_auto"] - data1["i_auto"]), (data1["r_auto"] - data1["F660_auto"]), "o")
ax.scatter((table["R_PStotal"] - table["I_PStotal"]), (table["R_PStotal"] - table["F660_PStotal"]), c=sn.xkcd_rgb['green'], 
                  alpha=0.9, marker='o', s=200, zorder=3, edgecolor='w', cmap="Blues")
x = np.linspace(-15.0, 15.0, 2000)
y = 0.15*x + 0.53
ax.plot(x, y, c="k", lw=0.9)
textbb = {"facecolor": "white", "alpha": 0.7, "edgecolor": "none"}
textpars = {'ha': 'center', 'va': 'center', 'bbox': textbb, 'fontsize': 'small'}
ax.text(-2.3, 0.19, r'$0.15*(r - i) + 0.53$', rotation=8.8, rotation_mode='anchor', **textpars)
# Out:
# No handles with labels found to put in legend.
# Text(-2.3, 0.19, '$0.15*(r - i) + 0.53$')
