# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

# %%
datadir = "../WD_SPLUS_dr2/"
fitsfile = "SPLUSidr2_SPLUS_WD_gaia.fits"

# %%
hdu = fits.open(os.path.join(datadir, fitsfile))

# %%
G = hdu[1].data["Gmag_2"]
BPmag = hdu[1].data["BPmag"]
RPmag = hdu[1].data["RPmag"]
hdu[1].data
# Out:
# FITS_rec([('SPLUS-n01s37', 'SPLUS.SPLUS-n01s37.0000016775.griz', 199.35306,   0.04381, 7759.066, 5787.242, 183, 406.69, 0, 2.63, 0.96, 12.76, 2.47, 2.33, -85.29, 1.332, 1.04, 12, 12, 12,  15.43, 0.02, 248.6,  14.98, 0.02, 292.9,  15.33, 0.02, 260.4, 15.53, 0.02, 171.9, 15.11, 0.02, 197.2, 15.43, 0.02, 179.3, 15.62, 0.02, 116.9, 15.18, 0.02, 131.4, 15.52, 0.02, 121.9, 15.7 , 0.02, 119.5, 15.14, 0.02, 141. , 15.56, 0.02, 127.1, 15.74, 0.02, 127.8, 15.34, 0.02, 139. , 15.64, 0.02, 132.9, 15.98, 0.02, 268.3, 15.65, 0.02, 286.6, 15.9 , 0.02, 276.3, 16.02, 0.02, 138.2, 15.71, 0.02, 140.4, 15.95, 0.02, 141.8, 16.41, 0.02, 245.4, 16.16, 0.02, 228. , 16.35, 0.02, 248.7, 16.64, 0.02, 176.9, 16.25, 0.02, 173.6, 16.54, 0.02, 183.2, 16.87, 0.02, 172.8, 16.54, 0.02, 136.5, 16.79, 0.02, 174.1, 17.11, 0.02,  80.3, 16.77, 0.02, 54. , 17.02, 0.02,  79.6, 17.21, 0.02,  96. , 16.85, 0.02,  60.5, 17.11, 0.02,  94.5,  28252, '*', 'WDJ131724.75+000237.38', 'Gaia DR2 3687524749863026304', 368752474986302630
# ...

# %%
color = BPmag - RPmag
len(color)
# Out:
# 14

# %%
plt.xlim(-1.0, 3.5)
#plt.ylim(0, 16)
#plt.plot((data1["r_auto"] - data1["i_auto"]), (data1["r_auto"] - data1["F660_auto"]), "o")
plt.xlabel("GBP - GRB")
plt.ylabel("Gabs[mag]")
plt.plot(color, G, "o")
gcf().set_size_inches(10,8)
