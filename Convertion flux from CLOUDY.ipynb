# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt

# %%
datadir = "../BB_N2242_L3-300-spectros/"
file_ = "N2242_L3_T100_output_SED_D100-E0.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
datadir = "../BB_N2242_L3-300-spectros/"
file_ = "N2242_L3_T100_output_SED.dat.tere_E0"
x1 = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
datadir = "../BB_N2242_L3-300-spectros/"
file_ = "N2242_L3_T100_output_SED_D5-E0.dat"
x2 = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
datadir = "../BB_N2242_L3-300-spectros/"
file_ = "N2242_L3_T100_output_SED_D15-E0.dat"
x3 = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
datadir = "../BB_N2242_L3-300-spectros/"
file_ = "N2242_L3_T100_output_SED_D20-E0.dat"
x4 = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
#plt.xlim(xmin=3500,xmax=9900)
#plt.ylim(ymin=0.0,ymax=9e-13)
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.plot(x['Wl'], x['Flux'], label="10kpc Luis")
plt.plot(x1['Wl'], x1['Flux']/0.12, label="10kpc Col")
plt.plot(x2['Wl'], x2['Flux'], label="5kpc")
plt.plot(x3['Wl'], x3['Flux'], label="15kpc")
plt.plot(x4['Wl'], x4['Flux'], label="20kpc")
plt.yscale("log")
plt.legend()
#plt.savefig("spectrum-DdDm1.jpg")
gcf().set_size_inches(12,8)

# %%
datadir = "../BB_BB1_L2-300-spectros/"
file_ = "BB1_L2_T70_output_SED_D100-E0.dat"
x = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))
datadir = "../BB_BB1_L2-300-spectros/"
file_ = "BB1_L2_T70_output_SED.dat.tere_E0"
x1 = np.loadtxt(os.path.join(datadir, file_), delimiter = None, skiprows = 0, usecols = None, 
               unpack = False, dtype = np.dtype([('Wl', '|f8'), ('Flux', 'f8')]))

# %%
plt.xlabel('Wavelength $(\AA)$', fontsize=15)
plt.ylabel('Log Flux', fontsize=15)
plt.plot(x['Wl'], x['Flux'], label="10kpc Luis")
plt.plot(x1['Wl'], x1['Flux'], label="10kpc Denise")
plt.yscale("log")
plt.legend()
plt.savefig("BB1_L2_T70_output_SED-D10.pdf")
gcf().set_size_inches(12,8)
