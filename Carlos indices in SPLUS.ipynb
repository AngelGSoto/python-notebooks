# %% [markdown]
# # Color indices
# Autor: Luis Angel

# %%
# %pylab inline
import numpy as np
import glob
import json
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pattern = "../*-spectros/*-JPAS15-magnitude.json"
file_list = glob.glob(pattern)

def filter_mag(e, s, f1, f2, f3, f4, f5, f6, f7):
    col, col0, col1 = [], [], []
    if data['id'].endswith(e):
        if data['id'].startswith(str(s)):
            filter1 = data[f1]
            filter2 = data[f2]
            filter3 = data[f3]
            filter4 = data[f4]
            filter5 = data[f5]
            filter6 = data[f6]
            filter7 = data[f7]
            A1 = ((filter2-filter3) - (filter3-filter4))/filter5 + (filter6-filter7)
            B1 = ((filter1-filter2) - (filter2-filter3))/filter5
            C1 = filter3-filter4
            col.append(A1)
            col0.append(B1)
            col1.append(C1)
    
    return col, col0, col1

# %%
def plot_mag(f1, f2, f3, f4, f5, f6, f7):
    x, y, z = filter_mag("HPNe", "", f1, f2, f3, f4, f5, f6, f7)
    x1, y1, z1 = filter_mag("CV", "", f1, f2, f3, f4, f5, f6, f7)
    x2, y2, z2 = filter_mag("E00", "DdDm1_L2", f1, f2, f3, f4, f5, f6, f7)
    x3, y3, z3 = filter_mag("E00", "DdDm1_L3", f1, f2, f3, f4, f5, f6, f7)
    x4, y4, z4 = filter_mag("E00", "DdDm1_L4", f1, f2, f3, f4, f5, f6, f7)
    x5, y5, z5 = filter_mag("E00", "DdDm1_L5", f1, f2, f3, f4, f5, f6, f7)
    x6, y6, z6 = filter_mag("E00", "N2242_L2", f1, f2, f3, f4, f5, f6, f7)
    x7, y7, z7 = filter_mag("E00", "N2242_L3", f1, f2, f3, f4, f5, f6, f7)
    x8, y8, z8 = filter_mag("E00", "N2242_L4", f1, f2, f3, f4, f5, f6, f7)
    x9, y9, z9 = filter_mag("E00", "N2242_L5", f1, f2, f3, f4, f5, f6, f7)
    x10, y10, z10 = filter_mag("E00", "K648_L2", f1, f2, f3, f4, f5, f6, f7)
    x11, y11, z11 = filter_mag("E00", "K648_L3", f1, f2, f3, f4, f5, f6, f7)
    x12, y12, z12 = filter_mag("E00", "K648_L4", f1, f2, f3, f4, f5, f6, f7)
    x13, y13, z13 = filter_mag("E00", "K648_L5", f1, f2, f3, f4, f5, f6, f7)
    x14, y14, z14 = filter_mag("E00", "BB1_L2", f1, f2, f3, f4, f5, f6, f7)
    x15, y15, z15 = filter_mag("E00", "BB1_L3", f1, f2, f3, f4, f5, f6, f7)
    x16, y16, z16 = filter_mag("E00", "BB1_L4", f1, f2, f3, f4, f5, f6, f7)
    x17, y17, z17 = filter_mag("E00", "BB1_L5", f1, f2, f3, f4, f5, f6, f7)
    x18, y18, z18 = filter_mag("E00", "Typ_L2", f1, f2, f3, f4, f5, f6, f7)
    x19, y19, z19 = filter_mag("E00", "Typ_L3", f1, f2, f3, f4, f5, f6, f7)
    x20, y20, z20 = filter_mag("E00", "Typ_L4", f1, f2, f3, f4, f5, f6, f7)
    x21, y21, z21 = filter_mag("E00", "Typ_L5", f1, f2, f3, f4, f5, f6, f7)
    x22, y22, z22 = filter_mag("E01", "DdDm1_L2", f1, f2, f3, f4, f5, f6, f7)
    x23, y23, z23 = filter_mag("E01", "DdDm1_L3", f1, f2, f3, f4, f5, f6, f7)
    x24, y24, z24 = filter_mag("E01", "DdDm1_L4", f1, f2, f3, f4, f5, f6, f7)
    x25, y25, z25 = filter_mag("E01", "DdDm1_L5", f1, f2, f3, f4, f5, f6, f7)
    x26, y26, z26 = filter_mag("E01", "N2242_L2", f1, f2, f3, f4, f5, f6, f7)
    x27, y27, z27 = filter_mag("E01", "N2242_L3", f1, f2, f3, f4, f5, f6, f7)
    x28, y28, z28 = filter_mag("E01", "N2242_L4", f1, f2, f3, f4, f5, f6, f7)
    x29, y29, z29 = filter_mag("E01", "N2242_L5", f1, f2, f3, f4, f5, f6, f7)
    x30, y30, z30 = filter_mag("E01", "K648_L2", f1, f2, f3, f4, f5, f6, f7)
    x31, y31, z31 = filter_mag("E01", "K648_L3", f1, f2, f3, f4, f5, f6, f7)
    x32, y32, z32 = filter_mag("E01", "K648_L4", f1, f2, f3, f4, f5, f6, f7)
    x33, y33, z33 = filter_mag("E01", "K648_L5", f1, f2, f3, f4, f5, f6, f7)
    x34, y34, z34 = filter_mag("E01", "BB1_L2", f1, f2, f3, f4, f5, f6, f7)
    x35, y35, z35 = filter_mag("E01", "BB1_L3", f1, f2, f3, f4, f5, f6, f7)
    x36, y36, z36 = filter_mag("E01", "BB1_L4", f1, f2, f3, f4, f5, f6, f7)
    x37, y37, z37 = filter_mag("E01", "BB1_L5", f1, f2, f3, f4, f5, f6, f7)
    x38, y38, z38 = filter_mag("E01", "Typ_L2", f1, f2, f3, f4, f5, f6, f7)
    x39, y39, z39 = filter_mag("E01", "Typ_L3", f1, f2, f3, f4, f5, f6, f7)
    x40, y40, z40 = filter_mag("E01", "Typ_L4", f1, f2, f3, f4, f5, f6, f7)
    x41, y41, z41 = filter_mag("E01", "Typ_L5", f1, f2, f3, f4, f5, f6, f7)
    x42, y42, z42 = filter_mag("E02", "DdDm1_L2", f1, f2, f3, f4, f5, f6, f7)
    x43, y43, z43 = filter_mag("E02", "DdDm1_L3", f1, f2, f3, f4, f5, f6, f7)
    x44, y44, z44 = filter_mag("E02", "DdDm1_L4", f1, f2, f3, f4, f5, f6, f7)
    x45, y45, z45 = filter_mag("E02", "DdDm1_L5", f1, f2, f3, f4, f5, f6, f7)
    x46, y46, z46 = filter_mag("E02", "N2242_L2", f1, f2, f3, f4, f5, f6, f7)
    x47, y47, z47 = filter_mag("E02", "N2242_L3", f1, f2, f3, f4, f5, f6, f7)
    x48, y48, z48 = filter_mag("E02", "N2242_L4", f1, f2, f3, f4, f5, f6, f7)
    x49, y49, z49 = filter_mag("E02", "N2242_L5", f1, f2, f3, f4, f5, f6, f7)
    x50, y50, z50 = filter_mag("E02", "K648_L2", f1, f2, f3, f4, f5, f6, f7)
    x51, y51, z51 = filter_mag("E02", "K648_L3", f1, f2, f3, f4, f5, f6, f7)
    x52, y52, z52 = filter_mag("E02", "K648_L4", f1, f2, f3, f4, f5, f6, f7)
    x53, y53, z53 = filter_mag("E02", "K648_L5", f1, f2, f3, f4, f5, f6, f7)
    x54, y54, z54 = filter_mag("E02", "BB1_L2", f1, f2, f3, f4, f5, f6, f7)
    x55, y55, z55 = filter_mag("E02", "BB1_L3", f1, f2, f3, f4, f5, f6, f7)
    x56, y56, z56 = filter_mag("E02", "BB1_L4", f1, f2, f3, f4, f5, f6, f7)
    x57, y57, z57 = filter_mag("E02", "BB1_L5", f1, f2, f3, f4, f5, f6, f7)
    x58, y58, z58 = filter_mag("E02", "Typ_L2", f1, f2, f3, f4, f5, f6, f7)
    x59, y59, z59 = filter_mag("E02", "Typ_L3", f1, f2, f3, f4, f5, f6, f7)
    x60, y60, z60 = filter_mag("E02", "Typ_L4", f1, f2, f3, f4, f5, f6, f7)
    x61, y61, z61 = filter_mag("E02", "Typ_L5", f1, f2, f3, f4, f5, f6, f7)
    x62, y62, z62 = filter_mag("DPNe", "", f1, f2, f3, f4, f5, f6, f7)
    x63, y63, z63 = filter_mag("QSOs-hz", "", f1, f2, f3, f4, f5, f6, f7)
    x64, y64, z64 = filter_mag("QSOs-010", "",  f1, f2, f3, f4, f5, f6, f7)
    x65, y65, z65 = filter_mag("QSOs-101", "", f1, f2, f3, f4, f5, f6, f7)
    x66, y66, z66 = filter_mag("QSOs-201", "", f1, f2, f3, f4, f5, f6, f7)
    x67, y67, z67 = filter_mag("QSOs-301", "", f1, f2, f3, f4, f5, f6, f7)
    x68, y68, z68 = filter_mag("QSOs-401", "", f1, f2, f3, f4, f5, f6, f7)
    x69, y69, z69 = filter_mag("-SFGs", "", f1, f2, f3, f4, f5, f6, f7)
    x70, y70, z70 = filter_mag("-sys", "", f1, f2, f3, f4, f5, f6, f7)
    x71, y71, z71 = filter_mag("-sys-IPHAS", "", f1, f2, f3, f4, f5, f6, f7) 
    x72, y72, z72 = filter_mag("-ExtHII", "", f1, f2, f3, f4, f5, f6, f7)
    x73, y73, z73 = filter_mag("-sys-Ext", "", f1, f2, f3, f4, f5, f6, f7)
    x74, y74, z74 = filter_mag("-survey", "", f1, f2, f3, f4, f5, f6, f7)
    x75, y75, z75 = filter_mag("-SNR", "", f1, f2, f3, f4, f5, f6, f7)
    for a, b, c in zip(x, y, z):
        A1[0].append(a)
        B1[0].append(b)
        C1[0].append(c)
    for a, b, c in zip(x1, y1, z1):
        A1[1].append(a)
        B1[1].append(b)
        C1[1].append(c)
    for a, b, c in zip(x2, y2, z2):
        A1[2].append(a)
        B1[2].append(b)
        C1[2].append(c)
    for a, b, c in zip(x3, y3, z3):
        A1[3].append(a)
        B1[3].append(b)
        C1[3].append(c)
    for a, b, c in zip(x4, y4, z4):
        A1[4].append(a)
        B1[4].append(b)
        C1[4].append(c)
    for a, b, c in zip(x5, y5, z5):
        A1[5].append(a)
        B1[5].append(b)
        C1[5].append(c)
    for a, b, c in zip(x6, y6, z6):
        A1[6].append(a)
        B1[6].append(b)
        C1[6].append(c)
    for a, b, c in zip(x7, y7, z7):
        A1[7].append(a)
        B1[7].append(b)
        C1[7].append(c)
    for a, b, c in zip(x8, y8, z8):
        A1[8].append(a)
        B1[8].append(b)
        C1[8].append(c)
    for a, b, c in zip(x9, y9, z9):
        A1[9].append(a)
        B1[9].append(b)
        C1[9].append(c)
    for a, b, c in zip(x10, y10, z10):
        A1[10].append(a)
        B1[10].append(b)
        C1[10].append(c)
    for a, b, c in zip(x11, y11, z11):
        A1[11].append(a)
        B1[11].append(b)
        C1[11].append(c)
    for a, b, c in zip(x12, y12, z12):
        A1[12].append(a)
        B1[12].append(b)
        C1[12].append(c)
    for a, b, c in zip(x13, y13, z13):
        A1[13].append(a)
        B1[13].append(b)
        C1[13].append(c)
    for a, b, c in zip(x14, y14, z14):
        A1[14].append(a)
        B1[14].append(b)
        C1[14].append(c)
    for a, b, c in zip(x15, y15, z15):
        A1[15].append(a)
        B1[15].append(b)
        C1[15].append(c)
    for a, b, c in zip(x16, y16, z16):
        A1[16].append(a)
        B1[16].append(b)
        C1[16].append(c)
    for a, b, c in zip(x17, y17, z17):
        A1[17].append(a)
        B1[17].append(b)
        C1[17].append(c)
    for a, b, c in zip(x18, y18, z18):
        A1[18].append(a)
        B1[18].append(b)
        C1[18].append(c)
    for a, b, c in zip(x19, y19, z19):
        A1[19].append(a)
        B1[19].append(b)
        C1[19].append(c)
    for a, b, c in zip(x20, y20, z20):
        A1[20].append(a)
        B1[20].append(b)
        C1[20].append(c)
    for a, b, c in zip(x21, y21, z21):
        A1[21].append(a)
        B1[21].append(b)
        C1[21].append(c)
    for a, b, c in zip(x22, y22, z22):
        A1[22].append(a)
        B1[22].append(b)
        C1[22].append(c)
    for a, b, c in zip(x23, y23, z23):
        A1[23].append(a)
        B1[23].append(b)
        C1[23].append(c)
    for a, b, c in zip(x24, y24, z24):
        A1[24].append(a)
        B1[24].append(b)
        C1[24].append(c)
    for a, b, c in zip(x25, y25, z25):
        A1[25].append(a)
        B1[25].append(b)
        C1[25].append(c)
    for a, b, c in zip(x26, y26, z26):
        A1[26].append(a)
        B1[26].append(b)
        C1[26].append(c)
    for a, b, c in zip(x27, y27, z27):
        A1[27].append(a)
        B1[27].append(b)
        C1[27].append(c)
    for a, b, c in zip(x28, y28, z28):
        A1[28].append(a)
        B1[28].append(b)
        C1[28].append(c)
    for a, b, c in zip(x29, y29, z29):
        A1[29].append(a)
        B1[29].append(b)
        C1[29].append(c)
    for a, b, c in zip(x30, y30, z30):
        A1[30].append(a)
        B1[30].append(b)
        C1[30].append(c)
    for a, b, c in zip(x31, y31, z31):
        A1[31].append(a)
        B1[31].append(b)
        C1[31].append(c)
    for a, b, c in zip(x32, y32, z32):
        A1[32].append(a)
        B1[32].append(b)
        C1[32].append(c)
    for a, b, c in zip(x33, y33, z33):
        A1[33].append(a)
        B1[33].append(b)
        C1[33].append(c)
    for a, b, c in zip(x34, y34, z34):
        A1[34].append(a)
        B1[34].append(b)
        C1[34].append(c)
    for a, b, c in zip(x35, y35, z35):
        A1[35].append(a)
        B1[35].append(b)
        C1[35].append(c)
    for a, b, c in zip(x36, y36, z36):
        A1[36].append(a)
        B1[36].append(b)
        C1[36].append(c)
    for a, b, c in zip(x37, y37, z37):
        A1[37].append(a)
        B1[37].append(b)
        C1[37].append(c)
    for a, b, c in zip(x38, y38, z38):
        A1[38].append(a)
        B1[38].append(b)
        C1[38].append(c)
    for a, b, c in zip(x39, y39, z39):
        A1[39].append(a)
        B1[39].append(b)
        C1[39].append(c)
    for a, b, c in zip(x40, y40, z40):
        A1[40].append(a)
        B1[40].append(b)
        C1[40].append(c)
    for a, b, c in zip(x41, y41, z41):
        A1[41].append(a)
        B1[41].append(b)
        C1[41].append(c)
    for a, b, c in zip(x42, y42, z42):
        A1[42].append(a)
        B1[42].append(b)
        C1[42].append(c)
    for a, b, c in zip(x43, y43, z43):
        A1[43].append(a)
        B1[43].append(b)
        C1[43].append(c)
    for a, b, c in zip(x44, y44, z44):
        A1[44].append(a)
        B1[44].append(b)
        C1[44].append(c)
    for a, b, c in zip(x45, y45, z45):
        A1[45].append(a)
        B1[45].append(b)
        C1[45].append(c)
    for a, b, c in zip(x46, y46, z46):
        A1[46].append(a)
        B1[46].append(b)
        C1[46].append(c)
    for a, b, c in zip(x47, y47, z47):
        A1[47].append(a)
        B1[47].append(b)
        C1[47].append(c)
    for a, b, c in zip(x48, y48, z48):
        A1[48].append(a)
        B1[48].append(b)
        C1[48].append(c)
    for a, b, c in zip(x49, y49, z49):
        A1[49].append(a)
        B1[49].append(b)
        C1[49].append(c)
    for a, b, c in zip(x50, y50, z50):
        A1[50].append(a)
        B1[50].append(b)
        C1[50].append(c)
    for a, b, c in zip(x51, y51, z51):
        A1[51].append(a)
        B1[51].append(b)
        C1[51].append(c)
    for a, b, c in zip(x52, y52, z52):
        A1[52].append(a)
        B1[52].append(b)
        C1[52].append(c)
    for a, b, c in zip(x53, y53, z53):
        A1[53].append(a)
        B1[53].append(b)
        C1[53].append(c)
    for a, b, c in zip(x54, y54, z54):
        A1[54].append(a)
        B1[54].append(b)
        C1[54].append(c)
    for a, b, c in zip(x55, y55, z55):
        A1[55].append(a)
        B1[55].append(b)
        C1[55].append(c)
    for a, b, c in zip(x56, y56, z56):
        A1[56].append(a)
        B1[56].append(b)
        C1[56].append(c)
    for a, b, c in zip(x57, y57, z57):
        A1[57].append(a)
        B1[57].append(b)
        C1[57].append(c)
    for a, b, c in zip(x58, y58, z58):
        A1[58].append(a)
        B1[58].append(b)
        C1[58].append(c)
    for a, b, c in zip(x59, y59, z59):
        A1[59].append(a)
        B1[59].append(b)
        C1[59].append(c)
    for a, b, c in zip(x60, y60, z60):
        A1[60].append(a)
        B1[60].append(b)
        C1[60].append(c)
    for a, b, c in zip(x61, y61, z61):
        A1[61].append(a)
        B1[61].append(b)
        C1[61].append(c)
    for a, b, c in zip(x62, y62, z62):
        A1[62].append(a)
        B1[62].append(b)
        C1[62].append(c)
    for a, b, c in zip(x63, y63, z63): #same list
        A1[63].append(a)
        B1[63].append(b)
        C1[63].append(c)
    for a, b, c in zip(x64, y64, z64):
        A1[64].append(a)
        B1[64].append(b)
        C1[64].append(c)
    for a, b, c in zip(x65, y65, z65):
        A1[65].append(a)
        B1[65].append(b)
        C1[65].append(c)
    for a, b, c in zip(x66, y66, z66):
        A1[66].append(a)
        B1[66].append(b)
        C1[66].append(c)
    for a, b, c in zip(x67, y67, z67):  #same list
        A1[63].append(a)
        B1[63].append(b)
        C1[63].append(c)
    for a, b, c in zip(x68, y68, z68):
        A1[67].append(a)
        B1[67].append(b)
        C1[67].append(c)
    for a, b, c in zip(x69, y69, z69):
        A1[68].append(a)
        B1[68].append(b)
        C1[68].append(c)
    for a, b, c in zip(x70, y70, z70):
        A1[69].append(a)
        B1[69].append(b)
        C1[69].append(c)
    for a, b, c in zip(x71, y71, z71):
        A1[70].append(a)
        B1[70].append(b)
        C1[70].append(c)
    for a, b, c in zip(x72, y72, z72):
        A1[71].append(a)
        B1[71].append(b)
        C1[71].append(c)
    for a, b, c in zip(x73, y73, z73):
        A1[72].append(a)
        B1[72].append(b)
        C1[72].append(c)
    for a, b, c in zip(x74, y74, z74):
        A1[73].append(a)
        B1[73].append(b)
        C1[73].append(c)
    for a, b, c in zip(x75, y75, z75):
        A1[74].append(a)
        B1[74].append(b)
        C1[74].append(c)

# %%
n = 75
A1, B1, C1 = [[] for _ in range(n)], [[] for _ in range(n)], [[] for _ in range(n)]
for file_name in file_list:
    with open(file_name) as f:
        data = json.load(f)
        plot_mag("Jv0915_3495", "Jv0915_4100", "Jv0915_4701", "Jv0915_5500", 
                        "Jv0915_6600", "Jv0915_9000", "Jv0915_9669")

# %%
fig = plt.figure(figsize=(7, 6))
ax1 = fig.add_subplot(111) #ax1.set_xlim(xmin=-1.5,xmax=1.6)
#ax1.set_ylim(ymin=-0.25,ymax=0.12)
plt.tick_params(axis='x', labelsize=15) 
#plt.tick_params(axis='y', labelsize=15)
#ax1.fill(x, y, color= 'k', alpha=0.1)
#ax1.add_artist(circle)
# ax1.set_xlim(xmin=-0.8,xmax=2.5)
#ax1.set_ylim(ymin=-1.8,ymax=5.0)
plt.xlabel('A1', fontsize= 16)
plt.ylabel('B1', fontsize= 16)
ax1.scatter(A1[0], B1[0], c='black', alpha=0.8, s=35, label='Halo PNe')
ax1.scatter(A1[62], B1[62],  c= "yellow", alpha=0.8, marker='o', label='Disk PN from SDSS')
ax1.scatter(A1[1], B1[1], c='purple', alpha=0.8, label='CVs from SDSS')
ax1.scatter(A1[2], B1[2],  c= "orange", alpha=0.8, marker='s', s=5 )
ax1.scatter(A1[3], B1[3],  c= "orange", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[4], B1[4],  c= "orange", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[5], B1[5],  c= "orange", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[6], B1[6],  c= "green", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[7], B1[7],  c= "green", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[8], B1[8],  c= "green", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[9], B1[9],  c= "green", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[10], B1[10],  c= "brown", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[11], B1[11],  c= "brown", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[12], B1[12],  c= "brown", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[13], B1[13],  c= "brown", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[14], B1[14],  c= "cyan", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[15], B1[15],  c= "cyan", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[16], B1[16],  c= "cyan", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[17], B1[17],  c= "cyan", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[18], B1[18],  c= "magenta", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[19], B1[19],  c= "magenta", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[20], B1[20],  c= "magenta", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[21], B1[21],  c= "magenta", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[22], B1[22],  c= "orange", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[23], B1[23],  c= "orange", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[24], B1[24],  c= "orange", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[25], B1[25],  c= "orange", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[26], B1[26],  c= "green", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[27], B1[27],  c= "green", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[28], B1[28],  c= "green", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[29], B1[29],  c= "green", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[30], B1[30],  c= "brown", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[31], B1[31],  c= "brown", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[32], B1[32],  c= "brown", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[33], B1[33],  c= "brown", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[34], B1[34],  c= "cyan", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[35], B1[35],  c= "cyan", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[36], B1[36],  c= "cyan", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[37], B1[37],  c= "cyan", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[38], B1[38],  c= "magenta", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[39], B1[39],  c= "magenta", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[40], B1[40],  c= "magenta", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[41], B1[41],  c= "magenta", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[42], B1[42],  c= "orange", alpha=0.8, s=28,   marker='s', label='BB dddm1 L2')
ax1.scatter(A1[43], B1[43],  c= "orange", alpha=0.8, s=28,  marker='D', label='BB dddm1 L3')
ax1.scatter(A1[44], B1[44],  c= "orange", alpha=0.8, s=28,  marker='^', label='BB dddm1 L4')
ax1.scatter(A1[45], B1[45],  c= "orange", alpha=0.8, s=28,  marker='*', label='BB dddm1 L5')
ax1.scatter(A1[46], B1[46],  c= "green", alpha=0.8, s=28,  marker='s', label='BB N2242 L2')
ax1.scatter(A1[47], B1[47],  c= "green", alpha=0.8, s=28,  marker='D', label='BB N2242 L3')
ax1.scatter(A1[48], B1[48],  c= "green", alpha=0.8, s=28,  marker='^', label='BB N2242 L4')
ax1.scatter(A1[49], B1[49],  c= "green", alpha=0.8, s=28,  marker='*', label='BB N2242 L5')
ax1.scatter(A1[50], B1[50],  c= "brown", alpha=0.8, s=28,  marker='s', label='BB K648 L2')
ax1.scatter(A1[51], B1[51],  c= "brown", alpha=0.8, s=28,  marker='D', label='BB K648 L3')
ax1.scatter(A1[52], B1[52],  c= "brown", alpha=0.8, s=28,  marker='^', label='BB K648 L4')
ax1.scatter(A1[53], B1[53],  c= "brown", alpha=0.8, s=28,  marker='*', label='BB K648 L5')
ax1.scatter(A1[54], B1[54],  c= "cyan", alpha=0.8, s=28,  marker='s', label='BB BB1 L2')
ax1.scatter(A1[55], B1[55],  c= "cyan", alpha=0.8, s=28,  marker='D', label='BB BB1 L3')
ax1.scatter(A1[56], B1[56],  c= "cyan", alpha=0.8, s=28,  marker='^', label='BB BB1 L4')
ax1.scatter(A1[57], B1[57],  c= "cyan", alpha=0.8, s=28,  marker='*', label='BB BB1 L5')
ax1.scatter(A1[58], B1[58],  c= "magenta", alpha=0.8, s=28,  marker='s', label='BB Typ L2')
ax1.scatter(A1[59], B1[59],  c= "magenta", alpha=0.8, s=28,  marker='D', label='BB Typ L3')
ax1.scatter(A1[60], B1[60],  c= "magenta", alpha=0.8, s=28,  marker='^', label='BB Typ L4')
ax1.scatter(A1[61], B1[61],  c= "magenta", alpha=0.8, s=28,  marker='*',  label='BB Typ L5')
ax1.scatter(A1[67], B1[67],  c= "mediumaquamarine" , alpha=0.8, marker='s',  label='QSOs (4.01<z<5.0)')
ax1.scatter(A1[63], B1[63],  c= "royalblue", alpha=0.8, marker='D',  label='QSOs (3.01<z<4.0)')
ax1.scatter(A1[66], B1[66],  c= "goldenrod", alpha=0.8, marker='^',  label='QSOs (2.01<z<3.0)')
ax1.scatter(A1[65], B1[65],  c= "salmon", alpha=0.8, marker='*',  label='QSOs (1.01<z<2.0)')
ax1.scatter(A1[64], B1[64],  c= "sage", alpha=0.8, marker='o',  label='QSOs (0.01<z<1.0)')
ax1.scatter(A1[68], B1[68],  c= "white", alpha=0.3, marker='^', label='SFGs from SDSS')
ax1.scatter(A1[69], B1[69],  c= "red", alpha=0.8, marker='s', label='Munari Symbiotics')
ax1.scatter(A1[72], B1[72],  c= "red", alpha=0.8, marker='D', label='Symbiotics in NGC 55')
ax1.scatter(A1[70], B1[70],  c= "red", alpha=0.8, marker='^', label='Symbiotics from IPHAS')
ax1.scatter(A1[73], B1[73],  c= "red", alpha=0.8, marker='o', label='C. Buil Symbiotics')
ax1.scatter(A1[71], B1[71],  c= "gray", alpha=0.8, marker='D', label='HII region in NGC 55')
ax1.scatter(A1[74], B1[74],  c= "black", alpha=0.8, marker='.', label='SN Remanents')
plt.show()

# %%
fig = plt.figure(figsize=(7, 6))
ax1 = fig.add_subplot(111)
#ax1.set_xlim(xmin=-1.5,xmax=1.6)
#ax1.set_ylim(ymin=-0.25,ymax=0.12)
plt.tick_params(axis='x', labelsize=15) 
#plt.tick_params(axis='y', labelsize=15)
#ax1.fill(x, y, color= 'k', alpha=0.1)
#ax1.add_artist(circle)
# ax1.set_xlim(xmin=-0.8,xmax=2.5)
#ax1.set_ylim(ymin=-1.8,ymax=5.0)
plt.xlabel('A1', fontsize= 16)
plt.ylabel('B1', fontsize= 16)
ax1.scatter(A1[0], B1[0], c='black', alpha=0.8, s=35, label='Halo PNe')
ax1.scatter(A1[62], B1[62],  c= "yellow", alpha=0.8, marker='o', label='Disk PN from SDSS')
ax1.scatter(A1[1], C1[1], c='purple', alpha=0.8, label='CVs from SDSS')
ax1.scatter(A1[2], C1[2],  c= "orange", alpha=0.8, marker='s', s=5 )
ax1.scatter(A1[3], C1[3],  c= "orange", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[4], C1[4],  c= "orange", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[5], C1[5],  c= "orange", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[6], C1[6],  c= "green", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[7], C1[7],  c= "green", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[8], C1[8],  c= "green", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[9], C1[9],  c= "green", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[10], C1[10],  c= "brown", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[11], C1[11],  c= "brown", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[12], C1[12],  c= "brown", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[13], C1[13],  c= "brown", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[14], C1[14],  c= "cyan", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[15], C1[15],  c= "cyan", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[16], C1[16],  c= "cyan", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[17], C1[17],  c= "cyan", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[18], C1[18],  c= "magenta", alpha=0.8, marker='s', s=5)
ax1.scatter(A1[19], C1[19],  c= "magenta", alpha=0.8, marker='D', s=5)
ax1.scatter(A1[20], C1[20],  c= "magenta", alpha=0.8, marker='^', s=5)
ax1.scatter(A1[21], C1[21],  c= "magenta", alpha=0.8, marker='*', s=5)
ax1.scatter(A1[22], C1[22],  c= "orange", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[23], C1[23],  c= "orange", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[24], C1[24],  c= "orange", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[25], C1[25],  c= "orange", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[26], C1[26],  c= "green", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[27], C1[27],  c= "green", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[28], C1[28],  c= "green", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[29], C1[29],  c= "green", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[30], C1[30],  c= "brown", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[31], C1[31],  c= "brown", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[32], C1[32],  c= "brown", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[33], C1[33],  c= "brown", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[34], C1[34],  c= "cyan", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[35], C1[35],  c= "cyan", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[36], C1[36],  c= "cyan", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[37], C1[37],  c= "cyan", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[38], C1[38],  c= "magenta", alpha=0.8, s=11,  marker='s')
ax1.scatter(A1[39], C1[39],  c= "magenta", alpha=0.8, s=11,  marker='D')
ax1.scatter(A1[40], C1[40],  c= "magenta", alpha=0.8, s=11,  marker='^')
ax1.scatter(A1[41], C1[41],  c= "magenta", alpha=0.8, s=11,  marker='*')
ax1.scatter(A1[42], C1[42],  c= "orange", alpha=0.8, s=28,   marker='s', label='BB dddm1 L2')
ax1.scatter(A1[43], C1[43],  c= "orange", alpha=0.8, s=28,  marker='D', label='BB dddm1 L3')
ax1.scatter(A1[44], C1[44],  c= "orange", alpha=0.8, s=28,  marker='^', label='BB dddm1 L4')
ax1.scatter(A1[45], C1[45],  c= "orange", alpha=0.8, s=28,  marker='*', label='BB dddm1 L5')
ax1.scatter(A1[46], C1[46],  c= "green", alpha=0.8, s=28,  marker='s', label='BB N2242 L2')
ax1.scatter(A1[47], C1[47],  c= "green", alpha=0.8, s=28,  marker='D', label='BB N2242 L3')
ax1.scatter(A1[48], C1[48],  c= "green", alpha=0.8, s=28,  marker='^', label='BB N2242 L4')
ax1.scatter(A1[49], C1[49],  c= "green", alpha=0.8, s=28,  marker='*', label='BB N2242 L5')
ax1.scatter(A1[50], C1[50],  c= "brown", alpha=0.8, s=28,  marker='s', label='BB K648 L2')
ax1.scatter(A1[51], C1[51],  c= "brown", alpha=0.8, s=28,  marker='D', label='BB K648 L3')
ax1.scatter(A1[52], C1[52],  c= "brown", alpha=0.8, s=28,  marker='^', label='BB K648 L4')
ax1.scatter(A1[53], C1[53],  c= "brown", alpha=0.8, s=28,  marker='*', label='BB K648 L5')
ax1.scatter(A1[54], C1[54],  c= "cyan", alpha=0.8, s=28,  marker='s', label='BB BB1 L2')
ax1.scatter(A1[55], C1[55],  c= "cyan", alpha=0.8, s=28,  marker='D', label='BB BB1 L3')
ax1.scatter(A1[56], C1[56],  c= "cyan", alpha=0.8, s=28,  marker='^', label='BB BB1 L4')
ax1.scatter(A1[57], C1[57],  c= "cyan", alpha=0.8, s=28,  marker='*', label='BB BB1 L5')
ax1.scatter(A1[58], C1[58],  c= "magenta", alpha=0.8, s=28,  marker='s', label='BB Typ L2')
ax1.scatter(A1[59], C1[59],  c= "magenta", alpha=0.8, s=28,  marker='D', label='BB Typ L3')
ax1.scatter(A1[60], C1[60],  c= "magenta", alpha=0.8, s=28,  marker='^', label='BB Typ L4')
ax1.scatter(A1[61], C1[61],  c= "magenta", alpha=0.8, s=28,  marker='*',  label='BB Typ L5')
ax1.scatter(A1[67], C1[67],  c= "mediumaquamarine" , alpha=0.8, marker='s',  label='QSOs (4.01<z<5.0)')
ax1.scatter(A1[63], C1[63],  c= "royalblue", alpha=0.8, marker='D',  label='QSOs (3.01<z<4.0)')
ax1.scatter(A1[66], C1[66],  c= "goldenrod", alpha=0.8, marker='^',  label='QSOs (2.01<z<3.0)')
ax1.scatter(A1[65], C1[65],  c= "salmon", alpha=0.8, marker='*',  label='QSOs (1.01<z<2.0)')
ax1.scatter(A1[64], C1[64],  c= "sage", alpha=0.8, marker='o',  label='QSOs (0.01<z<1.0)')
ax1.scatter(A1[68], C1[68],  c= "white", alpha=0.3, marker='^', label='SFGs from SDSS')
ax1.scatter(A1[69], C1[69],  c= "red", alpha=0.8, marker='s', label='Munari Symbiotics')
ax1.scatter(A1[72], C1[72],  c= "red", alpha=0.8, marker='D', label='Symbiotics in NGC 55')
ax1.scatter(A1[70], C1[70],  c= "red", alpha=0.8, marker='^', label='Symbiotics from IPHAS')
ax1.scatter(A1[73], C1[73],  c= "red", alpha=0.8, marker='o', label='C. Buil Symbiotics')
ax1.scatter(A1[71], C1[71],  c= "gray", alpha=0.8, marker='D', label='HII region in NGC 55')
ax1.scatter(A1[74], C1[74],  c= "black", alpha=0.8, marker='.', label='SN Remanents')
plt.show()
gcf().set_size_inches(12,8)

# %%
fig = plt.figure(figsize=(7, 6))
ax1 = fig.add_subplot(111)
#ax1.set_xlim(xmin=-1.5,xmax=1.6)
#ax1.set_ylim(ymin=-0.25,ymax=0.12)
plt.tick_params(axis='x', labelsize=15) 
#plt.tick_params(axis='y', labelsize=15)
#ax1.fill(x, y, color= 'k', alpha=0.1)
#ax1.add_artist(circle)
# ax1.set_xlim(xmin=-0.8,xmax=2.5)
#ax1.set_ylim(ymin=-1.8,ymax=5.0)
plt.xlabel('B1', fontsize= 16)
plt.ylabel('C1', fontsize= 16)
ax1.scatter(B1[0], B1[0], c='black', alpha=0.8, s=35, label='Halo PNe')
ax1.scatter(B1[62], B1[62],  c= "yellow", alpha=0.8, marker='o', label='Disk PN from SDSS')
ax1.scatter(B1[1], C1[1], c='purple', alpha=0.8, label='CVs from SDSS')
ax1.scatter(B1[2], C1[2],  c= "orange", alpha=0.8, marker='s', s=5 )
ax1.scatter(B1[3], C1[3],  c= "orange", alpha=0.8, marker='D', s=5)
ax1.scatter(B1[4], C1[4],  c= "orange", alpha=0.8, marker='^', s=5)
ax1.scatter(B1[5], C1[5],  c= "orange", alpha=0.8, marker='*', s=5)
ax1.scatter(B1[6], C1[6],  c= "green", alpha=0.8, marker='s', s=5)
ax1.scatter(B1[7], C1[7],  c= "green", alpha=0.8, marker='D', s=5)
ax1.scatter(B1[8], C1[8],  c= "green", alpha=0.8, marker='^', s=5)
ax1.scatter(B1[9], C1[9],  c= "green", alpha=0.8, marker='*', s=5)
ax1.scatter(B1[10], C1[10],  c= "brown", alpha=0.8, marker='s', s=5)
ax1.scatter(B1[11], C1[11],  c= "brown", alpha=0.8, marker='D', s=5)
ax1.scatter(B1[12], C1[12],  c= "brown", alpha=0.8, marker='^', s=5)
ax1.scatter(B1[13], C1[13],  c= "brown", alpha=0.8, marker='*', s=5)
ax1.scatter(B1[14], C1[14],  c= "cyan", alpha=0.8, marker='s', s=5)
ax1.scatter(B1[15], C1[15],  c= "cyan", alpha=0.8, marker='D', s=5)
ax1.scatter(B1[16], C1[16],  c= "cyan", alpha=0.8, marker='^', s=5)
ax1.scatter(B1[17], C1[17],  c= "cyan", alpha=0.8, marker='*', s=5)
ax1.scatter(B1[18], C1[18],  c= "magenta", alpha=0.8, marker='s', s=5)
ax1.scatter(B1[19], C1[19],  c= "magenta", alpha=0.8, marker='D', s=5)
ax1.scatter(B1[20], C1[20],  c= "magenta", alpha=0.8, marker='^', s=5)
ax1.scatter(B1[21], C1[21],  c= "magenta", alpha=0.8, marker='*', s=5)
ax1.scatter(B1[22], C1[22],  c= "orange", alpha=0.8, s=11,  marker='s')
ax1.scatter(B1[23], C1[23],  c= "orange", alpha=0.8, s=11,  marker='D')
ax1.scatter(B1[24], C1[24],  c= "orange", alpha=0.8, s=11,  marker='^')
ax1.scatter(B1[25], C1[25],  c= "orange", alpha=0.8, s=11,  marker='*')
ax1.scatter(B1[26], C1[26],  c= "green", alpha=0.8, s=11,  marker='s')
ax1.scatter(B1[27], C1[27],  c= "green", alpha=0.8, s=11,  marker='D')
ax1.scatter(B1[28], C1[28],  c= "green", alpha=0.8, s=11,  marker='^')
ax1.scatter(B1[29], C1[29],  c= "green", alpha=0.8, s=11,  marker='*')
ax1.scatter(B1[30], C1[30],  c= "brown", alpha=0.8, s=11,  marker='s')
ax1.scatter(B1[31], C1[31],  c= "brown", alpha=0.8, s=11,  marker='D')
ax1.scatter(B1[32], C1[32],  c= "brown", alpha=0.8, s=11,  marker='^')
ax1.scatter(B1[33], C1[33],  c= "brown", alpha=0.8, s=11,  marker='*')
ax1.scatter(B1[34], C1[34],  c= "cyan", alpha=0.8, s=11,  marker='s')
ax1.scatter(B1[35], C1[35],  c= "cyan", alpha=0.8, s=11,  marker='D')
ax1.scatter(B1[36], C1[36],  c= "cyan", alpha=0.8, s=11,  marker='^')
ax1.scatter(B1[37], C1[37],  c= "cyan", alpha=0.8, s=11,  marker='*')
ax1.scatter(B1[38], C1[38],  c= "magenta", alpha=0.8, s=11,  marker='s')
ax1.scatter(B1[39], C1[39],  c= "magenta", alpha=0.8, s=11,  marker='D')
ax1.scatter(B1[40], C1[40],  c= "magenta", alpha=0.8, s=11,  marker='^')
ax1.scatter(B1[41], C1[41],  c= "magenta", alpha=0.8, s=11,  marker='*')
ax1.scatter(B1[42], C1[42],  c= "orange", alpha=0.8, s=28,   marker='s', label='BB dddm1 L2')
ax1.scatter(B1[43], C1[43],  c= "orange", alpha=0.8, s=28,  marker='D', label='BB dddm1 L3')
ax1.scatter(B1[44], C1[44],  c= "orange", alpha=0.8, s=28,  marker='^', label='BB dddm1 L4')
ax1.scatter(B1[45], C1[45],  c= "orange", alpha=0.8, s=28,  marker='*', label='BB dddm1 L5')
ax1.scatter(B1[46], C1[46],  c= "green", alpha=0.8, s=28,  marker='s', label='BB N2242 L2')
ax1.scatter(B1[47], C1[47],  c= "green", alpha=0.8, s=28,  marker='D', label='BB N2242 L3')
ax1.scatter(B1[48], C1[48],  c= "green", alpha=0.8, s=28,  marker='^', label='BB N2242 L4')
ax1.scatter(B1[49], C1[49],  c= "green", alpha=0.8, s=28,  marker='*', label='BB N2242 L5')
ax1.scatter(B1[50], C1[50],  c= "brown", alpha=0.8, s=28,  marker='s', label='BB K648 L2')
ax1.scatter(B1[51], C1[51],  c= "brown", alpha=0.8, s=28,  marker='D', label='BB K648 L3')
ax1.scatter(B1[52], C1[52],  c= "brown", alpha=0.8, s=28,  marker='^', label='BB K648 L4')
ax1.scatter(B1[53], C1[53],  c= "brown", alpha=0.8, s=28,  marker='*', label='BB K648 L5')
ax1.scatter(B1[54], C1[54],  c= "cyan", alpha=0.8, s=28,  marker='s', label='BB BB1 L2')
ax1.scatter(B1[55], C1[55],  c= "cyan", alpha=0.8, s=28,  marker='D', label='BB BB1 L3')
ax1.scatter(B1[56], C1[56],  c= "cyan", alpha=0.8, s=28,  marker='^', label='BB BB1 L4')
ax1.scatter(B1[57], C1[57],  c= "cyan", alpha=0.8, s=28,  marker='*', label='BB BB1 L5')
ax1.scatter(B1[58], C1[58],  c= "magenta", alpha=0.8, s=28,  marker='s', label='BB Typ L2')
ax1.scatter(B1[59], C1[59],  c= "magenta", alpha=0.8, s=28,  marker='D', label='BB Typ L3')
ax1.scatter(B1[60], C1[60],  c= "magenta", alpha=0.8, s=28,  marker='^', label='BB Typ L4')
ax1.scatter(B1[61], C1[61],  c= "magenta", alpha=0.8, s=28,  marker='*',  label='BB Typ L5')
ax1.scatter(B1[67], C1[67],  c= "mediumaquamarine" , alpha=0.8, marker='s',  label='QSOs (4.01<z<5.0)')
ax1.scatter(B1[63], C1[63],  c= "royalblue", alpha=0.8, marker='D',  label='QSOs (3.01<z<4.0)')
ax1.scatter(B1[66], C1[66],  c= "goldenrod", alpha=0.8, marker='^',  label='QSOs (2.01<z<3.0)')
ax1.scatter(B1[65], C1[65],  c= "salmon", alpha=0.8, marker='*',  label='QSOs (1.01<z<2.0)')
ax1.scatter(B1[64], C1[64],  c= "sage", alpha=0.8, marker='o',  label='QSOs (0.01<z<1.0)')
ax1.scatter(B1[68], C1[68],  c= "white", alpha=0.3, marker='^', label='SFGs from SDSS')
ax1.scatter(B1[69], C1[69],  c= "red", alpha=0.8, marker='s', label='Munari Symbiotics')
ax1.scatter(B1[72], C1[72],  c= "red", alpha=0.8, marker='D', label='Symbiotics in NGC 55')
ax1.scatter(B1[70], C1[70],  c= "red", alpha=0.8, marker='^', label='Symbiotics from IPHAS')
ax1.scatter(B1[73], C1[73],  c= "red", alpha=0.8, marker='o', label='C. Buil Symbiotics')
ax1.scatter(B1[71], C1[71],  c= "gray", alpha=0.8, marker='D', label='HII region in NGC 55')
ax1.scatter(B1[74], C1[74],  c= "black", alpha=0.8, marker='.', label='SN Remanents')
plt.show()
gcf().set_size_inches(12,8)
