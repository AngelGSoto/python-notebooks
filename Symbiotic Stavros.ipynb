# %%
# %pylab inline
from __future__ import print_function
from astropy.io import fits
import os
import numpy as np
import glob
import matplotlib.pyplot as plt
from astropy.wcs import WCS
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datadir = "../star-stavros/"
fitsfile = "starx.fits"
hdulist = fits.open(os.path.join(datadir, fitsfile))
# Out:
# WARNING: AstropyDeprecationWarning: Config parameter 'enabled_record_valued_keyword_cards' in section [io.fits] of the file '/home/angel/.astropy/config/astropy.cfg' is deprecated. Use 'enable_record_valued_keyword_cards' in section [io.fits] instead. [astropy.config.configuration]

# %%
hdulist.info()
# Out:
# Filename: ../star-stavros/starx.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     503   (1750,)      float32

# %%
hdulist[0].header
# Out:
# SIMPLE  =                    T / Standard FITS format: NOST 100-2.0
# BITPIX  =                  -32 / No. of bits per pixel
# NAXIS   =                    1 / No. of axes in image
# NAXIS1  =                 1750 / No. of pixels
# EXTEND  =                    T / FITS extension may be present
#
#
# CRPIX1  =                   1. / Reference pixel
# CRVAL1  =               6101.4 / Coordinate at reference pixel
# CDELT1  =                  2.8 / Coord. incr. per pixel (original value)
# CTYPE1  = 'LINEAR          '   / Units of coordinate
# BUNIT   = '10^(-16) erg/(cm'   / Units of data values
# DATAMAX =        29.1485080719 / Maximum data value
# DATAMIN =       -7.99572610855 / Minimum data value
#
# ORIGIN  = 'ESO-MIDAS'          / Written by MIDAS
# DATE    = '2017-02-23T14:46:15' /  [UTC] Date of writing
# FILENAME= 'starx.bdf'          / Original file base-name
# MIDASFTP= 'IMAGE   '           / MIDAS File Type
#
# OBJECT  = 'average frame'      / MIDAS desc.: IDENT(1)
# RA      =            12.805132 / MIDAS desc.: O_POS(1)
# DEC     =            -73.18591 / MIDAS desc.: O_POS(2)
# EQUINOX =                2000. / MIDAS desc.: O_POS(3)
# DATE-OBS= '2016-11-06'         / MIDAS desc.: O_TIME(1)
# MJD-OBS =       57698.17393712 / MIDAS desc.: O_TIME(4)
# TM-START=        15028.1671688 / MIDAS desc.: O_TIME(5)
# EXPTIME =                   0. / MIDAS desc.: O_TIME(7)
# COMMENT NOST 100-2.0: Hanisch,R. et al. 2001, Astron. & Astrophys. 376, 559
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'ESO-VLT-U1'         / MIDAS desc.: TELESCOP(1)
# RADECSYS= 'FK5     '           / MIDAS desc.: RADECSYS(1)
# INSTRUME= 'FORS2   '           / MIDAS desc.: INSTRUME(1)
# HISTORY AVERAGE/IMAG starx = starx1,starx2,starx3,starx4 N 0.00000E+00 Median +\
# HISTORY
# CD1_1   =                  2.8
# CD1_2   =                   0.
# CD2_1   =                   0.
# CD2_2   =                   1.
# LST     =             9125.134 / 02:32:05.134 LST at start (sec)
# UTC     =               15028. / 04:10:28.000 UTC at start (sec)
# ARCFILE = 'FORS2.2016-11-06T04:10:28.167.fits' / Archive File Name
# DATAMD5 = '54b0442e27ec2e7df644fab2b00a266c' / MD5 checksum
# PIPEFILE= 'mapped_flux_sci_mos.fits' / Filename of data product
# CHECKSUM= '96BFA49E94AEA47E'   / HDU checksum updated 2016-11-14T13:36:17
# DATASUM = '3445389512'         / data unit checksum updated 2016-11-14T13:36:17
# HIERARCH ESO OBS NTPL  =          4 / Number of templates within OB
# HIERARCH ESO OBS TPLNO =          3 / Template number within OB
# HIERARCH ESO OBS NAME  = 'MOS-SMC-F1-red' / OB name
# HIERARCH ESO OBS PROG ID       = '098.D-0301(B)' / ESO program identification
# HIERARCH ESO OBS ID    =    1427902 / Observation block ID
# HIERARCH ESO OBS DID   = 'ESO-VLT-DIC.OBS-2.0' / OBS Dictionary
# HIERARCH ESO OBS OBSERVER      = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI NAME   = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PI-COI ID     =      72954 / ESO internal PI-COI ID
# HIERARCH ESO OBS TARG NAME     = 'SMC-F1  ' / OB target name
# HIERARCH ESO OBS GRP   = '0       ' / linked blocks
# HIERARCH ESO OBS START = '2016-11-06T04:02:35' / OB start time
# HIERARCH ESO OBS EXECTIME      =       2504 / Expected execution time
# HIERARCH ESO OBS CONTAINER ID  =       -999 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE= 'U       ' / Scheduling container type
# HIERARCH ESO OBS MOON FLI      =        0.6 / Req. max. fractional lunar illum.
# HIERARCH ESO OBS MOON DIST     =         60 / Req. min. angular dist. from moon
# HIERARCH ESO OBS AMBI FWHM     =         1. / Req. max. seeing
# HIERARCH ESO OBS STREHLRATIO   =         0. / Req. strehl ratio
# HIERARCH ESO OBS TWILIGHT      =          0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR   =         0. / Req. water vapour
# HIERARCH ESO OBS AMBI TRANS    = '2CLR    ' / Req. sky transparency
# HIERARCH ESO OBS AIRM  =        1.6 / Req. max. airmass
# HIERARCH ESO OBS ATM   = 'NATM    ' / Req. Atmospheric Turbulence Model
# HIERARCH ESO OBS CONTRAST      =         0. / Req. contrast
# HIERARCH ESO TPL ID    = 'FORS2_mos_obs_off' / Template signature ID
# HIERARCH ESO TPL NAME  = 'Take mos exposure' / Template name
# HIERARCH ESO TPL NEXP  =          3 / Number of exposures within templat
# HIERARCH ESO TPL EXPNO =          1 / Exposure number within template
# HIERARCH ESO TPL START = '2016-11-06T04:09:41' / TPL start time
# HIERARCH ESO TEL DID   = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL ID    = 'v 287975' / TCS version number
# HIERARCH ESO TEL DATE  = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL ALT   =     39.666 / Alt angle at start (deg)
# HIERARCH ESO TEL AZ    =      9.205 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL GEOELEV       =      2648. / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT=   -24.6276 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON=   -70.4051 / Tel geo longitude (+=East) (deg)
# HIERARCH ESO TEL OPER  = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL FOCU ID       = 'CA      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN      =    108.827 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE    =      1.894 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE    =     -6.772 / M2 setting (mm)
# HIERARCH ESO TEL PARANG START  =     29.986 / Parallactic angle at start (deg)
# HIERARCH ESO TEL AIRM START    =      1.565 / Airmass at start
# HIERARCH ESO TEL AMBI FWHM START       =       0.69 / Observatory Seeing queried
# HIERARCH ESO TEL AMBI PRES START       =     745.02 / Observatory ambient air pr
# HIERARCH ESO TEL AMBI WINDSP   =       4.63 / Observatory ambient wind speed que
# HIERARCH ESO TEL AMBI WINDDIR  =         8. / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI RHUM     =         9. / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP     =      16.55 / Observatory ambient temperature qu
# HIERARCH ESO TEL MOON RA       = 295.329941 / 19:41:19.1 RA (J2000) (deg)
# HIERARCH ESO TEL MOON DEC      =  -17.17114 / -17:10:16.1 DEC (J2000) (deg)
# HIERARCH ESO TEL TH M1 TEMP    =      14.74 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS   = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL DOME STATUS   = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL CHOP ST       = F / True when chopping is active
# HIERARCH ESO TEL TARG ALPHA    =   5113.151 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG DELTA    = -731109.13 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH    =      2000. / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM      = 'J       ' / Epoch system (default J=Ju
# HIERARCH ESO TEL TARG EQUINOX  =      2000. / Equinox
# HIERARCH ESO TEL TARG PMA      =         0. / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD      =         0. / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL   =         0. / Radial velocity
# HIERARCH ESO TEL TARG PARALLAX =         0. / Parallax
# HIERARCH ESO TEL TARG COORDTYPE= 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL PARANG END    =     32.325 / Parallactic angle at end (deg)
# HIERARCH ESO TEL AIRM END      =      1.575 / Airmass at end
# HIERARCH ESO TEL AMBI FWHM END =       0.72 / Observatory Seeing queried from AS
# HIERARCH ESO TEL IA FWHM       =       0.66 / Delivered seeing corrected by airm
# HIERARCH ESO TEL IA FWHMLIN    =       0.73 / Delivered seeing on IA detector (l
# HIERARCH ESO TEL IA FWHMLINOBS =       0.96 / Delivered seeing on IA detector (l
# HIERARCH ESO TEL AMBI PRES END =     744.95 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI TAU0     =   0.003258 / Average coherence time
# HIERARCH ESO TEL LADC TARGSEPPOS       =      1072. / LADC target separation dis
# HIERARCH ESO INS PIXSCALE      =      0.126 / pixel scale in arcsec/pixel
# HIERARCH ESO INS SHUT EXPTIME  =    479.985 / Real exposure time in sec.
# HIERARCH ESO INS MODE  = 'MOS     ' / Instrument mode used
# HIERARCH ESO INS MOS CHECKSUM  =       7725 / Checksum of MOS slitlet configurat
# HIERARCH ESO INS MOS1 POS      =  -11.06657 / Position of the slit in mm.
# HIERARCH ESO INS MOS2 POS      =  -2.174983 / Position of the slit in mm.
# HIERARCH ESO INS MOS3 POS      =   1.606016 / Position of the slit in mm.
# HIERARCH ESO INS MOS4 POS      =  -5.461567 / Position of the slit in mm.
# HIERARCH ESO INS MOS5 POS      =   14.60736 / Position of the slit in mm.
# HIERARCH ESO INS MOS6 POS      =   1.908786 / Position of the slit in mm.
# HIERARCH ESO INS MOS7 POS      =  -4.379731 / Position of the slit in mm.
# HIERARCH ESO INS MOS8 POS      = -0.2657267 / Position of the slit in mm.
# HIERARCH ESO INS MOS9 POS      =  -4.154283 / Position of the slit in mm.
# HIERARCH ESO INS MOS10 POS     =      -119. / Position of the slit in mm.
# HIERARCH ESO INS MOS11 POS     =   8.768753 / Position of the slit in mm.
# HIERARCH ESO INS MOS12 POS     =   2.718917 / Position of the slit in mm.
# HIERARCH ESO INS MOS13 POS     =   8.274918 / Position of the slit in mm.
# HIERARCH ESO INS MOS14 POS     =   18.78004 / Position of the slit in mm.
# HIERARCH ESO INS MOS15 POS     =   19.24044 / Position of the slit in mm.
# HIERARCH ESO INS MOS16 POS     =   20.59842 / Position of the slit in mm.
# HIERARCH ESO INS MOS17 POS     =   17.48778 / Position of the slit in mm.
# HIERARCH ESO INS MOS18 POS     =  -12.98304 / Position of the slit in mm.
# HIERARCH ESO INS MOS19 POS     =   3.747969 / Position of the slit in mm.
# HIERARCH ESO INS MOS1 WIDTH    =  0.5261329 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS1 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS2 WIDTH    =  0.5259659 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS2 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS3 WIDTH    =  0.5259678 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS3 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS4 WIDTH    =  0.5261333 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS4 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS5 WIDTH    =  0.5262869 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS5 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS6 WIDTH    =  0.5264276 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS6 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS7 WIDTH    =  0.5264629 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS7 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS8 WIDTH    =  0.5264534 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS8 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS9 WIDTH    =  0.5265654 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS9 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS10 WIDTH   =   5.999952 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS10 WID     =       11.4 / MOSi slit width in arcsec
# HIERARCH ESO INS MOS11 WIDTH   =  0.5264933 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS11 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS12 WIDTH   =  0.5271661 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS12 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS13 WIDTH   =  0.5261635 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS13 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS14 WIDTH   =  0.5259261 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS14 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS15 WIDTH   =  0.5261257 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS15 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS16 WIDTH   =  0.5261606 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS16 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS17 WIDTH   =  0.5264479 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS17 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS18 WIDTH   =  0.5260727 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS18 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS19 WIDTH   =  0.5260627 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS19 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS1 RA       =   12.92097 / RA of slit in deg
# HIERARCH ESO INS MOS2 RA       =   12.89605 / RA of slit in deg
# HIERARCH ESO INS MOS3 RA       =   12.87917 / RA of slit in deg
# HIERARCH ESO INS MOS4 RA       =    12.8794 / RA of slit in deg
# HIERARCH ESO INS MOS5 RA       =   12.83682 / RA of slit in deg
# HIERARCH ESO INS MOS6 RA       =   12.84592 / RA of slit in deg
# HIERARCH ESO INS MOS7 RA       =    12.8449 / RA of slit in deg
# HIERARCH ESO INS MOS8 RA       =   12.82746 / RA of slit in deg
# HIERARCH ESO INS MOS9 RA       =   12.82265 / RA of slit in deg
# HIERARCH ESO INS MOS11 RA      =   12.78031 / RA of slit in deg
# HIERARCH ESO INS MOS12 RA      =   12.77889 / RA of slit in deg
# HIERARCH ESO INS MOS13 RA      =   12.75913 / RA of slit in deg
# HIERARCH ESO INS MOS14 RA      =   12.73154 / RA of slit in deg
# HIERARCH ESO INS MOS15 RA      =   12.71982 / RA of slit in deg
# HIERARCH ESO INS MOS16 RA      =   12.70666 / RA of slit in deg
# HIERARCH ESO INS MOS17 RA      =   12.70056 / RA of slit in deg
# HIERARCH ESO INS MOS18 RA      =   12.73774 / RA of slit in deg
# HIERARCH ESO INS MOS19 RA      =   12.70025 / RA of slit in deg
# HIERARCH ESO INS MOS1 DEC      =  -73.13946 / DEC of slit in deg
# HIERARCH ESO INS MOS2 DEC      =  -73.14261 / DEC of slit in deg
# HIERARCH ESO INS MOS3 DEC      =   -73.1471 / DEC of slit in deg
# HIERARCH ESO INS MOS4 DEC      =  -73.15445 / DEC of slit in deg
# HIERARCH ESO INS MOS5 DEC      =  -73.15463 / DEC of slit in deg
# HIERARCH ESO INS MOS6 DEC      =  -73.16347 / DEC of slit in deg
# HIERARCH ESO INS MOS7 DEC      =  -73.17062 / DEC of slit in deg
# HIERARCH ESO INS MOS8 DEC      =  -73.17501 / DEC of slit in deg
# HIERARCH ESO INS MOS9 DEC      =  -73.18152 / DEC of slit in deg
# HIERARCH ESO INS MOS11 DEC     =  -73.18907 / DEC of slit in deg
# HIERARCH ESO INS MOS12 DEC     =  -73.19615 / DEC of slit in deg
# HIERARCH ESO INS MOS13 DEC     =  -73.20016 / DEC of slit in deg
# HIERARCH ESO INS MOS14 DEC     =  -73.20286 / DEC of slit in deg
# HIERARCH ESO INS MOS15 DEC     =  -73.20822 / DEC of slit in deg
# HIERARCH ESO INS MOS16 DEC     =  -73.21334 / DEC of slit in deg
# HIERARCH ESO INS MOS17 DEC     =  -73.21964 / DEC of slit in deg
# HIERARCH ESO INS MOS18 DEC     =  -73.23319 / DEC of slit in deg
# HIERARCH ESO INS MOS19 DEC     =  -73.23423 / DEC of slit in deg
# HIERARCH ESO INS MOS1 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS2 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS3 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS4 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS5 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS6 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS7 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS8 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS9 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS11 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS12 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS13 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS14 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS15 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS16 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS17 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS18 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS19 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS1 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS2 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS3 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS4 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS5 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS6 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS7 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS8 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS9 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS11 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS12 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS13 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS14 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS15 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS16 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS17 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS18 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS19 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS TARG1 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG2 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG3 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG4 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG5 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG6 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG7 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG8 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG9 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG11 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG12 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG13 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG14 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG15 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG16 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG17 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG18 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG19 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG1 RA      = 12.91867917 / RA of MOS target in deg
# HIERARCH ESO INS TARG2 RA      = 12.8944375 / RA of MOS target in deg
# HIERARCH ESO INS TARG3 RA      = 12.8818875 / RA of MOS target in deg
# HIERARCH ESO INS TARG4 RA      = 12.88132917 / RA of MOS target in deg
# HIERARCH ESO INS TARG5 RA      = 12.83502083 / RA of MOS target in deg
# HIERARCH ESO INS TARG6 RA      = 12.84428333 / RA of MOS target in deg
# HIERARCH ESO INS TARG7 RA      = 12.84716667 / RA of MOS target in deg
# HIERARCH ESO INS TARG8 RA      = 12.82750417 / RA of MOS target in deg
# HIERARCH ESO INS TARG9 RA      = 12.82390833 / RA of MOS target in deg
# HIERARCH ESO INS TARG11 RA     = 12.7834125 / RA of MOS target in deg
# HIERARCH ESO INS TARG12 RA     = 12.7785125 / RA of MOS target in deg
# HIERARCH ESO INS TARG13 RA     = 12.75936667 / RA of MOS target in deg
# HIERARCH ESO INS TARG14 RA     =   12.73105 / RA of MOS target in deg
# HIERARCH ESO INS TARG15 RA     =   12.72165 / RA of MOS target in deg
# HIERARCH ESO INS TARG16 RA     =    12.7042 / RA of MOS target in deg
# HIERARCH ESO INS TARG17 RA     = 12.69787917 / RA of MOS target in deg
# HIERARCH ESO INS TARG18 RA     = 12.73672917 / RA of MOS target in deg
# HIERARCH ESO INS TARG19 RA     = 12.70422083 / RA of MOS target in deg
# HIERARCH ESO INS TARG1 DEC     = -73.14031111 / DEC of MOS target in deg
# HIERARCH ESO INS TARG2 DEC     = -73.14312222 / DEC of MOS target in deg
# HIERARCH ESO INS TARG3 DEC     = -73.14544444 / DEC of MOS target in deg
# HIERARCH ESO INS TARG4 DEC     = -73.15320278 / DEC of MOS target in deg
# HIERARCH ESO INS TARG5 DEC     = -73.15527778 / DEC of MOS target in deg
# HIERARCH ESO INS TARG6 DEC     = -73.16404167 / DEC of MOS target in deg
# HIERARCH ESO INS TARG7 DEC     = -73.16923889 / DEC of MOS target in deg
# HIERARCH ESO INS TARG8 DEC     = -73.17476389 / DEC of MOS target in deg
# HIERARCH ESO INS TARG9 DEC     = -73.180675 / DEC of MOS target in deg
# HIERARCH ESO INS TARG11 DEC    = -73.187325 / DEC of MOS target in deg
# HIERARCH ESO INS TARG12 DEC    = -73.19615833 / DEC of MOS target in deg
# HIERARCH ESO INS TARG13 DEC    = -73.19987222 / DEC of MOS target in deg
# HIERARCH ESO INS TARG14 DEC    = -73.20294444 / DEC of MOS target in deg
# HIERARCH ESO INS TARG15 DEC    =  -73.20715 / DEC of MOS target in deg
# HIERARCH ESO INS TARG16 DEC    = -73.21441944 / DEC of MOS target in deg
# HIERARCH ESO INS TARG17 DEC    = -73.22084167 / DEC of MOS target in deg
# HIERARCH ESO INS TARG18 DEC    = -73.23357222 / DEC of MOS target in deg
# HIERARCH ESO INS TARG19 DEC    = -73.23214444 / DEC of MOS target in deg
# HIERARCH ESO INS COLL ID       = '+6      ' / Collimator unique ID
# HIERARCH ESO INS COLL NAME     = 'COLL_SR ' / Collimator name
# HIERARCH ESO INS GRIS1 POSANG  =    -30.048 / Grism posang (N=0 E=90)
# HIERARCH ESO INS GRIS1 ID      = '+11     ' / Grism unique ID
# HIERARCH ESO INS GRIS1 NAME    = 'GRIS_300I' / Grism name.
# HIERARCH ESO INS GRIS1 DISP    =       10.8 / Grism dispersion
# HIERARCH ESO INS GRIS1 WLEN    =       858. / Grism central wavelength
# HIERARCH ESO INS FILT1 ID      = '+32     ' / Filter unique ID
# HIERARCH ESO INS FILT1 NAME    = 'OG590   ' / Filter i name
# HIERARCH ESO INS FOCU POS      =   0.144975 / Focus position in cm
# HIERARCH ESO INS FOCU TEMP     =       16.3 / Focus temperature in C
# HIERARCH ESO INS IMAGE DISTOR1 = 0.000536747 / distortion coefficient
# HIERARCH ESO INS IMAGE DISTOR2 = -2.15778E-06 / distortion coefficient
# HIERARCH ESO INS IMAGE DISTOR3 = 2.11331E-09 / distortion coefficient
# HIERARCH ESO INS OPTI2 NAME    = 'MOS     ' / Name of long slit or polarimetric
# HIERARCH ESO INS OPTI3 NAME    = 'COLL_SR ' / Name of collimator
# HIERARCH ESO INS OPTI4 NAME    = 'free    ' / Name of retarder plate
# HIERARCH ESO INS OPTI5 NAME    = 'free    ' / element name in wheel 1 (Wollaston
# HIERARCH ESO INS OPTI6 NAME    = 'GRIS_300I' / element name in wheel2 (grism)
# HIERARCH ESO INS OPTI7 NAME    = 'OG590   ' / element name in wheel3 (parallel b
# HIERARCH ESO INS OPTI8 NAME    = 'CAMERA  ' / camera name
# HIERARCH ESO INS OPTI9 NAME    = 'free    ' / element name in wheel 4 (interfere
# HIERARCH ESO INS OPTI10 NAME   = 'free    ' / Element name in wheel 5 (interf. 2
# HIERARCH ESO INS OPTI2 ID      = '        ' / Id of long slit or polarimetric ma
# HIERARCH ESO INS OPTI3 ID      = '+6      ' / Identification of collimator
# HIERARCH ESO INS OPTI4 ID      = '        ' / Id of retarder plate
# HIERARCH ESO INS OPTI5 ID      = '        ' / element id in wheel 1 (Wollaston)
# HIERARCH ESO INS OPTI6 ID      = '+11     ' / element id in wheel2 (grism)
# HIERARCH ESO INS OPTI7 ID      = '+32     ' / element id in wheel3 (parallel bea
# HIERARCH ESO INS OPTI8 ID      = '+8      ' / camera id
# HIERARCH ESO INS OPTI9 ID      = '        ' / element id in wheel 4 (interferenc
# HIERARCH ESO INS OPTI10 ID     = '        ' / Element id in wheel 5 (interf. 2)
# HIERARCH ESO INS OPTI2 TYPE    = 'MOS     ' / Element type in the focal field.
# HIERARCH ESO INS OPTI3 TYPE    = 'COLL    ' / Element type
# HIERARCH ESO INS OPTI4 TYPE    = '        ' / Element type
# HIERARCH ESO INS OPTI5 TYPE    = '        ' / Element type in wheel 1
# HIERARCH ESO INS OPTI6 TYPE    = 'GRIS    ' / Element type in wheel 2
# HIERARCH ESO INS OPTI7 TYPE    = 'FILT    ' / Element type in wheel 3
# HIERARCH ESO INS OPTI8 TYPE    = 'CAMERA  ' / Element type
# HIERARCH ESO INS OPTI9 TYPE    = '        ' / Element type in wheel 4
# HIERARCH ESO INS OPTI10 TYPE   = '        ' / Element type in wheel 5
# HIERARCH ESO DET CHIP1 INDEX   =          1 / Chip index
# HIERARCH ESO DET CHIP1 ID      = 'CCID20-14-5-3' / Detector chip identification
# HIERARCH ESO DET CHIP1 NAME    = 'MIT/LL mosaic' / Detector chip name
# HIERARCH ESO DET CHIP1 DATE    = '2001-08-01' / Date of installation [YYYY-MM-DD
# HIERARCH ESO DET CHIP1 X       =          1 / X location in array
# HIERARCH ESO DET CHIP1 Y       =          2 / Y location in array
# HIERARCH ESO DET CHIP1 NX      =       4096 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY      =       2048 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX    =        15. / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY    =        15. / Size of pixel in Y
# HIERARCH ESO DET CHIP1 XGAP    =        30. / Gap between chips along x
# HIERARCH ESO DET CHIP1 YGAP    =       480. / Gap between chips along y
# HIERARCH ESO DET OUT1 INDEX    =          1 / Output index
# HIERARCH ESO DET OUT1 ID       = 'A       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 NAME     = 'A       ' / Description of output
# HIERARCH ESO DET OUT1 CHIP     =          1 / index of chip it belongs to
# HIERARCH ESO DET OUT1 X=          1 / X location of output
# HIERARCH ESO DET OUT1 Y=       1024 / Y location of output
# HIERARCH ESO DET OUT1 NX       =       2048 / valid pixels along X
# HIERARCH ESO DET OUT1 NY       =       1024 / valid pixels along Y
# HIERARCH ESO DET OUT1 PRSCX    =          0 / Prescan region in X
# HIERARCH ESO DET OUT1 OVSCX    =          0 / Overscan region in X
# HIERARCH ESO DET OUT1 PRSCY    =          5 / Prescan region in Y
# HIERARCH ESO DET OUT1 OVSCY    =          5 / Overscan region in Y
# HIERARCH ESO DET OUT1 CONAD    =        0.7 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 RON      =        2.9 / Readout noise per output (e-)
# HIERARCH ESO DET OUT1 GAIN     =       1.43 / Conversion from electrons to ADU
# HIERARCH ESO DET ID    = 'CCD FIERA - Rev: 3.82.1.1' / Detector system Id
# HIERARCH ESO DET NAME  = 'ccdF - fors2' / Name of detector system
# HIERARCH ESO DET DATE  = '2008-05-12' / Installation date
# HIERARCH ESO DET DID   = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET BITS  =         16 / Bits per pixel readout
# HIERARCH ESO DET RA    =    7.52625 / Apparent 00:30:06.3 RA at start
# HIERARCH ESO DET DEC   = -46.46906111 / Apparent -46:28:08.6 DEC at start
# HIERARCH ESO DET CHIPS =          1 / # of chips in detector array
# HIERARCH ESO DET OUTPUTS       =          1 / # of outputs
# HIERARCH ESO DET OUTREF=          0 / reference output
# HIERARCH ESO DET WINDOWS       =          1 / # of windows readout
# HIERARCH ESO DET SOFW MODE     = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET EXP NO=       1261 / Unique exposure ID number
# HIERARCH ESO DET EXP TYPE      = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP RDTTIME   =     12.745 / image readout time
# HIERARCH ESO DET EXP XFERTIM   =     23.772 / image transfer time
# HIERARCH ESO DET WIN1 ST       = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX     =          1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY     =          1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 NX       =       2068 / # of pixels along X
# HIERARCH ESO DET WIN1 NY       =       2048 / # of pixels along Y
# HIERARCH ESO DET WIN1 BINX     =          2 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY     =          2 / Binning factor along Y
# HIERARCH ESO DET WIN1 NDIT     =          1 / # of subintegrations
# HIERARCH ESO DET WIN1 UIT1     =       480. / user defined subintegration time
# HIERARCH ESO DET WIN1 DIT1     = 480.005636 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM     =   480.1709 / Dark current time
# HIERARCH ESO DET READ MODE     = 'normal  ' / Readout method
# HIERARCH ESO DET READ SPEED    = '100Kpix/s' / Readout speed
# HIERARCH ESO DET READ CLOCK    = '100Kps/2ports/high_gain' / Readout clock patte
# HIERARCH ESO DET READ NFRAM    =          1 / Number of readouts buffered in sin
# HIERARCH ESO DET FRAM ID       =          1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE     = 'Normal  ' / Type of frame
# HIERARCH ESO DET SHUT TYPE     = 'Iris    ' / type of shutter
# HIERARCH ESO DET SHUT ID       = 'fors shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMOPEN   =      0.198 / Time taken to open shutter
# HIERARCH ESO DET SHUT TMCLOS   =      0.209 / Time taken to close shutter
# HIERARCH ESO DET CHIP1 RGAP    =    0.08278 / Gap rotation between chips 1 and 2
# HIERARCH ESO PRO ANCESTOR      = 'FORS2.2016-11-06T04:10:28.167.fits'
# HIERARCH ESO PRO DID   = 'PRO-1.15' / Data dictionary for PRO
# HIERARCH ESO PRO CATG  = 'MAPPED_FLUX_SCI_MOS' / Category of pipeline product fr
# HIERARCH ESO PRO TYPE  = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH  = 'MOS     ' / Observation technique
# HIERARCH ESO PRO SCIENCE       = T / Scientific product if T
# HIERARCH ESO PRO REC1 ID       = 'fors_science' / Pipeline recipe (unique) ident
# HIERARCH ESO PRO REC1 DRS ID   = 'cpl-7.0 ' / Data Reduction System identifier
# HIERARCH ESO PRO REC1 PIPE ID  = 'fors2/5.3.11' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC1 RAW1 NAME= 'FORS2.2016-11-06T04:10:28.167.fits' / File na
# HIERARCH ESO PRO REC1 RAW1 CATG= 'SCIENCE_MOS' / Category of raw frame
# HIERARCH ESO PRO DATANCOM      =          1 / Number of combined frames
# HIERARCH ESO PRO REC1 CAL1 NAME= 'curv_coeff_mos.fits' / File name of calibrati
# HIERARCH ESO PRO REC1 CAL1 CATG= 'CURV_COEFF_MOS' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL1 DATAMD5     = '61615463191637312de37ae4a8818b0d' / MD
# HIERARCH ESO PRO REC1 CAL2 NAME= 'disp_coeff_mos.fits' / File name of calibrati
# HIERARCH ESO PRO REC1 CAL2 CATG= 'DISP_COEFF_MOS' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL2 DATAMD5     = 'fdaac1a3a9ebddbbb9c67f934b624d44' / MD
# HIERARCH ESO PRO REC1 CAL3 NAME= 'fors2_extinct_table.fits' / File name of cali
# HIERARCH ESO PRO REC1 CAL3 CATG= 'EXTINCT_TABLE' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL4 NAME= 'flat_sed_mos.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL4 CATG= 'FLAT_SED_MOS' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL4 DATAMD5     = '20847e2b3c33b84988d9d08b2118fdeb' / MD
# HIERARCH ESO PRO REC1 CAL5 NAME= 'FORS2_GRS_300I_11_OG590_32.fits' / File name
# HIERARCH ESO PRO REC1 CAL5 CATG= 'GRISM_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL5 DATAMD5     = '5f297c63b9d8003ec525f5db116acf74' / MD
# HIERARCH ESO PRO REC1 CAL6 NAME= 'master_bias.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL6 CATG= 'MASTER_BIAS' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL6 DATAMD5     = '9641e9eac1221a0872122fbfc11bc82f' / MD
# HIERARCH ESO PRO REC1 CAL7 NAME= 'master_norm_flat_mos.fits' / File name of cal
# HIERARCH ESO PRO REC1 CAL7 CATG= 'MASTER_NORM_FLAT_MOS' / Category of calibrati
# HIERARCH ESO PRO REC1 CAL7 DATAMD5     = 'e5574441e4140b882be2aa805efa2698' / MD
# HIERARCH ESO PRO REC1 CAL8 NAME= 'slit_location_mos.fits' / File name of calibr
# HIERARCH ESO PRO REC1 CAL8 CATG= 'SLIT_LOCATION_MOS' / Category of calibration
# HIERARCH ESO PRO REC1 CAL8 DATAMD5     = '98e5d381e79226d08fcead0cfe888b8f' / MD
# HIERARCH ESO PRO REC1 CAL9 NAME= 'specphot_table.fits' / File name of calibrati
# HIERARCH ESO PRO REC1 CAL9 CATG= 'SPECPHOT_TABLE' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL9 DATAMD5     = 'e7dacfd6d5d558cac081cc8ea543ce7e' / MD
# HIERARCH ESO PRO REC1 PARAM1 NAME      = 'skyalign' / Polynomial order for sky l
# HIERARCH ESO PRO REC1 PARAM1 VALUE     = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM2 NAME      = 'flatfield' / Apply flat field
# HIERARCH ESO PRO REC1 PARAM2 VALUE     = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM3 NAME      = 'skyglobal' / Subtract global sky spect
# HIERARCH ESO PRO REC1 PARAM3 VALUE     = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM4 NAME      = 'skymedian' / Sky subtraction from extr
# HIERARCH ESO PRO REC1 PARAM4 VALUE     = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM5 NAME      = 'skylocal' / Sky subtraction from CCD s
# HIERARCH ESO PRO REC1 PARAM5 VALUE     = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM6 NAME      = 'cosmics ' / Eliminate cosmic rays hits
# HIERARCH ESO PRO REC1 PARAM6 VALUE     = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM7 NAME      = 'slit_margin' / Number of pixels to exc
# HIERARCH ESO PRO REC1 PARAM7 VALUE     = '3       ' / Default: 3
# HIERARCH ESO PRO REC1 PARAM8 NAME      = 'ext_radius' / Maximum extraction radiu
# HIERARCH ESO PRO REC1 PARAM8 VALUE     = '12      ' / Default: 12
# HIERARCH ESO PRO REC1 PARAM9 NAME      = 'cont_radius' / Minimum distance at whi
# HIERARCH ESO PRO REC1 PARAM9 VALUE     = '0       ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM10 NAME     = 'ext_mode' / Object extraction method:
# HIERARCH ESO PRO REC1 PARAM10 VALUE    = '1       ' / Default: 1
# HIERARCH ESO PRO REC1 PARAM11 NAME     = 'resp_fit_nknots' / Number of knots in
# HIERARCH ESO PRO REC1 PARAM11 VALUE    = '-1      ' / Default: -2
# HIERARCH ESO PRO REC1 PARAM12 NAME     = 'resp_fit_degree' / Degree of polynomia
# HIERARCH ESO PRO REC1 PARAM12 VALUE    = '6       ' / Default: -2
# HIERARCH ESO PRO REC1 PARAM13 NAME     = 'resp_ignore_mode' / Types of lines/reg
# HIERARCH ESO PRO REC1 PARAM13 VALUE    = 'stellar_absorption,telluric,command_l'
# HIERARCH ESO PRO REC1 PARAM14 NAME     = 'resp_ignore_points' / Extra lines/regi
# HIERARCH ESO PRO REC1 PARAM14 VALUE    = '        ' / Default: ''
# HIERARCH ESO PRO REC1 PARAM15 NAME     = 'resp_use_flat_sed' / Use the flat SED
# HIERARCH ESO PRO REC1 PARAM15 VALUE    = 'grism_table' / Default: 'grism_table'
# HIERARCH ESO PRO REC1 PARAM16 NAME     = 'nonlinear_level' / Level above which t
# HIERARCH ESO PRO REC1 PARAM16 VALUE    = '60000   ' / Default: 60000
# HIERARCH ESO ADA ABSROT START  = -179.57963 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA POSANG=  -30.04844 / Position angle at start
# HIERARCH ESO ADA GUID STATUS   = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA GUID RA       =  12.500321 / 00:50:00.0 Guide star RA J2000
# HIERARCH ESO ADA GUID DEC      =  -73.17125 / -73:10:16.5 Guide star DEC J2000
# HIERARCH ESO ADA ABSROT PPOS   = 'NEG     ' / sign of probe position
# HIERARCH ESO ADA ABSROT END    = -177.23957 / Abs rot angle at exp end (deg)
#
# HISTORY  ESO-DESCRIPTORS START   ................
# HISTORY  'ROTANG_FROM_CD-MATRIX','R*8',1,2,'3E23.15'
# HISTORY    0.000000000000000E+00  0.000000000000000E+00
# HISTORY
# HISTORY  'LHCUTS','R*4',1,4,'5E14.7'
# HISTORY  -7.9957261E+00 2.9148508E+01-7.9957261E+00 2.9148508E+01
# HISTORY
# HISTORY  ESO-DESCRIPTORS END     ................

# %%
hdulist[0].data
# Out:
# array([-7.03635406, -7.03120613, -7.02605629, ..., -7.42641497,
#        -7.41576815, -7.40501928], dtype=float32)

# %%
datadir = "../star-stavros/"
fitsfile = "star2.fits"
hdulist = fits.open(os.path.join(datadir, fitsfile))

# %%
hdulist.info()
# Out:
# Filename: ../star-stavros/star2.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     503   (1750,)      float32

# %%
hdulist[0].header
# Out:
# SIMPLE  =                    T / Standard FITS format: NOST 100-2.0
# BITPIX  =                  -32 / No. of bits per pixel
# NAXIS   =                    1 / No. of axes in image
# NAXIS1  =                 1750 / No. of pixels
# EXTEND  =                    T / FITS extension may be present
#
#
# CRPIX1  =                   1. / Reference pixel
# CRVAL1  =               6101.4 / Coordinate at reference pixel
# CDELT1  =                  2.8 / Coord. incr. per pixel (original value)
# CTYPE1  = 'LINEAR          '   / Units of coordinate
# BUNIT   = '10^(-16) erg/(cm'   / Units of data values
# DATAMAX =        13.3411426544 / Maximum data value
# DATAMIN =       -5.99423694611 / Minimum data value
#
# ORIGIN  = 'ESO-MIDAS'          / Written by MIDAS
# DATE    = '2017-02-23T14:45:44' /  [UTC] Date of writing
# FILENAME= 'star2.bdf'          / Original file base-name
# MIDASFTP= 'IMAGE   '           / MIDAS File Type
#
# OBJECT  = 'average frame'      / MIDAS desc.: IDENT(1)
# RA      =            12.805132 / MIDAS desc.: O_POS(1)
# DEC     =            -73.18591 / MIDAS desc.: O_POS(2)
# EQUINOX =                2000. / MIDAS desc.: O_POS(3)
# DATE-OBS= '2016-11-06'         / MIDAS desc.: O_TIME(1)
# MJD-OBS =       57698.17393712 / MIDAS desc.: O_TIME(4)
# TM-START=        15028.1671688 / MIDAS desc.: O_TIME(5)
# EXPTIME =                   0. / MIDAS desc.: O_TIME(7)
# COMMENT NOST 100-2.0: Hanisch,R. et al. 2001, Astron. & Astrophys. 376, 559
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'ESO-VLT-U1'         / MIDAS desc.: TELESCOP(1)
# RADECSYS= 'FK5     '           / MIDAS desc.: RADECSYS(1)
# INSTRUME= 'FORS2   '           / MIDAS desc.: INSTRUME(1)
# HISTORY AVERAGE/IMAG star2 = star21,star22,star23,star23 N 0.00000E+00 Median +\
# HISTORY
# CD1_1   =                  2.8
# CD1_2   =                   0.
# CD2_1   =                   0.
# CD2_2   =                   1.
# LST     =             9125.134 / 02:32:05.134 LST at start (sec)
# UTC     =               15028. / 04:10:28.000 UTC at start (sec)
# ARCFILE = 'FORS2.2016-11-06T04:10:28.167.fits' / Archive File Name
# DATAMD5 = '54b0442e27ec2e7df644fab2b00a266c' / MD5 checksum
# PIPEFILE= 'mapped_flux_sci_mos.fits' / Filename of data product
# CHECKSUM= '96BFA49E94AEA47E'   / HDU checksum updated 2016-11-14T13:36:17
# DATASUM = '3445389512'         / data unit checksum updated 2016-11-14T13:36:17
# HIERARCH ESO OBS NTPL  =          4 / Number of templates within OB
# HIERARCH ESO OBS TPLNO =          3 / Template number within OB
# HIERARCH ESO OBS NAME  = 'MOS-SMC-F1-red' / OB name
# HIERARCH ESO OBS PROG ID       = '098.D-0301(B)' / ESO program identification
# HIERARCH ESO OBS ID    =    1427902 / Observation block ID
# HIERARCH ESO OBS DID   = 'ESO-VLT-DIC.OBS-2.0' / OBS Dictionary
# HIERARCH ESO OBS OBSERVER      = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI NAME   = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PI-COI ID     =      72954 / ESO internal PI-COI ID
# HIERARCH ESO OBS TARG NAME     = 'SMC-F1  ' / OB target name
# HIERARCH ESO OBS GRP   = '0       ' / linked blocks
# HIERARCH ESO OBS START = '2016-11-06T04:02:35' / OB start time
# HIERARCH ESO OBS EXECTIME      =       2504 / Expected execution time
# HIERARCH ESO OBS CONTAINER ID  =       -999 / Scheduling container ID
# HIERARCH ESO OBS CONTAINER TYPE= 'U       ' / Scheduling container type
# HIERARCH ESO OBS MOON FLI      =        0.6 / Req. max. fractional lunar illum.
# HIERARCH ESO OBS MOON DIST     =         60 / Req. min. angular dist. from moon
# HIERARCH ESO OBS AMBI FWHM     =         1. / Req. max. seeing
# HIERARCH ESO OBS STREHLRATIO   =         0. / Req. strehl ratio
# HIERARCH ESO OBS TWILIGHT      =          0 / Req. twilight
# HIERARCH ESO OBS WATERVAPOUR   =         0. / Req. water vapour
# HIERARCH ESO OBS AMBI TRANS    = '2CLR    ' / Req. sky transparency
# HIERARCH ESO OBS AIRM  =        1.6 / Req. max. airmass
# HIERARCH ESO OBS ATM   = 'NATM    ' / Req. Atmospheric Turbulence Model
# HIERARCH ESO OBS CONTRAST      =         0. / Req. contrast
# HIERARCH ESO TPL ID    = 'FORS2_mos_obs_off' / Template signature ID
# HIERARCH ESO TPL NAME  = 'Take mos exposure' / Template name
# HIERARCH ESO TPL NEXP  =          3 / Number of exposures within templat
# HIERARCH ESO TPL EXPNO =          1 / Exposure number within template
# HIERARCH ESO TPL START = '2016-11-06T04:09:41' / TPL start time
# HIERARCH ESO TEL DID   = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL ID    = 'v 287975' / TCS version number
# HIERARCH ESO TEL DATE  = '2000-01-01T00:00:00' / TCS installation date
# HIERARCH ESO TEL ALT   =     39.666 / Alt angle at start (deg)
# HIERARCH ESO TEL AZ    =      9.205 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL GEOELEV       =      2648. / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT=   -24.6276 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON=   -70.4051 / Tel geo longitude (+=East) (deg)
# HIERARCH ESO TEL OPER  = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL FOCU ID       = 'CA      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN      =    108.827 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE    =      1.894 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE    =     -6.772 / M2 setting (mm)
# HIERARCH ESO TEL PARANG START  =     29.986 / Parallactic angle at start (deg)
# HIERARCH ESO TEL AIRM START    =      1.565 / Airmass at start
# HIERARCH ESO TEL AMBI FWHM START       =       0.69 / Observatory Seeing queried
# HIERARCH ESO TEL AMBI PRES START       =     745.02 / Observatory ambient air pr
# HIERARCH ESO TEL AMBI WINDSP   =       4.63 / Observatory ambient wind speed que
# HIERARCH ESO TEL AMBI WINDDIR  =         8. / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI RHUM     =         9. / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP     =      16.55 / Observatory ambient temperature qu
# HIERARCH ESO TEL MOON RA       = 295.329941 / 19:41:19.1 RA (J2000) (deg)
# HIERARCH ESO TEL MOON DEC      =  -17.17114 / -17:10:16.1 DEC (J2000) (deg)
# HIERARCH ESO TEL TH M1 TEMP    =      14.74 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS   = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL DOME STATUS   = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL CHOP ST       = F / True when chopping is active
# HIERARCH ESO TEL TARG ALPHA    =   5113.151 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG DELTA    = -731109.13 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH    =      2000. / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM      = 'J       ' / Epoch system (default J=Ju
# HIERARCH ESO TEL TARG EQUINOX  =      2000. / Equinox
# HIERARCH ESO TEL TARG PMA      =         0. / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD      =         0. / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL   =         0. / Radial velocity
# HIERARCH ESO TEL TARG PARALLAX =         0. / Parallax
# HIERARCH ESO TEL TARG COORDTYPE= 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL PARANG END    =     32.325 / Parallactic angle at end (deg)
# HIERARCH ESO TEL AIRM END      =      1.575 / Airmass at end
# HIERARCH ESO TEL AMBI FWHM END =       0.72 / Observatory Seeing queried from AS
# HIERARCH ESO TEL IA FWHM       =       0.66 / Delivered seeing corrected by airm
# HIERARCH ESO TEL IA FWHMLIN    =       0.73 / Delivered seeing on IA detector (l
# HIERARCH ESO TEL IA FWHMLINOBS =       0.96 / Delivered seeing on IA detector (l
# HIERARCH ESO TEL AMBI PRES END =     744.95 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI TAU0     =   0.003258 / Average coherence time
# HIERARCH ESO TEL LADC TARGSEPPOS       =      1072. / LADC target separation dis
# HIERARCH ESO INS PIXSCALE      =      0.126 / pixel scale in arcsec/pixel
# HIERARCH ESO INS SHUT EXPTIME  =    479.985 / Real exposure time in sec.
# HIERARCH ESO INS MODE  = 'MOS     ' / Instrument mode used
# HIERARCH ESO INS MOS CHECKSUM  =       7725 / Checksum of MOS slitlet configurat
# HIERARCH ESO INS MOS1 POS      =  -11.06657 / Position of the slit in mm.
# HIERARCH ESO INS MOS2 POS      =  -2.174983 / Position of the slit in mm.
# HIERARCH ESO INS MOS3 POS      =   1.606016 / Position of the slit in mm.
# HIERARCH ESO INS MOS4 POS      =  -5.461567 / Position of the slit in mm.
# HIERARCH ESO INS MOS5 POS      =   14.60736 / Position of the slit in mm.
# HIERARCH ESO INS MOS6 POS      =   1.908786 / Position of the slit in mm.
# HIERARCH ESO INS MOS7 POS      =  -4.379731 / Position of the slit in mm.
# HIERARCH ESO INS MOS8 POS      = -0.2657267 / Position of the slit in mm.
# HIERARCH ESO INS MOS9 POS      =  -4.154283 / Position of the slit in mm.
# HIERARCH ESO INS MOS10 POS     =      -119. / Position of the slit in mm.
# HIERARCH ESO INS MOS11 POS     =   8.768753 / Position of the slit in mm.
# HIERARCH ESO INS MOS12 POS     =   2.718917 / Position of the slit in mm.
# HIERARCH ESO INS MOS13 POS     =   8.274918 / Position of the slit in mm.
# HIERARCH ESO INS MOS14 POS     =   18.78004 / Position of the slit in mm.
# HIERARCH ESO INS MOS15 POS     =   19.24044 / Position of the slit in mm.
# HIERARCH ESO INS MOS16 POS     =   20.59842 / Position of the slit in mm.
# HIERARCH ESO INS MOS17 POS     =   17.48778 / Position of the slit in mm.
# HIERARCH ESO INS MOS18 POS     =  -12.98304 / Position of the slit in mm.
# HIERARCH ESO INS MOS19 POS     =   3.747969 / Position of the slit in mm.
# HIERARCH ESO INS MOS1 WIDTH    =  0.5261329 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS1 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS2 WIDTH    =  0.5259659 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS2 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS3 WIDTH    =  0.5259678 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS3 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS4 WIDTH    =  0.5261333 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS4 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS5 WIDTH    =  0.5262869 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS5 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS6 WIDTH    =  0.5264276 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS6 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS7 WIDTH    =  0.5264629 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS7 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS8 WIDTH    =  0.5264534 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS8 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS9 WIDTH    =  0.5265654 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS9 WID      =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS10 WIDTH   =   5.999952 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS10 WID     =       11.4 / MOSi slit width in arcsec
# HIERARCH ESO INS MOS11 WIDTH   =  0.5264933 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS11 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS12 WIDTH   =  0.5271661 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS12 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS13 WIDTH   =  0.5261635 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS13 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS14 WIDTH   =  0.5259261 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS14 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS15 WIDTH   =  0.5261257 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS15 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS16 WIDTH   =  0.5261606 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS16 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS17 WIDTH   =  0.5264479 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS17 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS18 WIDTH   =  0.5260727 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS18 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS19 WIDTH   =  0.5260627 / Width of the MOS slit in mm.
# HIERARCH ESO INS MOS19 WID     =         1. / MOSi slit width in arcsec
# HIERARCH ESO INS MOS1 RA       =   12.92097 / RA of slit in deg
# HIERARCH ESO INS MOS2 RA       =   12.89605 / RA of slit in deg
# HIERARCH ESO INS MOS3 RA       =   12.87917 / RA of slit in deg
# HIERARCH ESO INS MOS4 RA       =    12.8794 / RA of slit in deg
# HIERARCH ESO INS MOS5 RA       =   12.83682 / RA of slit in deg
# HIERARCH ESO INS MOS6 RA       =   12.84592 / RA of slit in deg
# HIERARCH ESO INS MOS7 RA       =    12.8449 / RA of slit in deg
# HIERARCH ESO INS MOS8 RA       =   12.82746 / RA of slit in deg
# HIERARCH ESO INS MOS9 RA       =   12.82265 / RA of slit in deg
# HIERARCH ESO INS MOS11 RA      =   12.78031 / RA of slit in deg
# HIERARCH ESO INS MOS12 RA      =   12.77889 / RA of slit in deg
# HIERARCH ESO INS MOS13 RA      =   12.75913 / RA of slit in deg
# HIERARCH ESO INS MOS14 RA      =   12.73154 / RA of slit in deg
# HIERARCH ESO INS MOS15 RA      =   12.71982 / RA of slit in deg
# HIERARCH ESO INS MOS16 RA      =   12.70666 / RA of slit in deg
# HIERARCH ESO INS MOS17 RA      =   12.70056 / RA of slit in deg
# HIERARCH ESO INS MOS18 RA      =   12.73774 / RA of slit in deg
# HIERARCH ESO INS MOS19 RA      =   12.70025 / RA of slit in deg
# HIERARCH ESO INS MOS1 DEC      =  -73.13946 / DEC of slit in deg
# HIERARCH ESO INS MOS2 DEC      =  -73.14261 / DEC of slit in deg
# HIERARCH ESO INS MOS3 DEC      =   -73.1471 / DEC of slit in deg
# HIERARCH ESO INS MOS4 DEC      =  -73.15445 / DEC of slit in deg
# HIERARCH ESO INS MOS5 DEC      =  -73.15463 / DEC of slit in deg
# HIERARCH ESO INS MOS6 DEC      =  -73.16347 / DEC of slit in deg
# HIERARCH ESO INS MOS7 DEC      =  -73.17062 / DEC of slit in deg
# HIERARCH ESO INS MOS8 DEC      =  -73.17501 / DEC of slit in deg
# HIERARCH ESO INS MOS9 DEC      =  -73.18152 / DEC of slit in deg
# HIERARCH ESO INS MOS11 DEC     =  -73.18907 / DEC of slit in deg
# HIERARCH ESO INS MOS12 DEC     =  -73.19615 / DEC of slit in deg
# HIERARCH ESO INS MOS13 DEC     =  -73.20016 / DEC of slit in deg
# HIERARCH ESO INS MOS14 DEC     =  -73.20286 / DEC of slit in deg
# HIERARCH ESO INS MOS15 DEC     =  -73.20822 / DEC of slit in deg
# HIERARCH ESO INS MOS16 DEC     =  -73.21334 / DEC of slit in deg
# HIERARCH ESO INS MOS17 DEC     =  -73.21964 / DEC of slit in deg
# HIERARCH ESO INS MOS18 DEC     =  -73.23319 / DEC of slit in deg
# HIERARCH ESO INS MOS19 DEC     =  -73.23423 / DEC of slit in deg
# HIERARCH ESO INS MOS1 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS2 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS3 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS4 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS5 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS6 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS7 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS8 LEN      =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS9 LEN      =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS11 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS12 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS13 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS14 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS15 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS16 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS17 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS18 LEN     =      38.98 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS19 LEN     =       43.4 / MOSi slit length in arcsec
# HIERARCH ESO INS MOS1 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS2 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS3 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS4 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS5 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS6 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS7 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS8 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS9 POSANG   =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS11 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS12 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS13 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS14 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS15 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS16 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS17 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS18 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS MOS19 POSANG  =    -30.048 / MOS slit posang (N=0 E=90)
# HIERARCH ESO INS TARG1 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG2 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG3 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG4 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG5 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG6 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG7 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG8 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG9 NAME    = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG11 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG12 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG13 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG14 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG15 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG16 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG17 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG18 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG19 NAME   = 'NN      ' / Name of the target for MOS observa
# HIERARCH ESO INS TARG1 RA      = 12.91867917 / RA of MOS target in deg
# HIERARCH ESO INS TARG2 RA      = 12.8944375 / RA of MOS target in deg
# HIERARCH ESO INS TARG3 RA      = 12.8818875 / RA of MOS target in deg
# HIERARCH ESO INS TARG4 RA      = 12.88132917 / RA of MOS target in deg
# HIERARCH ESO INS TARG5 RA      = 12.83502083 / RA of MOS target in deg
# HIERARCH ESO INS TARG6 RA      = 12.84428333 / RA of MOS target in deg
# HIERARCH ESO INS TARG7 RA      = 12.84716667 / RA of MOS target in deg
# HIERARCH ESO INS TARG8 RA      = 12.82750417 / RA of MOS target in deg
# HIERARCH ESO INS TARG9 RA      = 12.82390833 / RA of MOS target in deg
# HIERARCH ESO INS TARG11 RA     = 12.7834125 / RA of MOS target in deg
# HIERARCH ESO INS TARG12 RA     = 12.7785125 / RA of MOS target in deg
# HIERARCH ESO INS TARG13 RA     = 12.75936667 / RA of MOS target in deg
# HIERARCH ESO INS TARG14 RA     =   12.73105 / RA of MOS target in deg
# HIERARCH ESO INS TARG15 RA     =   12.72165 / RA of MOS target in deg
# HIERARCH ESO INS TARG16 RA     =    12.7042 / RA of MOS target in deg
# HIERARCH ESO INS TARG17 RA     = 12.69787917 / RA of MOS target in deg
# HIERARCH ESO INS TARG18 RA     = 12.73672917 / RA of MOS target in deg
# HIERARCH ESO INS TARG19 RA     = 12.70422083 / RA of MOS target in deg
# HIERARCH ESO INS TARG1 DEC     = -73.14031111 / DEC of MOS target in deg
# HIERARCH ESO INS TARG2 DEC     = -73.14312222 / DEC of MOS target in deg
# HIERARCH ESO INS TARG3 DEC     = -73.14544444 / DEC of MOS target in deg
# HIERARCH ESO INS TARG4 DEC     = -73.15320278 / DEC of MOS target in deg
# HIERARCH ESO INS TARG5 DEC     = -73.15527778 / DEC of MOS target in deg
# HIERARCH ESO INS TARG6 DEC     = -73.16404167 / DEC of MOS target in deg
# HIERARCH ESO INS TARG7 DEC     = -73.16923889 / DEC of MOS target in deg
# HIERARCH ESO INS TARG8 DEC     = -73.17476389 / DEC of MOS target in deg
# HIERARCH ESO INS TARG9 DEC     = -73.180675 / DEC of MOS target in deg
# HIERARCH ESO INS TARG11 DEC    = -73.187325 / DEC of MOS target in deg
# HIERARCH ESO INS TARG12 DEC    = -73.19615833 / DEC of MOS target in deg
# HIERARCH ESO INS TARG13 DEC    = -73.19987222 / DEC of MOS target in deg
# HIERARCH ESO INS TARG14 DEC    = -73.20294444 / DEC of MOS target in deg
# HIERARCH ESO INS TARG15 DEC    =  -73.20715 / DEC of MOS target in deg
# HIERARCH ESO INS TARG16 DEC    = -73.21441944 / DEC of MOS target in deg
# HIERARCH ESO INS TARG17 DEC    = -73.22084167 / DEC of MOS target in deg
# HIERARCH ESO INS TARG18 DEC    = -73.23357222 / DEC of MOS target in deg
# HIERARCH ESO INS TARG19 DEC    = -73.23214444 / DEC of MOS target in deg
# HIERARCH ESO INS COLL ID       = '+6      ' / Collimator unique ID
# HIERARCH ESO INS COLL NAME     = 'COLL_SR ' / Collimator name
# HIERARCH ESO INS GRIS1 POSANG  =    -30.048 / Grism posang (N=0 E=90)
# HIERARCH ESO INS GRIS1 ID      = '+11     ' / Grism unique ID
# HIERARCH ESO INS GRIS1 NAME    = 'GRIS_300I' / Grism name.
# HIERARCH ESO INS GRIS1 DISP    =       10.8 / Grism dispersion
# HIERARCH ESO INS GRIS1 WLEN    =       858. / Grism central wavelength
# HIERARCH ESO INS FILT1 ID      = '+32     ' / Filter unique ID
# HIERARCH ESO INS FILT1 NAME    = 'OG590   ' / Filter i name
# HIERARCH ESO INS FOCU POS      =   0.144975 / Focus position in cm
# HIERARCH ESO INS FOCU TEMP     =       16.3 / Focus temperature in C
# HIERARCH ESO INS IMAGE DISTOR1 = 0.000536747 / distortion coefficient
# HIERARCH ESO INS IMAGE DISTOR2 = -2.15778E-06 / distortion coefficient
# HIERARCH ESO INS IMAGE DISTOR3 = 2.11331E-09 / distortion coefficient
# HIERARCH ESO INS OPTI2 NAME    = 'MOS     ' / Name of long slit or polarimetric
# HIERARCH ESO INS OPTI3 NAME    = 'COLL_SR ' / Name of collimator
# HIERARCH ESO INS OPTI4 NAME    = 'free    ' / Name of retarder plate
# HIERARCH ESO INS OPTI5 NAME    = 'free    ' / element name in wheel 1 (Wollaston
# HIERARCH ESO INS OPTI6 NAME    = 'GRIS_300I' / element name in wheel2 (grism)
# HIERARCH ESO INS OPTI7 NAME    = 'OG590   ' / element name in wheel3 (parallel b
# HIERARCH ESO INS OPTI8 NAME    = 'CAMERA  ' / camera name
# HIERARCH ESO INS OPTI9 NAME    = 'free    ' / element name in wheel 4 (interfere
# HIERARCH ESO INS OPTI10 NAME   = 'free    ' / Element name in wheel 5 (interf. 2
# HIERARCH ESO INS OPTI2 ID      = '        ' / Id of long slit or polarimetric ma
# HIERARCH ESO INS OPTI3 ID      = '+6      ' / Identification of collimator
# HIERARCH ESO INS OPTI4 ID      = '        ' / Id of retarder plate
# HIERARCH ESO INS OPTI5 ID      = '        ' / element id in wheel 1 (Wollaston)
# HIERARCH ESO INS OPTI6 ID      = '+11     ' / element id in wheel2 (grism)
# HIERARCH ESO INS OPTI7 ID      = '+32     ' / element id in wheel3 (parallel bea
# HIERARCH ESO INS OPTI8 ID      = '+8      ' / camera id
# HIERARCH ESO INS OPTI9 ID      = '        ' / element id in wheel 4 (interferenc
# HIERARCH ESO INS OPTI10 ID     = '        ' / Element id in wheel 5 (interf. 2)
# HIERARCH ESO INS OPTI2 TYPE    = 'MOS     ' / Element type in the focal field.
# HIERARCH ESO INS OPTI3 TYPE    = 'COLL    ' / Element type
# HIERARCH ESO INS OPTI4 TYPE    = '        ' / Element type
# HIERARCH ESO INS OPTI5 TYPE    = '        ' / Element type in wheel 1
# HIERARCH ESO INS OPTI6 TYPE    = 'GRIS    ' / Element type in wheel 2
# HIERARCH ESO INS OPTI7 TYPE    = 'FILT    ' / Element type in wheel 3
# HIERARCH ESO INS OPTI8 TYPE    = 'CAMERA  ' / Element type
# HIERARCH ESO INS OPTI9 TYPE    = '        ' / Element type in wheel 4
# HIERARCH ESO INS OPTI10 TYPE   = '        ' / Element type in wheel 5
# HIERARCH ESO DET CHIP1 INDEX   =          1 / Chip index
# HIERARCH ESO DET CHIP1 ID      = 'CCID20-14-5-3' / Detector chip identification
# HIERARCH ESO DET CHIP1 NAME    = 'MIT/LL mosaic' / Detector chip name
# HIERARCH ESO DET CHIP1 DATE    = '2001-08-01' / Date of installation [YYYY-MM-DD
# HIERARCH ESO DET CHIP1 X       =          1 / X location in array
# HIERARCH ESO DET CHIP1 Y       =          2 / Y location in array
# HIERARCH ESO DET CHIP1 NX      =       4096 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY      =       2048 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX    =        15. / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY    =        15. / Size of pixel in Y
# HIERARCH ESO DET CHIP1 XGAP    =        30. / Gap between chips along x
# HIERARCH ESO DET CHIP1 YGAP    =       480. / Gap between chips along y
# HIERARCH ESO DET OUT1 INDEX    =          1 / Output index
# HIERARCH ESO DET OUT1 ID       = 'A       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 NAME     = 'A       ' / Description of output
# HIERARCH ESO DET OUT1 CHIP     =          1 / index of chip it belongs to
# HIERARCH ESO DET OUT1 X=          1 / X location of output
# HIERARCH ESO DET OUT1 Y=       1024 / Y location of output
# HIERARCH ESO DET OUT1 NX       =       2048 / valid pixels along X
# HIERARCH ESO DET OUT1 NY       =       1024 / valid pixels along Y
# HIERARCH ESO DET OUT1 PRSCX    =          0 / Prescan region in X
# HIERARCH ESO DET OUT1 OVSCX    =          0 / Overscan region in X
# HIERARCH ESO DET OUT1 PRSCY    =          5 / Prescan region in Y
# HIERARCH ESO DET OUT1 OVSCY    =          5 / Overscan region in Y
# HIERARCH ESO DET OUT1 CONAD    =        0.7 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 RON      =        2.9 / Readout noise per output (e-)
# HIERARCH ESO DET OUT1 GAIN     =       1.43 / Conversion from electrons to ADU
# HIERARCH ESO DET ID    = 'CCD FIERA - Rev: 3.82.1.1' / Detector system Id
# HIERARCH ESO DET NAME  = 'ccdF - fors2' / Name of detector system
# HIERARCH ESO DET DATE  = '2008-05-12' / Installation date
# HIERARCH ESO DET DID   = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET BITS  =         16 / Bits per pixel readout
# HIERARCH ESO DET RA    =    7.52625 / Apparent 00:30:06.3 RA at start
# HIERARCH ESO DET DEC   = -46.46906111 / Apparent -46:28:08.6 DEC at start
# HIERARCH ESO DET CHIPS =          1 / # of chips in detector array
# HIERARCH ESO DET OUTPUTS       =          1 / # of outputs
# HIERARCH ESO DET OUTREF=          0 / reference output
# HIERARCH ESO DET WINDOWS       =          1 / # of windows readout
# HIERARCH ESO DET SOFW MODE     = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET EXP NO=       1261 / Unique exposure ID number
# HIERARCH ESO DET EXP TYPE      = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP RDTTIME   =     12.745 / image readout time
# HIERARCH ESO DET EXP XFERTIM   =     23.772 / image transfer time
# HIERARCH ESO DET WIN1 ST       = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX     =          1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY     =          1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 NX       =       2068 / # of pixels along X
# HIERARCH ESO DET WIN1 NY       =       2048 / # of pixels along Y
# HIERARCH ESO DET WIN1 BINX     =          2 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY     =          2 / Binning factor along Y
# HIERARCH ESO DET WIN1 NDIT     =          1 / # of subintegrations
# HIERARCH ESO DET WIN1 UIT1     =       480. / user defined subintegration time
# HIERARCH ESO DET WIN1 DIT1     = 480.005636 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM     =   480.1709 / Dark current time
# HIERARCH ESO DET READ MODE     = 'normal  ' / Readout method
# HIERARCH ESO DET READ SPEED    = '100Kpix/s' / Readout speed
# HIERARCH ESO DET READ CLOCK    = '100Kps/2ports/high_gain' / Readout clock patte
# HIERARCH ESO DET READ NFRAM    =          1 / Number of readouts buffered in sin
# HIERARCH ESO DET FRAM ID       =          1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE     = 'Normal  ' / Type of frame
# HIERARCH ESO DET SHUT TYPE     = 'Iris    ' / type of shutter
# HIERARCH ESO DET SHUT ID       = 'fors shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMOPEN   =      0.198 / Time taken to open shutter
# HIERARCH ESO DET SHUT TMCLOS   =      0.209 / Time taken to close shutter
# HIERARCH ESO DET CHIP1 RGAP    =    0.08278 / Gap rotation between chips 1 and 2
# HIERARCH ESO PRO ANCESTOR      = 'FORS2.2016-11-06T04:10:28.167.fits'
# HIERARCH ESO PRO DID   = 'PRO-1.15' / Data dictionary for PRO
# HIERARCH ESO PRO CATG  = 'MAPPED_FLUX_SCI_MOS' / Category of pipeline product fr
# HIERARCH ESO PRO TYPE  = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH  = 'MOS     ' / Observation technique
# HIERARCH ESO PRO SCIENCE       = T / Scientific product if T
# HIERARCH ESO PRO REC1 ID       = 'fors_science' / Pipeline recipe (unique) ident
# HIERARCH ESO PRO REC1 DRS ID   = 'cpl-7.0 ' / Data Reduction System identifier
# HIERARCH ESO PRO REC1 PIPE ID  = 'fors2/5.3.11' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC1 RAW1 NAME= 'FORS2.2016-11-06T04:10:28.167.fits' / File na
# HIERARCH ESO PRO REC1 RAW1 CATG= 'SCIENCE_MOS' / Category of raw frame
# HIERARCH ESO PRO DATANCOM      =          1 / Number of combined frames
# HIERARCH ESO PRO REC1 CAL1 NAME= 'curv_coeff_mos.fits' / File name of calibrati
# HIERARCH ESO PRO REC1 CAL1 CATG= 'CURV_COEFF_MOS' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL1 DATAMD5     = '61615463191637312de37ae4a8818b0d' / MD
# HIERARCH ESO PRO REC1 CAL2 NAME= 'disp_coeff_mos.fits' / File name of calibrati
# HIERARCH ESO PRO REC1 CAL2 CATG= 'DISP_COEFF_MOS' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL2 DATAMD5     = 'fdaac1a3a9ebddbbb9c67f934b624d44' / MD
# HIERARCH ESO PRO REC1 CAL3 NAME= 'fors2_extinct_table.fits' / File name of cali
# HIERARCH ESO PRO REC1 CAL3 CATG= 'EXTINCT_TABLE' / Category of calibration fram
# HIERARCH ESO PRO REC1 CAL4 NAME= 'flat_sed_mos.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL4 CATG= 'FLAT_SED_MOS' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL4 DATAMD5     = '20847e2b3c33b84988d9d08b2118fdeb' / MD
# HIERARCH ESO PRO REC1 CAL5 NAME= 'FORS2_GRS_300I_11_OG590_32.fits' / File name
# HIERARCH ESO PRO REC1 CAL5 CATG= 'GRISM_TABLE' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL5 DATAMD5     = '5f297c63b9d8003ec525f5db116acf74' / MD
# HIERARCH ESO PRO REC1 CAL6 NAME= 'master_bias.fits' / File name of calibration
# HIERARCH ESO PRO REC1 CAL6 CATG= 'MASTER_BIAS' / Category of calibration frame
# HIERARCH ESO PRO REC1 CAL6 DATAMD5     = '9641e9eac1221a0872122fbfc11bc82f' / MD
# HIERARCH ESO PRO REC1 CAL7 NAME= 'master_norm_flat_mos.fits' / File name of cal
# HIERARCH ESO PRO REC1 CAL7 CATG= 'MASTER_NORM_FLAT_MOS' / Category of calibrati
# HIERARCH ESO PRO REC1 CAL7 DATAMD5     = 'e5574441e4140b882be2aa805efa2698' / MD
# HIERARCH ESO PRO REC1 CAL8 NAME= 'slit_location_mos.fits' / File name of calibr
# HIERARCH ESO PRO REC1 CAL8 CATG= 'SLIT_LOCATION_MOS' / Category of calibration
# HIERARCH ESO PRO REC1 CAL8 DATAMD5     = '98e5d381e79226d08fcead0cfe888b8f' / MD
# HIERARCH ESO PRO REC1 CAL9 NAME= 'specphot_table.fits' / File name of calibrati
# HIERARCH ESO PRO REC1 CAL9 CATG= 'SPECPHOT_TABLE' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL9 DATAMD5     = 'e7dacfd6d5d558cac081cc8ea543ce7e' / MD
# HIERARCH ESO PRO REC1 PARAM1 NAME      = 'skyalign' / Polynomial order for sky l
# HIERARCH ESO PRO REC1 PARAM1 VALUE     = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM2 NAME      = 'flatfield' / Apply flat field
# HIERARCH ESO PRO REC1 PARAM2 VALUE     = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM3 NAME      = 'skyglobal' / Subtract global sky spect
# HIERARCH ESO PRO REC1 PARAM3 VALUE     = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM4 NAME      = 'skymedian' / Sky subtraction from extr
# HIERARCH ESO PRO REC1 PARAM4 VALUE     = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM5 NAME      = 'skylocal' / Sky subtraction from CCD s
# HIERARCH ESO PRO REC1 PARAM5 VALUE     = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM6 NAME      = 'cosmics ' / Eliminate cosmic rays hits
# HIERARCH ESO PRO REC1 PARAM6 VALUE     = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM7 NAME      = 'slit_margin' / Number of pixels to exc
# HIERARCH ESO PRO REC1 PARAM7 VALUE     = '3       ' / Default: 3
# HIERARCH ESO PRO REC1 PARAM8 NAME      = 'ext_radius' / Maximum extraction radiu
# HIERARCH ESO PRO REC1 PARAM8 VALUE     = '12      ' / Default: 12
# HIERARCH ESO PRO REC1 PARAM9 NAME      = 'cont_radius' / Minimum distance at whi
# HIERARCH ESO PRO REC1 PARAM9 VALUE     = '0       ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM10 NAME     = 'ext_mode' / Object extraction method:
# HIERARCH ESO PRO REC1 PARAM10 VALUE    = '1       ' / Default: 1
# HIERARCH ESO PRO REC1 PARAM11 NAME     = 'resp_fit_nknots' / Number of knots in
# HIERARCH ESO PRO REC1 PARAM11 VALUE    = '-1      ' / Default: -2
# HIERARCH ESO PRO REC1 PARAM12 NAME     = 'resp_fit_degree' / Degree of polynomia
# HIERARCH ESO PRO REC1 PARAM12 VALUE    = '6       ' / Default: -2
# HIERARCH ESO PRO REC1 PARAM13 NAME     = 'resp_ignore_mode' / Types of lines/reg
# HIERARCH ESO PRO REC1 PARAM13 VALUE    = 'stellar_absorption,telluric,command_l'
# HIERARCH ESO PRO REC1 PARAM14 NAME     = 'resp_ignore_points' / Extra lines/regi
# HIERARCH ESO PRO REC1 PARAM14 VALUE    = '        ' / Default: ''
# HIERARCH ESO PRO REC1 PARAM15 NAME     = 'resp_use_flat_sed' / Use the flat SED
# HIERARCH ESO PRO REC1 PARAM15 VALUE    = 'grism_table' / Default: 'grism_table'
# HIERARCH ESO PRO REC1 PARAM16 NAME     = 'nonlinear_level' / Level above which t
# HIERARCH ESO PRO REC1 PARAM16 VALUE    = '60000   ' / Default: 60000
# HIERARCH ESO ADA ABSROT START  = -179.57963 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA POSANG=  -30.04844 / Position angle at start
# HIERARCH ESO ADA GUID STATUS   = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA GUID RA       =  12.500321 / 00:50:00.0 Guide star RA J2000
# HIERARCH ESO ADA GUID DEC      =  -73.17125 / -73:10:16.5 Guide star DEC J2000
# HIERARCH ESO ADA ABSROT PPOS   = 'NEG     ' / sign of probe position
# HIERARCH ESO ADA ABSROT END    = -177.23957 / Abs rot angle at exp end (deg)
#
# HISTORY  ESO-DESCRIPTORS START   ................
# HISTORY  'ROTANG_FROM_CD-MATRIX','R*8',1,2,'3E23.15'
# HISTORY    0.000000000000000E+00  0.000000000000000E+00
# HISTORY
# HISTORY  'LHCUTS','R*4',1,4,'5E14.7'
# HISTORY  -5.9942369E+00 1.3341143E+01-5.9942369E+00 1.3341143E+01
# HISTORY
# HISTORY  ESO-DESCRIPTORS END     ................

# %%
hdu = hdulist[0]

# %%
nx, wav0, i0, dwav = [hdu.header[k] for k in ("NAXIS1", "CRVAL1", "CRPIX1", "CD1_1")]
wavs = wav0 + (np.arange(nx) - (i0 - 1))*dwav

# %%
Flux = hdulist[0].data

# %%
Flux*=10**-16

# %%
Flux
# Out:
# array([ -4.89584091e-16,  -4.89239666e-16,  -4.88895770e-16, ...,
#         -5.53296321e-16,  -5.52405189e-16,  -5.51505058e-16], dtype=float32)

# %%
#plt.xlim(xmin=3000,xmax=7000)
#plt.ylim(ymin=-1e-17,ymax=1e-16)
xlabel("Wavelength, Angstrom")
ylabel("Flux, erg/cm^2/s/A")
plt.plot(wavs, Flux)
gcf().set_size_inches(12,8)
grid()
