# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt

# %% [raw]
# Candidate 1

# %% [markdown]
# Candidate 1: Number: 29862, field: 59, Coor Deceimal: RA = 40.6964  Dec = 0.0145, Coord Sex: 02 42 47.13600 +00 00 52.2000. Looking in Simbad I found are very close to the H II region: [EKS96] NGC 1068 92 -- HII (ionized) region, in the Galaxy NGC 1060 or Messier 77. coor: 02 42 46.98 +00 00 45.5, colud be this H II regions but dont have positional coincidencia. Are not catalogen in SDSS. Close of a galaxy cataloged by SDSS: 02:42:44.86 +00:00:56.11... 47 milhões de anos-luz (14,4 Mpc)

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters.append(a)
mag = [18.17, 17.75, 17.75, 18.95, 17.98, 18.47, 19.02, 18.42, 16.5, 18.8, 19.37, 20.0]

# %%
plt.plot(filters, mag, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.tick_params(axis='x', labelsize=14) 
plt.tick_params(axis='y', labelsize=14)
plt.xlabel("Filters", size = 14)
plt.ylabel("Magnitude [AB]", size = 14)
plt.xlim(xmin=0,xmax=13)
plt.ylim(ymin=16.3,ymax=20.1)
plt.tight_layout()
plt.savefig("known-HII-splus-idr-photo2098.png")
plt.show()
plt.clf()

# %% [raw]
# Candidate 2

# %% [markdown]
# Candidate 2: Number: 661, field:70,   Coor Deceimal: RA = 48.3320  Dec = 0.1812, Coord Sex: 03 13 19.68000 +00 10 52.3200. Very close according to SIMBAD of: HD 20045 -- Star, star very bright (but not are), Coord: 03 13 21.4824 +00 10 27.257. According to DR14 SDSS: 48.332927302, 0.181957414, Sexa: 03:13:19.90, +00:10:55.04, classified like star, probabily is not because I got the spectrum made the convulution and the photospectrum is very differnt to this. it look like a typical star. Perdida de tiempo.

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters.append(a)
mag = [14.16, 14.19, 14.05, 13.88, 14.16, 12.47, 14.08, 13.75, 11.69, 13.85, 14.26, 13.75]

# %%
plotfile = "NP-splus.jpg"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=13)
ax.set_ylim(ymin=11.5,ymax=15)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
#plt.text(0.05, 0.90, 'S-PLUS cPN1',
         #transform=ax.transAxes, fontsize=21)
#plt.margins(0.06)
plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)

# %% [markdown]
# # Symbiotics candidates

# %% [markdown]
# candidate 1 ==>
# Field: 39.0, number: 20682.0,	RA=26.3853, Dec=-0.6545--- 01 45 32.472  -00 39 16.200
# Appear: dr14 SDSS as galaxy. 01:45:32.49, -00:39:16.28
# -)THE SECOND-GENERATION GUIDE STAR CATALOG: DESCRIPTION AND PROPERTIES
# -)THE PAN-STARRS1 SURVEYS
# -)VizieR Online Data Catalog: WISE All-Sky Data Release
# -)The Guide Star Catalog, Version 2.3.2 (GSC2.3) (STScI, 2006)
# -)Light-Motion Curve Catalogue (LMCC) in Stripe 82 (Bramich+ 2008)
#    We present a new public archive of light-motion curves in Sloan Digital Sky Survey (SDSS) Stripe 82, covering 99° in right ascension from to and spanning in declination from to , for a total sky area of ~249 deg2. Stripe 82 has been repeatedly monitored in the u, g, r, i and z bands over a seven-year baseline. Objects are cross-matched between runs, taking into account the effects of any proper motion. The resulting catalogue contains almost 4 million light-motion curves of stellar objects and galaxies. The photometry are recalibrated to correct for varying photometric zero-points, achieving ~20 and 30 mmag rms accuracy down to 18 mag in the g,r,i and z bands for point sources and extended sources, respectively. The astrometry are recalibrated to correct for inherent systematic errors in the SDSS astrometric solutions, achieving ~32 and 35 mas rms accuracy down to 18 mag for point sources and extended sources, respectively. For each light-motion curve, 229 photometric and astrometric quantities are derived and stored in a higher level catalogue. On the photometric side, these include mean exponential and point spread function (PSF) magnitudes along with uncertainties, rms scatter, χ2 per degree of freedom, various magnitude distribution percentiles, object type (stellar or galaxy), and eclipse, Stetson and Vidrih variability indices. On the astrometric side, these quantities include mean positions, proper motions as well as their uncertainties and χ2 per degree of freedom. The light-motion curve catalogue presented here is complete down to r ~ 21.5 and is at present the deepest large-area photometric and astrometric variability catalogue available.

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 12):
    filters.append(a)
mag = [22.18, 22.51, 25.66, 21.97, 21.68, 21.34, 20.54, 19.15, 20.0, 19.65, 19.65] # no tiene el filtro J0395

plotfile = "yst-splus.pdf"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=12)
#ax.set_ylim(ymin=11.5,ymax=15)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
plt.text(0.7, 0.90, 'S-PLUS cSySt1',
         transform=ax.transAxes, fontsize=21)
#plt.margins(0.06)
plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)

# %% [markdown]
# Candidate 2
# Field 47.0, number=14547.0,	RA=32.5678, dec=-0.1084. 02 10 16.272  -00 06 30.240'
# Appear SDSS as galaxy:02:10:15.48, -00:06:29.83

# %%
filters = []
filter_name = [ 'J0395', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 10):
    filters.append(a)
mag = [ 20.52, 21.16, 22.27, 21.25, 20.17, 17.56, 19.38, 18.99, 18.93] # no tiene el filtro uJAVA, J0378, J0410


plotfile = "yst2-splus.pdf"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=10)
#ax.set_ylim(ymin=11.5,ymax=15)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
plt.text(0.02, 0.90, 'S-PLUS cSySt1',
         transform=ax.transAxes, fontsize=21)
#plt.margins(0.06)
plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)

# %% [markdown]
# Candidate 3:
# Field: 53.0, Nember:30375.0	RA:36.1045,	dec:0.0103
# -) SDSS galaxy
# -) Photometric redshift catalog from the RCS (Hsieh+, 2005)
# -)SFR for WISE + SDSS spectroscopic galaxies (Chang+, 2015)
# -) Compact groups of galaxies in SDSS DR6 (McConnachie+, 2009)

# %%
filters = []
filter_name = ['uJAVA', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 12):
    filters.append(a)
mag = [ 23.4, 21.37, 21.28, 21.33, 20.99, 20.44, 19.61, 17.62, 18.95, 18.75, 18.77] # no tiene el filtro J0378, 
plt.plot(filters, mag, 'ko-')
#plt.xlim(xmin=3900,xmax=8000)
#plt.ylim(ymin=18,ymax=28)
plt.xticks(filters, filter_name, rotation=45)
plt.xlabel("Filters")
plt.ylabel("Magnitude")
plt.xlim(xmin=0,xmax=12)
plt.tight_layout()
plt.show()
plt.clf()

# %% [markdown]
# Candidate 4
#
# Field: 108.0, Number:12828.0, RA=314.0986, Dec=0.3336
# Appear: SDSS galaxi
# -)The Million Quasars (Milliquas) catalog (V5.2) (Flesch, 2017): 20 56 23.633	+00 20 01.00	314.098472	+00.333611
# -)

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 12):
    filters.append(a)
mag = [22.34, 21.77, 23.69, 21.28, 21.06, 20.42, 19.59, 18.52, 19.3, 18.73, 18.75] # no tiene 0395
#plt.xlim(xmin=3900,xmax=8000)
#plt.ylim(ymin=18,ymax=28)
plt.plot(filters, mag, 'ko-')
plt.xticks(filters, filter_name, rotation=45)
plt.xlabel("Filters")
plt.ylabel("Magnitude")
plt.xlim(xmin=0,xmax=12)
plt.show()
plt.clf()

# %% [markdown]
# Candiadate 5
#
# Field:115.0, Number:43843.0, RA:320.3835, dec=-0.3744, 21 21 32.040  -00 22 27.840
# -) SDSS star
# -)The Guide Star Catalog, Version 2.3.2 (GSC2.3) (STScI, 2006)
# [No tener en cuanta esta referencia-)Asiago-ESO/RASS QSO survey. II. (Grazian+, 2002): 21 21 31.65	-00 22 30.0 	320.38186	-00.375000 ]

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'gSSSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 10):
    filters.append(a)
mag = [20.59, 20.15, 21.37, 20.65, 19.69, 17.77, 18.67, 18.1, 18.22] # no tiene J0410,J0430,J0395

plotfile = "yst3-splus.pdf"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=10)
#ax.set_ylim(ymin=11.5,ymax=15)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
plt.text(0.02, 0.90, 'S-PLUS cSySt2',
         transform=ax.transAxes, fontsize=21)
#plt.margins(0.06)
plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)

# %% [markdown]
# # Convolution

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters.append(a)
mag = [18.52834, 19.1067, 19.07474, 18.9938, 18.656929, 17.546213, 17.2867393, 15.97116756, 15.0154104, 15.7851486, 15.480927467, 15.458161354064941] # no tiene J0410,J0430,J0395

plotfile = "conbulution-splus-syst.pdf"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=13)
#ax.set_ylim(ymin=15.4,ymax=20.9)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
plt.text(0.5, 0.90, 'Synthetic S-PLUS SySt SMC 1',
         transform=ax.transAxes, fontsize=21)
#plt.margins(0.06)
plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)

# %% [markdown]
# Photo-spectra

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'J0861', 'zSDSS']
for a in range(1, 13):
    filters.append(a)
mag = [13.61, 13.74, 13.81, 13.79, 13.85, 14.11, 14.17, 14.55, 14.67, 14.96, 15.2, 15.28] # no tiene J0410,J0430,J0395

plotfile = "fr2-21-HASH-PN-splus.jpg"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=10)
#ax.set_ylim(ymin=11.5,ymax=15)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
plt.text(0.02, 0.90, 'Fr 2-21',
         transform=ax.transAxes, fontsize=21)
#plt.margins(0.06)
plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)

# %% [markdown]
# # PNe or HII region candidate DR (marz 2018)

# %% [markdown]
# Extragalactic Halpha emitter STRIPE82-0028,	15766.0: Deci:18.2018	0.9871, sex: 01 12 48.43200 +00 59 13.5600 located in NGC 428 AGN

# %%
filters = []
filter_name = ['uJAVA', 'J0378', 'J0395', 'J0410', 'J0430', 'gSDSS', 'J0515', 'rSDSS', 'J0660', 'iSDSS', 'zSDSS']
for a in range(1, 12):
    filters.append(a)
mag = [20.22, 19.86, 19.95, 20.98, 20.98, 20.63, 20.86, 20.37, 18.68, 21.03, 20.73] # no tiene J0861

plotfile = "HII-cand1-splus.jpg"
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(1,1,1)
plt.tick_params(axis='x', labelsize=21) 
plt.tick_params(axis='y', labelsize=21)
ax.set_xlim(xmin=0,xmax=12)
#ax.set_ylim(ymin=11.5,ymax=15)
    #ax1.set_xlabel(r'$\lambda$')
ax.set_xlabel(r'Filters', size = 21)
ax.set_ylabel(r'Magnitude [AB]', size = 21)
ax.plot(filters, mag, 'ko-')
#ax.errorbar(filters, X_h4, yerr=err_h41, marker='o', fmt='ko', elinewidth=1.2, markeredgewidth=1.2, markersize=8,)
plt.xticks(filters, filter_name, rotation=45)
#plt.margins(0.06)
#plt.subplots_adjust(bottom=0.19)
#plt.gca().invert_yaxis()
plt.savefig(plotfile)
plt.show()
plt.clf()
