# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import glob
import json
import matplotlib.pyplot as plt

# %%
x=np.linspace (-20, 20) 
y = 2.7*x + 2.15 
y1 = 2.7*x + 0.5

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_xlim(xmin=-2.5,xmax=5.5)
ax1.set_ylim(ymin=-2.0,ymax=5.0)
plt.xlabel('Jv0915_6199 - Jv0915_7700', size = 12)
plt.ylabel('Jv0915_6199 - Jv0915_6600', size = 12)
ax1.plot(x, y, c='black', label='1')
ax1.plot(x, y1, c='red', label='2')
ax1.legend(scatterpoints=1, ncol=2, fontsize='x-small')
ax1.grid()
gcf().set_size_inches(12,8)
